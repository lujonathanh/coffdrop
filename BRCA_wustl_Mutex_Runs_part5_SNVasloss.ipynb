# %% [markdown]
# # ----------------------------------------------------------------------
# # Coffdrop Runs
# # ----------------------------------------------------------------------
#
#
# Coffdrop is a software package for finding mutual exclusivity and co-occurrence in cancer genes.

# %% [markdown]
# # Set parameters

# %%
mutationmatrix = '/Users/jlu96/maf/new/BRCA_wustl/BRCA_wustl-som-l-cna-gl.m2'
# Set to name of tab-delimited matrix file. First column of each row should be Patient ID. Remaining row entries are names of present mutations

patientFile = '/Users/jlu96/maf/new/BRCA_wustl/shared_patients.plst'
# only load patients listed in this file. Set to None to use all the patients.

geneFile = None
# Only load genes listed in this file. Set to None to use all the patients


geneList1 = 'data/COSMICCensus-gl.glst'

geneList2 = None
# If want to specifically look for pairs between certain genes, set geneList1 and geneList2. All
# pairs between one gene in geneList1 and one gene in geneList2 will be tested
# If you just want to look among geneList1, set geneList2 to None

output_prefix =  "output/BRCA_wustl-som-l-cna-gl-snvsnotasloss_COSMIC" # Prefix for "OUTPUT FILES", below:



#OUTPUT FILES-------
pairfile = output_prefix + 'pairs-min_cohort.txt' #Pair statistics within the least mutated patients
new_pairfile = output_prefix + "-pairs-min_cohort_filtered.txt" #Pair statistics over all patients
new_cpairfile = output_prefix + "-cpairs-min_cohort_filtered.txt" #Co-occurringPair statistics over all patients
new_mpairfile = output_prefix + "-mpairs-min_cohort_filtered.txt"#Mutually exclusive Pair statistics over all patients
triplet_output_prefix = output_prefix + '-triplets-'
segment_info_file = output_prefix + "segment_info.txt" # Name of file to write segmentation information to
gene_c_file = new_cpairfile[:-4] + "_genes.txt"
gene_m_file = new_mpairfile[:-4] + "_genes.txt"
cyto_c_file = new_cpairfile[:-4] + "_cytobands.txt"
cyto_m_file = new_mpairfile[:-4] + "_cytobands.txt"
cytopairs_c_file = new_cpairfile[:-4] + "_cytoband-pairs.txt"
cytopairs_m_file = new_mpairfile[:-4] + "_cytoband-pairs.txt"

network_c_file = new_cpairfile[:-4] + "_network.txt"
network_m_file = new_mpairfile[:-4] + "_network.txt"

# %% [markdown]
# # If you want to test all pairs without first using the least mutated patients, run the following cell.

# %%
minFreq = 0
leastPatientThreshold = 100
test_gene_threshold = 0
closer_than_distance = 100000000
only_filter_copy_distance = True
cFDRthreshold = 0.05
mFDRthreshold = 0.05
pairs_have_dependencies = True
remove_missing_genes = True

# %% [markdown]
# # Otherwise, set the parameters in the following cell and run it.

# %%
minFreq = 0
# Only load genes mutated at least this many times.


leastPatientThreshold = 15
# To choose which genes to test, first consider only the patients below this percentile. e.g. if set to 50, the bottom 50% of patients
# are called least mutated.

test_gene_threshold = 0
# Test genes that are mutated in at least this percentage of the least mutated patients.



closer_than_distance = 100000000
# Minimum distance between genes to test them, in bp. Set to None to prevent any filtering.

only_filter_copy_distance = True
# only filter the distance between copy number segements (by closer_than_distance) if True. Default is True.
# This is included since copy number segments are not independent.
# Note: if somatic mutations are annotated was loss, then they will be filtered as well

cFDRthreshold = 0.05
# FDR threshold for c-pvalues.

mFDRthreshold = 0.05
# FDR threshold for mutually exclusive pairs.

pairs_have_dependencies = True
#for FDR threshold. Set to True to be conservative, otherwise FDR only controls under independence/positive dependence assumptions

remove_missing_genes = True

# %% [markdown]
# # 1) Plot the distribution of mutations across genes and across patients
# # 2) Plot distribution over the least mutated patients
# # 3) Generate the gene pairs to be tested
#
# A good rule of thumb is to

# %%
import mutex as mex
import csv
import mutex_triangles as met
import chisquared as chi
import bingenesbypairs as bgbp
import time
import os
import scipy.stats as stats
import partition as par
import numpy as np
import multi_testing as mt
# %matplotlib inline

COSMIC_pair_insertion_index = 8
COSMIC_triplet_insertion_index = 5
compute_mutex = True

numGenes, numCases, genes, patients, geneToCases, patientToGenes = mex.load_mutation_data(mutationmatrix, patientFile, geneFile, minFreq)

print '%s genes x %s patients' % (numGenes, numCases)


print "*******************************************************************"
print "*                   PLOT MUTATION DISTRIBUTIONS                   *"
print "*******************************************************************"

print "GENE MUTATION DISTRIBUTION"
mex.graph_mutation_distribution(numCases, genes, geneToCases, filename=mutationmatrix + " Genes", bins=100, zoomin_percentile=95)


print "\nPATIENT MUTATION DISTRIBUTION"
mex.graph_patient_distribution(len(genes), patients, patientToGenes, mutationmatrix + " Patients", bottom_percentile=leastPatientThreshold, zoomin_percentile=95)


print "*******************************************************************"
print "*         PLOT DISTRIBUTIONS AMONG LEAST MUTATED PATIENTS         *"
print "*******************************************************************"




D = [len(patientToGenes[p]) for p in patientToGenes]
minThreshold = stats.scoreatpercentile(D, leastPatientThreshold)

c0patients = [p for p in patientToGenes if len(patientToGenes[p]) <= minThreshold]

c0cohort_dict = {0: c0patients}

c0genes, c0geneToCases, c0patientToGenes = par.get_cluster_gTC_pTG(geneToCases, patientToGenes, c0patients)

print "GENE MUTATION DISTRIBUTION IN LEAST MUTATED PATIENTS"
mex.graph_mutation_distribution(len(c0patients), c0genes, c0geneToCases, filename=mutationmatrix + " genes in least mutated", bins=100)

print "\nPATIENT MUTATION DISTRIBUTION IN LEAST MUTATED PATIENTS"
mex.graph_patient_distribution(len(genes), c0patients, c0patientToGenes, filename=mutationmatrix + " patients in least mutated")



print "*******************************************************************"
print "*                   GETTING TEST GENE PAIRS                       *"
print "*******************************************************************"
print "The least mutated patients are the bottom ", leastPatientThreshold, " % of patients"
print "Least mutated patients: %s genes x %s patients" % (len(c0genes), len(c0patients) )


test_minFreq = int( test_gene_threshold * 0.01 * len(c0patients))
print "The test gene threshold is ", test_gene_threshold, "% of the least mutated patients"
print "Test genes are mutated at least ", test_minFreq, " in th least mutated patients"

reload(bgbp)
print 
print
print "Number of test genes: ", len([g for g in c0genes if len(c0geneToCases[g]) >= test_minFreq and (not remove_missing_genes or
                                                                                                     bgbp.get_segment_gene_info(g)['Chromosome'] != bgbp.missing_chromosome)])

t = time.time()
if geneList1 != None and geneList2 !=None:
    with open(geneList1) as f:
            genes1 = set(l.rstrip().split()[0] for l in f if not l.startswith("#"))
    with open(geneList2) as f:
            genes2 = set(l.rstrip().split()[0] for l in f if not l.startswith("#"))
    
    genepairs = bgbp.getgenepairs(c0geneToCases, genes1, genes2=genes2, test_minFreq=0, closer_than_distance=closer_than_distance, only_filter_copy_distance=only_filter_copy_distance,
                                 remove_missing_genes=remove_missing_genes)
    
elif geneList1 != None:
    with open(geneList1) as f:
            genes1 = set(l.rstrip().split()[0] for l in f if not l.startswith("#"))
    
    genepairs = bgbp.getgenepairs(c0geneToCases, genes1, test_minFreq=0, closer_than_distance=closer_than_distance, only_filter_copy_distance=only_filter_copy_distance,
                                 remove_missing_genes=remove_missing_genes)     
else:
    genepairs = bgbp.getgenepairs(c0geneToCases, c0genes, test_minFreq=test_minFreq, closer_than_distance=closer_than_distance, only_filter_copy_distance=only_filter_copy_distance,
                                 remove_missing_genes=remove_missing_genes)

print "Pairs must be at least ", closer_than_distance, "away to be tested"    
print "Number of pairs is ", len(genepairs), " retrieved in time : ", time.time() - t

os.system('say "exploration finished"')
# Out:
# 50427 genes x 963 patients
# *******************************************************************
# *                   PLOT MUTATION DISTRIBUTIONS                   *
# *******************************************************************
# GENE MUTATION DISTRIBUTION
# Zoomed into bottom 95 percent region
# PATIENT MUTATION DISTRIBUTION
# Zoomed into bottom 95 percent region
# *******************************************************************
# *         PLOT DISTRIBUTIONS AMONG LEAST MUTATED PATIENTS         *
# *******************************************************************
# GENE MUTATION DISTRIBUTION IN LEAST MUTATED PATIENTS
# PATIENT MUTATION DISTRIBUTION IN LEAST MUTATED PATIENTS
# *******************************************************************
# *                   GETTING TEST GENE PAIRS                       *
# *******************************************************************
# The least mutated patients are the bottom  15  % of patients
# Least mutated patients: 40685 genes x 145 patients
# The test gene threshold is  0 % of the least mutated patients
# Test genes are mutated at least  0  in th least mutated patients
#
#
# Number of test genes:  Gene  NUDT16Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C11orf34loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238305.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  GPR97loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U3|ENSG00000252792.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  O3FAR1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238970.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SPATA31A4gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  B3GNT1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD112|ENSG00000252009.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL765Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000252265.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  FAM86Aloss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA64|ENSG00000199566.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  PRED57gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  AGAP10gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA18|ENSG00000252249.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD112|ENSG00000252687.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA40|ENSG00000212363.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U3|ENSG00000251800.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RMRPP4gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  ZNF259loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000239056.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  FAM194Bloss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA8|ENSG00000207410.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA24|ENSG00000207130.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  ACA64|ENSG00000239008.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SOGA2gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000239111.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD112|ENSG00000252790.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C19orf59loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  PHF15loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  LEPREL4gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  FTSJD2loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RPL23AP79loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U3|ENSG00000252683.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SCARNA15|ENSG00000252193.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  FAM5Cgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  MGC4294gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SCARNA20|ENSG00000251861.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD65|ENSG00000212229.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA72|ENSG00000206901.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238327.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  EMR2gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  PTPLAD2gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U8|ENSG00000199713.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA48|ENSG00000212214.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  CT49gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  FAM203Again  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  FAM205Bloss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C19orf59gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD11|ENSG00000238317.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238472.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL389Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  THEG5gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238654.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA40|ENSG00000212579.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  FAM203Bloss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C22orf26loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C1orf200gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C5orf54loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C6orf57gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238528.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  MRPL45P2gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL298Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  7SK|ENSG00000271765.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA48|ENSG00000212604.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD19B|ENSG00000238862.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL626Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SGK196loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C5orf27gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  LPPR1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  PTPLAD2loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL642Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA31|ENSG00000252580.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238799.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U3|ENSG00000221040.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  TSRMgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD46|ENSG00000200913.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238596.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238983.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U8|ENSG00000207430.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  HBCBPgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA18|ENSG00000252249.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238389.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA1|ENSG00000202059.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238422.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA18|ENSG00000252719.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C6orf123loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U3|ENSG00000221332.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238631.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238418.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA18|ENSG00000207145.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL576Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238801.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SCXAgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA48|ENSG00000252824.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA75|ENSG00000212432.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL224Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C9orf38gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoZ185gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238932.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  GSTT1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA40|ENSG00000212273.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SLC25A6|ENSG00000169100.8gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  DKFZP667F0711gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SOGA2loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  DEFB130|ENSG00000233050.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238322.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238545.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD112|ENSG00000252844.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  PRMT10loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD112|ENSG00000252646.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL142Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL844Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U3|ENSG00000252189.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U3|ENSG00000212422.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  WDR52gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238686.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  FAM203Aloss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U8|ENSG00000200496.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  FTSJD2gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238752.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238745.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA74|ENSG00000223182.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SLC24A6loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000239133.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238564.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RNU2-2loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238463.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL839Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  PHF16gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  GOLGA2Bgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL157Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C12orf23loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD42|ENSG00000201209.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238425.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000239098.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  TMEM236|ENSG00000184040.7loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000239066.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C17orf103loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C21orf37gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA15|ENSG00000206785.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  XAGE1Cgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SEPT4loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000239132.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA26|ENSG00000212590.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238733.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA81|ENSG00000253092.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  MARCH3gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL99Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  NBPF24gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  MIR4520Bloss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238494.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  LINC00849loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD103Aloss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000252609.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL439Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL86Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL529Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RPS17Lgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C7orf63loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA38|ENSG00000200816.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238863.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238951.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  TTLL13gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD74|ENSG00000200891.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000239111.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA43|ENSG00000253049.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U3|ENSG00000253014.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA18|ENSG00000206592.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238631.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U3|ENSG00000201368.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238718.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238569.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238686.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238522.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U3|ENSG00000251944.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C20orf20loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA42|ENSG00000199787.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U3|ENSG00000253091.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  OR5H8Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL224Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA31|ENSG00000251828.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238630.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238978.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C19orf82loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  GPR144gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL295Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD43|ENSG00000263764.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA33|ENSG00000252045.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD56|ENSG00000207299.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  HCCAT3gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000239089.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238486.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238501.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238768.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA26|ENSG00000212421.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD112|ENSG00000251911.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000239146.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  FKBP9Lgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA31|ENSG00000252349.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  GPR115loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C17orf61loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA70|ENSG00000206661.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA18|ENSG00000206849.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RNA5SP381loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238416.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238747.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA7|ENSG00000200620.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238863.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SCARNA20|ENSG00000252800.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238868.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD28|ENSG00000252284.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238855.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  MIR3191gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000239094.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA26|ENSG00000212624.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  FAM188B2gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD112|ENSG00000252354.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000252387.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U3|ENSG00000199666.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238326.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SCARNA6|ENSG00000252798.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA57|ENSG00000212529.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL609Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA31|ENSG00000252337.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  FAM21Bgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL53Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SIGLECP3loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL9Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA31|ENSG00000253059.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA31|ENSG00000252136.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  EMR3gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000239144.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238864.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  AKR1CL1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238893.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD5|ENSG00000238854.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL773Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA42|ENSG00000199787.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SCARNA24|ENSG00000252777.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238387.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  KIAA0182loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  PTPN20Aloss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000252799.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000239013.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL136Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C21orf90gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  MIR1255B1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  KIAA1432loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  MLTKloss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  MIR1910gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  YSK4loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL739Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U8|ENSG00000212581.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238939.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  NBPF20gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  GPR133loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA51|ENSG00000207177.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238717.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  CEAloss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD66|ENSG00000212158.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238970.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U3|ENSG00000201368.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  FAM194Aloss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  FLJ39653loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  LIMS3|ENSG00000257207.4loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  DOM3Zloss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238296.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  EMR3loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  INTS4L2gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C14orf144loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  PRED58gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA25|ENSG00000251735.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SEPT14gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U3|ENSG00000200042.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  FAM74A5gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  PIDDgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL511Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  LSMD1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA31|ENSG00000252433.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD65|ENSG00000212264.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U3|ENSG00000201329.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SMCR7loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000239061.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA40|ENSG00000252352.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL312Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U3|ENSG00000251793.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL112Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD112|ENSG00000253068.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  MARCH8loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL71Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL710Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C19orf10gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  MIR548O2gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL770Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA74|ENSG00000252917.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U3|ENSG00000212539.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238935.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238981.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  FAM138Fgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  GOLGA6L10|ENSG00000205281.6gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD112|ENSG00000252565.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238947.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA70|ENSG00000252133.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C19orf42loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  FLJ20306gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  PDPK2loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SCARNA18|ENSG00000238835.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C12orf55gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SKP215gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U3|ENSG00000212479.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoZ6|ENSG00000252200.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  FLJ27365gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA40|ENSG00000253065.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238979.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U3|ENSG00000212479.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  LINC00312gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL365Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL669Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SCARNA11|ENSG00000251898.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA7|ENSG00000222604.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C1orf173gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA63|ENSG00000200130.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA11|ENSG00000261709.2gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U3|ENSG00000200538.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA46|ENSG00000212371.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL109Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U3|ENSG00000251979.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  MIR4667loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA58|ENSG00000201003.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238314.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  NSG1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  BAI3gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  FAM74A2gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238587.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  LINC00948gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA26|ENSG00000212421.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  MIR518Dloss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL857Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238375.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA30|ENSG00000202189.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA70|ENSG00000252258.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  ATP1A1OSloss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA31|ENSG00000251802.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C5orf50gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL852Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SEPT4gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U6|ENSG00000272028.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL358Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U3|ENSG00000200042.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C15ORF37gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  NUDT16Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA70|ENSG00000252724.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD74|ENSG00000201025.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C21orf119gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  ZNF271loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD111|ENSG00000252230.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  LIMS3|ENSG00000256977.6loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238433.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL701Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000252071.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD112|ENSG00000252646.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL548Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA74|ENSG00000252213.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  TRNAI6loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  TMEM236|ENSG00000148483.7loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL115Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  AGAP8loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL175Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238318.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA51|ENSG00000206853.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA40|ENSG00000252049.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL367Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000239176.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RMRPP1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U3|ENSG00000221461.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA72|ENSG00000252158.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL349Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000272179.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  GPR128gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238857.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238896.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SBP1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000251860.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  FAM115Aloss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA70|ENSG00000200237.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C20orf166gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD112|ENSG00000252873.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoZ6|ENSG00000253067.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C17orf66loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL347Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  CXorf48loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238336.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238629.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000239079.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA1|ENSG00000199405.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000239137.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA72|ENSG00000207084.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  PP13439gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C16orf11loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SCARNA11|ENSG00000251898.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA62|ENSG00000202363.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  TRNAI2loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238878.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD56|ENSG00000229686.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL669Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA7|ENSG00000222604.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238409.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA40|ENSG00000212587.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SMCR7Lloss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  LINC00617gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  WDR52loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  NSG2loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238665.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA38|ENSG00000201042.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  AKD1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RMRPP2gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD67|ENSG00000212135.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U8|ENSG00000207432.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SOLHloss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA25|ENSG00000252204.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  FOXD4L2loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238473.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD77|ENSG00000212414.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  MIR3607gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA16|ENSG00000201467.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000252706.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL651Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA26|ENSG00000212590.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA22|ENSG00000199571.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  CSPG4P8gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U8|ENSG00000212249.2loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  ENSG00000210194loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  EMR2loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  FAM27Aloss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA75|ENSG00000212440.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  FAM22Gloss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238692.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  DKFZP779J2370gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD63|ENSG00000252112.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000243321.2gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000239123.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA62|ENSG00000272015.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  IQCA1P1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238792.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C10orf118loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  MIR3200loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL572Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  KIAA1244gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  MIR3200gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C10orf68loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA11|ENSG00000221750.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA67|ENSG00000252473.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  LEPRE1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C5orf20gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000239067.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL409Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA7|ENSG00000206976.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238907.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD56|ENSG00000199783.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD45|ENSG00000231297.2loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL374Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C1ORF220gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C10orf115loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  ZAKloss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000239130.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SCARNA16|ENSG00000252329.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA25|ENSG00000252550.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238841.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# ...
# Gene  C14orf23loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  FLJ11235loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238651.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C2orf53loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoZ178gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238834.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA45loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C5orf55loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U3|ENSG00000199769.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA43|ENSG00000201733.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RNY5P3gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000239134.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  ELTD1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U6|ENSG00000271932.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA48|ENSG00000252228.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000251762.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  PP13004gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA81|ENSG00000238390.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  NARG2gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA15|ENSG00000207062.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238525.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA27|ENSG00000252459.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA75|ENSG00000206780.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL777Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C9orf37gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  CCDC177|ENSG00000267909.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RNY5P1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C6orf164gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238488.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238595.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoZ6|ENSG00000264452.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA51|ENSG00000206878.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238352.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238744.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  ENSG00000249034loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C1orf222loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  CXorf64loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  GPR98loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C7orf10gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  CRYBG3|ENSG00000233280.2gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA57|ENSG00000223027.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA40|ENSG00000252188.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL289Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA70|ENSG00000253027.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000239027.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  KIAA1967loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  MGC20647gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  MIR519A2gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U8|ENSG00000200191.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  GPR133gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL730Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD112|ENSG00000252356.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238630.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA68|ENSG00000251715.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238475.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  KIAA1383loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SKP41loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U3|ENSG00000199851.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000251737.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  PCDHB17gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD59|ENSG00000252682.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SUZ12Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA73|ENSG00000201816.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000239080.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA25|ENSG00000199392.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238674.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  FAM105Bloss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA74|ENSG00000223182.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL723Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U3|ENSG00000253009.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C1orf180gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU109|ENSG00000238754.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238712.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA2|ENSG00000202343.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA64|ENSG00000207405.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  MIR4743gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238878.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA48|ENSG00000212445.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  CXorf31gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA40|ENSG00000252693.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL747Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RMRPP1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C1orf63gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238438.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD112|ENSG00000252154.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C6orf211loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD38|ENSG00000200733.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  KIAA1967gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL686Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238626.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SDIM1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  LPHN3loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C10orf40loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA74|ENSG00000252917.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA25|ENSG00000199392.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000239171.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL746Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238598.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238334.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  LINC00478gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  CCDC135gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD115|ENSG00000212428.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL59Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238699.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA40|ENSG00000252083.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238988.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  Vault|ENSG00000252283.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U8|ENSG00000200026.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  BAI2loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  CKS1B|ENSG00000268942.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD45|ENSG00000200706.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL109Ploss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U8|ENSG00000251740.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238986.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SCARNA20|ENSG00000252800.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SCARNA18|ENSG00000252139.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SCARNA6|ENSG00000252798.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  U3|ENSG00000252709.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  RN7SL324Pgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  MGC20647loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  7SK|ENSG00000232512.2gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  CCDC177|ENSG00000255994.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  KIAA1658loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000239159.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA3|ENSG00000221719.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA25|ENSG00000252993.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  PWRN2loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  MIR1910loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA31|ENSG00000252349.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SEPT7gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA63|ENSG00000199473.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA64|ENSG00000199566.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  PLAC1Lgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  LINC00516gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238895.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238859.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238684.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD33|ENSG00000252022.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C3orf37loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  LINC00344gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000239121.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA12|ENSG00000212342.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  MNF1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD112|ENSG00000252502.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238947.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  GPR114loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  snoU13|ENSG00000238712.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C22orf26gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD75|ENSG00000221711.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA21|ENSG00000199293.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORD111|ENSG00000221066.1loss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  MIR3192gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  SNORA75|ENSG00000212440.1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  FTSJD1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  C14orf64gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  MTERFgain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  FAM5Bloss  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# Gene  DBC1gain  was not found in gene_positions.txt. We pretend it is on Chromosome Z.
# 37444
# All genes that weren't found in gene_positions file will not be considered
# Number of pairs to test:  0
# Pairs must be at least  100000000 away to be tested
# Number of pairs is  0  retrieved in time :  0.0772821903229
# 0

# %%
print genes1
# Out:
# set(['ABI1'])

# %% [markdown]
# ## Perform statistical tests of each of the pairs
# ### This cell's runtime is usually about (number of pairs)/ 900 seconds.

# %%
print "Getting normal statistics..."
t = time.time()
pairsdict, genedict = met.cooccurpairs(numCases, geneToCases, patientToGenes, genepairs, compute_mutex=compute_mutex)
print "Finished in ", time.time() - t

print "Testing among least mutated patients..."
t = time.time()
pairsdict = chi.add_BinomP_cohorts_all_pairs(pairsdict, geneToCases, patientToGenes, c0cohort_dict, c0patients)
print "Finished in ", time.time() - t
print "All pairs tested in least mutated patients written to ",  pairfile

fieldnames = (pairsdict.values()[0]).keys()
fieldnames.remove('MutationFrequencies')
fieldnames.remove('MutationFrequencyDifference')
fieldnames.remove('MutationFrequencyDifferenceRatio')
fieldnames.remove('CooccurrenceRatio')
fieldnames.remove('Coverage')
fieldnames.remove('SetScore')
fieldnames.remove('AverageOverlapPMN')
fieldnames.remove('CombinedScore')
fieldnames.remove('Concordance')
fieldnames.remove('Somatic')
fieldnames.remove('RoundedLogPCov')
fieldnames.remove('GeneSet')
fieldnames.remove('Type')


fieldnames.insert(2, 'Type')
fieldnames.insert(3, '1CBinomProb0')
fieldnames.insert(3, '1MBinomProb0')

met.writeanydict(pairsdict, pairfile, fieldnames=fieldnames)
print "Pairs in least mutated patients finished"
os.system('say "Pairs in least mutated patients finished"')
# Out:
# Getting normal statistics...
# Finished in  0.000213861465454
# Testing among least mutated patients...
# Finished in  0.000267028808594
# All pairs tested in least mutated patients written to  output/BRCA_wustl-som-l-cna-gl-snvsnotasloss_COSMICpairs-min_cohort.txt
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-11e71f824b92> in <module>()
#      10 print "All pairs tested in least mutated patients written to ",  pairfile
#      11
# ---> 12 fieldnames = (pairsdict.values()[0]).keys()
#      13 fieldnames.remove('MutationFrequencies')
#      14 fieldnames.remove('MutationFrequencyDifference')
#
# IndexError: list index out of range

# %% [markdown]
# # Plot the distribution of p-values.

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
cpvalues = np.array([pairsdict[c]['1CBinomProb0'] for c in pairsdict])
logcp = np.log10(cpvalues)
mpvalues = np.array([pairsdict[c]['1MBinomProb0'] for c in pairsdict])
logmp = np.log10(mpvalues)


plt.figure()
plt.hist(logcp, bins=50)
plt.title("Distribution of " + str(len(logcp)) + " Co-occurring Pairs over " + str(leastPatientThreshold) + "% Least mut. patients", fontsize=20)
plt.xlabel("Log-10 P-values", fontsize=20)
plt.legend(loc='best')
plt.show()

plt.figure()
plt.hist(logmp, bins=50)
plt.title("Distribution of " + str(len(logmp))  + " Mutually Exclusive Pairs over " + str(leastPatientThreshold) + "% Least mut. patients", fontsize=20)
plt.xlabel("Log-10 P-values", fontsize=20)
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## The remaining code prepares for testing across the whole distribution with FDR control.
# ## If you just care about p-values and not significance, you can stop here.
# ## ---------------

# %% [markdown]
# # Set the cutoff of significant pairs to test over the whole distribution

# %%
cpairPercentile = 5
# Percentile of most significant co-occurring pairs to test

mpairPercentile = 5

# %% [markdown]
# # Visualize the cutoff
# ## Go back and adjust if you'd like!

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
cpvalues = np.array([pairsdict[c]['1CBinomProb0'] for c in pairsdict])
logcp = np.log10(cpvalues)
mpvalues = np.array([pairsdict[c]['1MBinomProb0'] for c in pairsdict])
logmp = np.log10(mpvalues)


cthreshold = stats.scoreatpercentile(cpvalues, cpairPercentile)
mthreshold = stats.scoreatpercentile(mpvalues, mpairPercentile)
print "Top ", cpairPercentile, "percent of cooccurring pairs: ", cthreshold
print "Top ", mpairPercentile, "percent of mutually exclusive pairs : ", mthreshold

# Let's get the top 10 percent of pairs

goodcpairs = [c for c in pairsdict if (pairsdict[c]['1CBinomProb0'] <= cthreshold)]
goodmpairs = [c for c in pairsdict if (pairsdict[c]['1MBinomProb0'] <= mthreshold)]
goodpairs = goodcpairs + goodmpairs
goodgenes = set.union(*(set(goodpair) for goodpair in goodpairs))
print "Now number of mutex pairs to test ", len(goodmpairs)
print "Now number of coocurr pairs to test ", len(goodcpairs)
print "Number of genes ", len(goodgenes)

plt.figure()
plt.hist(logcp, bins=50)
plt.axvline(x= np.log10(cthreshold), label="Top " + str(cpairPercentile) + "%")
plt.title("Distribution of " + str(len(logcp)) + " Co-occurring Pairs over " + str(leastPatientThreshold) + "% Least mut. patients", fontsize=20)
plt.xlabel("Log-10 P-values", fontsize=20)
plt.legend(loc='best')
plt.show()



plt.figure()
plt.hist(logmp, bins=50)
plt.axvline(x= np.log10(mthreshold), label="Top " + str(mpairPercentile) + "%")
plt.title("Distribution of " + str(len(logmp))  + " Mutually Exclusive Pairs over " + str(leastPatientThreshold) + "% Least mut. patients", fontsize=20)
plt.xlabel("Log-10 P-values", fontsize=20)
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### Test new pairs

# %%
print "Getting normal statistics across whole distribution"

new_mpairsdict, new_mgenedict = met.cooccurpairs(numCases, geneToCases, patientToGenes, goodmpairs, compute_mutex=compute_mutex)
new_cpairsdict, new_cgenedict = met.cooccurpairs(numCases, geneToCases, patientToGenes, goodcpairs, compute_mutex=compute_mutex)

print "Testing across the whole distribution"

new_mpairsdict = chi.add_BinomP_cohorts_all_pairs(new_mpairsdict, geneToCases, patientToGenes, c0cohort_dict, c0patients)
new_cpairsdict = chi.add_BinomP_cohorts_all_pairs(new_cpairsdict, geneToCases, patientToGenes, c0cohort_dict, c0patients)

new_pairsdict = new_mpairsdict.copy()
new_pairsdict.update(new_mpairsdict)


print "All tested pairs have been written to ", new_pairfile

fieldnames = (new_pairsdict.values()[0]).keys()
fieldnames.remove('MutationFrequencies')
fieldnames.remove('MutationFrequencyDifference')
fieldnames.remove('MutationFrequencyDifferenceRatio')
fieldnames.remove('CooccurrenceRatio')
fieldnames.remove('Coverage')
fieldnames.remove('SetScore')
fieldnames.remove('AverageOverlapPMN')
fieldnames.remove('CombinedScore')
fieldnames.remove('Concordance')
fieldnames.remove('Somatic')
fieldnames.remove('RoundedLogPCov')
fieldnames.remove('GeneSet')
fieldnames.remove('Type')

fieldnames.insert(2, 'Type')
fieldnames.insert(3, 'AllMBinomProb')
fieldnames.insert(3, 'AllCBinomProb')

met.writeanydict(new_pairsdict, new_pairfile, fieldnames=fieldnames)

os.system('say "whole distribution pairs finished"')

# %% [markdown]
# ### Plot results

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

cpairs = [c for c in new_cpairsdict]
cpvalues = np.array([new_cpairsdict[c]['AllCBinomProb'] for c in new_cpairsdict])
sig_cpairs, sig_cpvalues, cthreshold = mt.BH(cpairs, cpvalues, Q=cFDRthreshold, use_dependencies=pairs_have_dependencies)

not_sig_cpairs = set(new_cpairsdict.keys()).difference(set(sig_cpairs))

new_sig_c_dict = new_cpairsdict.copy()
for not_sig_cpair in not_sig_cpairs:
    del new_sig_c_dict[not_sig_cpair]

logcp = np.log10(cpvalues)

if len(logcp) > 1:
    plt.figure()
    plt.hist(logcp, bins=50)
    plt.axvline(x=np.log10(cthreshold), label="FDR Threshold", c='r')
    plt.title("Distribution of " + str(len(logcp)) + " Co-occurring Pairs over all", fontsize=20)
    plt.xlabel("Log-10 P-values", fontsize=20)
    plt.legend(loc='best')
    plt.show()
elif len(logcp) == 1:
    print "One tested co-occurring pair with p=", cpvalues[0]


mpairs = [c for c in new_mpairsdict]
mpvalues = np.array([new_mpairsdict[c]['AllMBinomProb'] for c in new_mpairsdict])
sig_mpairs, sig_mpvalues, mthreshold = mt.BH(mpairs, mpvalues, Q=mFDRthreshold, use_dependencies=pairs_have_dependencies)

not_sig_mpairs = set(new_mpairsdict.keys()).difference(set(sig_mpairs))

new_sig_m_dict = new_mpairsdict.copy()
for not_sig_mpair in not_sig_mpairs:
    del new_sig_m_dict[not_sig_mpair]

logmp = np.log10(mpvalues)

if len(logmp) > 1:
    plt.figure()
    plt.hist(logmp, bins=50)
    plt.axvline(x=np.log10(mthreshold), label="FDR Threshold", c='r')
    plt.title("Distribution of " + str(len(logmp)) + " Mutually Exclusive Pairs over all", fontsize=20)
    plt.xlabel("Log-10 P-values", fontsize=20)
    plt.legend(loc='best')
    plt.show()
elif len(logmp) == 1:
    print "One tested mutex pair with p=", mpvalues[0]




print "Number significant mutex", len(new_sig_m_dict)
print "Number significant coocurr", len(new_sig_c_dict)


new_sig_dict = new_sig_m_dict.copy()
new_sig_dict.update(new_sig_c_dict)
# Out:
# Number significant mutex 0
# Number significant coocurr 9

# %% [markdown]
# ## Mutual exclusivity info

# %%
bgbp.write_segment_infos(goodgenes, segment_info_file)



print "*********MUTUAL EXCLUSIVITY INFO**********\n"

print len(new_sig_m_dict), " Mutually exclusive pairs"

mfieldnames = ['Gene0', 'Gene1', 'Gene0Cytobands', 'Gene1Cytobands', 'AllMBinomProb', 
                'AllFreqs', 'AllOverlap', 'AllSize','1MBinomProb0', '1Freqs0', '1Overlap0',
               '1Size0']


gene_m_dict = {}
cyto_m_dict = {}
cyto_pair_m_dict = {}

for pair in new_sig_m_dict:
    if new_sig_m_dict[pair]['Gene0'][-4:] in {'loss', 'gain'}:
        suffix0 = new_sig_m_dict[pair]['Gene0'][-4:]
    else:
        suffix0 = ""

    if new_sig_m_dict[pair]['Gene1'][-4:] in {'loss', 'gain'}:
        suffix1 = new_sig_m_dict[pair]['Gene1'][-4:]
    else:
        suffix1 = ""
    
    
    info0 = bgbp.get_segment_gene_info(new_sig_m_dict[pair]['Gene0'])
    new_sig_m_dict[pair]['Gene0Loc'] = str(info0['Chromosome']) + ':' + str(info0['Start'])
    info1 = bgbp.get_segment_gene_info(new_sig_m_dict[pair]['Gene1'])
    new_sig_m_dict[pair]['Gene1Loc'] = str(info1['Chromosome']) + ':' + str(info1['Start'])
    new_sig_m_dict[pair]['Gene0Cytobands'] = "-".join(info0['Cytobands'])
    new_sig_m_dict[pair]['Gene1Cytobands'] = "-".join(info1['Cytobands'])
    
    
    if new_sig_m_dict[pair]['Gene0'] not in gene_m_dict:
        gene_m_dict[new_sig_m_dict[pair]['Gene0']] = set()
    gene_m_dict[new_sig_m_dict[pair]['Gene0']].add(pair)
    if new_sig_m_dict[pair]['Gene1'] not in gene_m_dict:
        gene_m_dict[new_sig_m_dict[pair]['Gene1']] = set()
    gene_m_dict[new_sig_m_dict[pair]['Gene1']].add(pair)
    
    
    
    if "-".join(info0['Cytobands']) + suffix0 not in cyto_m_dict:
        cyto_m_dict["-".join(info0['Cytobands']) + suffix0] = set()
    cyto_m_dict["-".join(info0['Cytobands']) + suffix0].add(pair)
    if "-".join(info1['Cytobands']) + suffix1 not in cyto_m_dict:
        cyto_m_dict["-".join(info1['Cytobands']) + suffix1] = set()
    cyto_m_dict["-".join(info1['Cytobands'])+ suffix1].add(pair)
    
    
    
    cyto_pair = frozenset(["-".join(info0['Cytobands']) + suffix0, "-".join(info1['Cytobands']) + suffix1])
    
    if cyto_pair not in cyto_pair_m_dict:
        cyto_pair_m_dict[cyto_pair] = set()
        
    cyto_pair_m_dict[cyto_pair].add(pair)


if new_sig_m_dict:
    for key in new_sig_m_dict[pair].keys():
        if key not in mfieldnames:
            mfieldnames.append(key)
    

orderedmpairs = sorted(new_sig_m_dict.keys(), key=lambda entry: (new_sig_m_dict[entry]['AllMBinomProb'],))
    
met.writeanydict(new_sig_m_dict, new_mpairfile, fieldnames=mfieldnames, orderedkeys=orderedmpairs)
print "updated with segment info ", new_mpairfile
# !python add_COSMIC.py -ic Gene0 Gene1 -ip $COSMIC_pair_insertion_index -i $new_mpairfile -o $new_mpairfile
print "updated with COSMIC info ", new_mpairfile


# Writing gene infos
    

sorted_genes = sorted(gene_m_dict.items(), key = lambda entry: len(entry[1]), reverse=True)
sorted_cytobands = sorted(cyto_m_dict.items(), key = lambda entry: len(entry[1]), reverse=True)
sorted_cytotuples = sorted(cyto_pair_m_dict.items(), key = lambda entry: len(entry[1]), reverse=True)

print "\n**********SINGLE GENES**********"
print_length = 15
for gene in sorted_genes:
    if len(gene[0]) <= print_length + 4:
        print gene[0], "has", len(gene[1])
    else:
        print gene[0][0:print_length] + gene[0][-4:], "has\t", len(gene[1])

print "Writing single genes output to ", gene_m_file
with open(gene_m_file, 'w') as csvfile:
    writer = csv.writer(csvfile, delimiter='\t')
    writer.writerow(["Gene", "Pairs"])
    for gene, pairs in sorted_genes:
        writer.writerow([gene, len(pairs)])

print "\n**********SINGLE CYTOBANDS**********"
for cytoband in sorted_cytobands:
    print cytoband[0], "has", len(cytoband[1])
    
print "Writing single cytobands output to ", cyto_m_file
with open(cyto_m_file, 'w') as csvfile:
    writer = csv.writer(csvfile, delimiter='\t')
    writer.writerow(["Cytoband", "Pairs"])
    for cytoband, pairs in sorted_cytobands:
        writer.writerow([cytoband, len(pairs)])

print "\n**********PAIRED CYTOBANDS**********"
for cytotuple in sorted_cytotuples:
    print  cytotuple[0], "has", len(cytotuple[1])
    
print "Writing paired cytobands output to ", cytopairs_m_file
with open(cytopairs_m_file, 'w') as csvfile:
    writer = csv.writer(csvfile, delimiter='\t')
    writer.writerow(["Cytoband1", "Cytoband2", "Number"])
    for cytopair, pairs in sorted_cytotuples:
        cyto1, cyto2 = tuple(cytopair)
        writer.writerow([cyto1, cyto2, len(pairs)])


os.system('say "finished"')
# Out:
# *********MUTUAL EXCLUSIVITY INFO**********
#
# 0  Mutually exclusive pairs
# updated with segment info  output/BRCA_wustl-som-cna-gl-tumor_suppressors_cytotest-mpairs-min_cohort_filtered.txt
# updated with COSMIC info  output/BRCA_wustl-som-cna-gl-tumor_suppressors_cytotest-mpairs-min_cohort_filtered.txt
#
# **********SINGLE GENES**********
# Writing single genes output to  output/BRCA_wustl-som-cna-gl-tumor_suppressors_cytotest-mpairs-min_cohort_filtered_genes.txt
#
# **********SINGLE CYTOBANDS**********
# Writing single cytobands output to  output/BRCA_wustl-som-cna-gl-tumor_suppressors_cytotest-mpairs-min_cohort_filtered_cytobands.txt
#
# **********PAIRED CYTOBANDS**********
# Writing paired cytobands output to  output/BRCA_wustl-som-cna-gl-tumor_suppressors_cytotest-mpairs-min_cohort_filtered_cytoband-pairs.txt
# 0

# %% [markdown]
# # Draw mutual exclusivity network

# %%
import networkx as nx
import csv

G=nx.Graph()
for pair in new_sig_m_dict:
    pair_type = new_sig_m_dict[pair]['Type']
    
    G.add_edge(tuple(pair)[0], tuple(pair)[1], {"Type": pair_type})

pos = nx.spring_layout(G)
nx.draw(G, pos)

# show graph
plt.show()

graphs = list(nx.connected_component_subgraphs(G))
graphs = sorted(graphs, key = lambda entry: entry.number_of_nodes(), reverse=True)

top_number = 3

for i in range(len(graphs)):
    print "\n***********************"
    print "COMPONENT " + str(i) 
    print "***********************"
    graph = graphs[i]
    print "Number of nodes ", graph.number_of_nodes()
    print "Number of edges ", graph.number_of_edges()
    
    node_items = [g + (graph.degree(g[0]),) for g in nx.degree_centrality(graph).items()]
    node_items = sorted(node_items, key=lambda entry: entry[1], reverse = True)
    

    print "---"
    print "Top", top_number, "nodes by degree centraliy in component", i
    print "Gene: Degree Centrality   Degree"
    for j in range(min(top_number, len(node_items))):
        print node_items[j][0], ":", np.round(node_items[j][1], 2), node_items[j][2]
    
    component_file = network_m_file[:-4] + "_comp" + str(i) + ".txt"
    
    print "---"
    print "Writing nodes to: ", component_file
    with open(component_file, 'w') as csvfile:
        writer = csv.writer(csvfile, delimiter='\t')
        writer.writerow(["Node", "Degreee Centrality", "Degree"])
        for node_item in node_items:
            writer.writerow(node_item)

# %% [markdown]
# ## Co-occurrence info

# %%
bgbp.write_segment_infos(goodgenes, segment_info_file)




print "*********COOCCURRENCE INFO**********\n"

print len(new_sig_c_dict), " Co-occurring pairs"

cfieldnames = ['Gene0', 'Gene1', 'Gene0Cytobands', 'Gene1Cytobands', 'AllCBinomProb', 
               'AllFreqs', 'AllOverlap', 'AllSize','1CBinomProb0', '1Freqs0', '1Overlap0',
               '1Size0']


gene_c_dict = {}
cyto_c_dict = {}
cyto_pair_c_dict = {}

for pair in new_sig_c_dict:
    if new_sig_c_dict[pair]['Gene0'][-4:] in {'loss', 'gain'}:
        suffix0 = new_sig_c_dict[pair]['Gene0'][-4:]
    else:
        suffix0 = ""

    if new_sig_c_dict[pair]['Gene1'][-4:] in {'loss', 'gain'}:
        suffix1 = new_sig_c_dict[pair]['Gene1'][-4:]
    else:
        suffix1 = ""
    
    
    info0 = bgbp.get_segment_gene_info(new_sig_c_dict[pair]['Gene0'])
    new_sig_c_dict[pair]['Gene0Loc'] = str(info0['Chromosome']) + ':' + str(info0['Start'])
    info1 = bgbp.get_segment_gene_info(new_sig_c_dict[pair]['Gene1'])
    new_sig_c_dict[pair]['Gene1Loc'] = str(info1['Chromosome']) + ':' + str(info1['Start'])
    new_sig_c_dict[pair]['Gene0Cytobands'] = "-".join(info0['Cytobands'])
    new_sig_c_dict[pair]['Gene1Cytobands'] = "-".join(info1['Cytobands'])
    
    
    if new_sig_c_dict[pair]['Gene0'] not in gene_c_dict:
        gene_c_dict[new_sig_c_dict[pair]['Gene0']] = set()
    gene_c_dict[new_sig_c_dict[pair]['Gene0']].add(pair)
    if new_sig_c_dict[pair]['Gene1'] not in gene_c_dict:
        gene_c_dict[new_sig_c_dict[pair]['Gene1']] = set()
    gene_c_dict[new_sig_c_dict[pair]['Gene1']].add(pair)
    
    
    
    if "-".join(info0['Cytobands']) + suffix0 not in cyto_c_dict:
        cyto_c_dict["-".join(info0['Cytobands']) + suffix0] = set()
    cyto_c_dict["-".join(info0['Cytobands']) + suffix0].add(pair)
    if "-".join(info1['Cytobands']) + suffix1 not in cyto_c_dict:
        cyto_c_dict["-".join(info1['Cytobands']) + suffix1] = set()
    cyto_c_dict["-".join(info1['Cytobands']) + suffix1].add(pair)
    
    
    
    cyto_pair = frozenset(["-".join(info0['Cytobands']) + suffix0, "-".join(info1['Cytobands']) + suffix1])
    
    if cyto_pair not in cyto_pair_c_dict:
        cyto_pair_c_dict[cyto_pair] = set()
        
    cyto_pair_c_dict[cyto_pair].add(pair)
    
# Writing to file
if new_sig_c_dict:
    for key in new_sig_c_dict[pair].keys():
        if key not in cfieldnames:
            cfieldnames.append(key)
    
orderedcpairs = sorted(new_sig_c_dict.keys(), key=lambda entry: (new_sig_c_dict[entry]['AllCBinomProb'],))
    
met.writeanydict(new_sig_c_dict, new_cpairfile, fieldnames=cfieldnames, orderedkeys=orderedcpairs)
print "updated with segment info ", new_cpairfile
# !python add_COSMIC.py -ic Gene0 Gene1 -ip $COSMIC_pair_insertion_index -i $new_cpairfile -o $new_cpairfile
print "updated with COSMIC info ", new_cpairfile


# Writing gene infos
    

sorted_genes = sorted(gene_c_dict.items(), key = lambda entry: len(entry[1]), reverse=True)
sorted_cytobands = sorted(cyto_c_dict.items(), key = lambda entry: len(entry[1]), reverse=True)
sorted_cytotuples = sorted(cyto_pair_c_dict.items(), key = lambda entry: len(entry[1]), reverse=True)

print "\n**********SINGLE GENES**********"
print_length = 15
for gene in sorted_genes:
    if len(gene[0]) <= print_length + 4:
        print gene[0], "has", len(gene[1])
    else:
        print gene[0][0:print_length] + gene[0][-4:], "has\t", len(gene[1])

print "Writing single genes output to ", gene_c_file
with open(gene_c_file, 'w') as csvfile:
    writer = csv.writer(csvfile, delimiter='\t')
    writer.writerow(["Gene", "Pairs"])
    for gene, pairs in sorted_genes:
        writer.writerow([gene, len(pairs)])

print "\n**********SINGLE CYTOBANDS**********"
for cytoband in sorted_cytobands:
    print cytoband[0], "has", len(cytoband[1])
    
print "Writing single cytobands output to ", cyto_c_file
with open(cyto_c_file, 'w') as csvfile:
    writer = csv.writer(csvfile, delimiter='\t')
    writer.writerow(["Cytoband", "Pairs"])
    for cytoband, pairs in sorted_cytobands:
        writer.writerow([cytoband, len(pairs)])

print "\n**********PAIRED CYTOBANDS**********"
for cytotuple in sorted_cytotuples:
    print  cytotuple[0], "has", len(cytotuple[1])
    
print "Writing paired cytobands output to ", cytopairs_c_file
with open(cytopairs_c_file, 'w') as csvfile:
    writer = csv.writer(csvfile, delimiter='\t')
    writer.writerow(["Cytoband1", "Cytoband2", "Number"])
    for cytopair, pairs in sorted_cytotuples:
        cyto1, cyto2 = tuple(cytopair)
        writer.writerow([cyto1, cyto2, len(pairs)])
os.system('say "finished"')
# Out:
# *********COOCCURRENCE INFO**********
#
# 9  Co-occurring pairs
# updated with segment info  output/BRCA_wustl-som-cna-gl-tumor_suppressors_cytotest-cpairs-min_cohort_filtered.txt
# updated with COSMIC info  output/BRCA_wustl-som-cna-gl-tumor_suppressors_cytotest-cpairs-min_cohort_filtered.txt
#
# **********SINGLE GENES**********
# TP53 has 9
# PTENloss has 1
# APCloss has 1
# TP53loss has 1
# TSC2loss has 1
# BRCA1loss has 1
# ST5loss has 1
# CDKN1Bloss has 1
# SFRP1loss has 1
# RB1loss has 1
# Writing single genes output to  output/BRCA_wustl-som-cna-gl-tumor_suppressors_cytotest-cpairs-min_cohort_filtered_genes.txt
#
# **********SINGLE CYTOBANDS**********
# ['17p13.1'] has 9
# ['5q22.2']loss has 1
# ['17q21.31']loss has 1
# ['12p13.2']loss has 1
# ['10q23.1', '10q23.2']loss has 1
# ['17p13.1']loss has 1
# ['13q14.2']loss has 1
# ['8p11.21']loss has 1
# ['11p15.4']loss has 1
# ['16p13.3']loss has 1
# Writing single cytobands output to  output/BRCA_wustl-som-cna-gl-tumor_suppressors_cytotest-cpairs-min_cohort_filtered_cytobands.txt
#
# **********PAIRED CYTOBANDS**********
# frozenset(["['17p13.1']", "['17q21.31']loss"]) has 1
# frozenset(["['10q23.1', '10q23.2']loss", "['17p13.1']"]) has 1
# frozenset(["['16p13.3']loss", "['17p13.1']"]) has 1
# frozenset(["['5q22.2']loss", "['17p13.1']"]) has 1
# frozenset(["['11p15.4']loss", "['17p13.1']"]) has 1
# frozenset(["['8p11.21']loss", "['17p13.1']"]) has 1
# frozenset(["['13q14.2']loss", "['17p13.1']"]) has 1
# frozenset(["['12p13.2']loss", "['17p13.1']"]) has 1
# frozenset(["['17p13.1']", "['17p13.1']loss"]) has 1
# Writing paired cytobands output to  output/BRCA_wustl-som-cna-gl-tumor_suppressors_cytotest-cpairs-min_cohort_filtered_cytoband-pairs.txt
# 0

# %% [markdown]
# # Draw co-occurrence network

# %%
import networkx as nx
import csv

G=nx.Graph()
for pair in new_sig_c_dict:
    pair_type = new_sig_c_dict[pair]['Type']
    
    G.add_edge(tuple(pair)[0], tuple(pair)[1], {"Type": pair_type})

pos = nx.spring_layout(G)
nx.draw(G, pos)

# show graph
plt.show()

graphs = list(nx.connected_component_subgraphs(G))
graphs = sorted(graphs, key = lambda entry: entry.number_of_nodes(), reverse=True)

top_number = 3

for i in range(len(graphs)):
    print "\n***********************"
    print "COMPONENT " + str(i) 
    print "***********************"
    graph = graphs[i]
    print "Number of nodes ", graph.number_of_nodes()
    print "Number of edges ", graph.number_of_edges()
    
    node_items = [g + (graph.degree(g[0]),) for g in nx.degree_centrality(graph).items()]
    node_items = sorted(node_items, key=lambda entry: entry[1], reverse = True)
    

    print "---"
    print "Top", top_number, "nodes by degree centraliy in component", i
    print "Gene: Degree Centrality   Degree"
    for j in range(min(top_number, len(node_items))):
        print node_items[j][0], ":", np.round(node_items[j][1], 2), node_items[j][2]
    
    component_file = network_c_file[:-4] + "_comp" + str(i) + ".txt"
    
    print "---"
    print "Writing nodes to: ", component_file
    with open(component_file, 'w') as csvfile:
        writer = csv.writer(csvfile, delimiter='\t')
        writer.writerow(["Node", "Degreee Centrality", "Degree"])
        for node_item in node_items:
            writer.writerow(node_item)
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
# ***********************
# COMPONENT 0
# ***********************
# Number of nodes  10
# Number of edges  9
# ---
# Top 3 nodes by degree centraliy in component 0
# Gene: Degree Centrality   Degree
# TP53 : 1.0 9
# PTENloss : 0.11 1
# APCloss : 0.11 1
# ---
# Writing nodes to:  output/BRCA_wustl-som-cna-gl-tumor_suppressors_cytotest-cpairs-min_cohort_filtered_network_comp0.txt

# %% [markdown]
# ## Search for triplets from among the pairs

# %%
# Search for triplets
import mutex_triangles as met
import edgereader as edg


        
    
    
# Search for triplets
import mutex_triangles as met
import edgereader as edg

genedict = edg.get_gene_dict(new_sig_dict)
Triplets, pairsdict_Triplets, sorted_pairs, genesdict_Triplets, sorted_genes = met.getTriplets(new_sig_dict, genedict, new_sig_dict, numCases, geneToCases=geneToCases, patientToGenes=patientToGenes)
Triplet_dict = met.sort_triplets_by_type(Triplets)

for t_type in Triplet_dict:
    print len(Triplet_dict[t_type]), " of type ",  t_type
    Triplet_dict[t_type] = sorted(Triplet_dict[t_type], key=lambda entry: entry.stats['Count'], reverse=True)
    triplet_file_name = triplet_output_prefix + t_type + '.txt'
    met.writeTriplets2(Triplet_dict[t_type], triplet_file_name)
    # !python add_COSMIC.py -ic Gene0 Gene1 Gene2 -ip $COSMIC_triplet_insertion_index -i $triplet_file_name -o $triplet_file_name
    print "updated with COSMIC info ", triplet_file_name
    
    
    
    print "*********" + str(t_type) + "INFO**********\n"
    gene_t_dict = {}
    cyto_t_dict = {}
    cyto_trip_t_dict = {}
    
    
    # LEFT OFF HERE-JLU
    
    for triplet in Triplet_dict[t_type]:
        genes = triplet.genes
        suffixes = [gene[-4:] if gene[-4:] in {'loss', 'gain'} else "" for gene in genes]
        
        cytobands = set([str(bgbp.get_segment_gene_info(gene)['Cytobands']) for gene, suffix in zip(genes, suffixes)])
        
        for gene in genes:
            if gene not in gene_t_dict:
                gene_t_dict[gene] = set()
            gene_t_dict[gene].add(frozenset(genes.difference(set([gene]))))
    
        
        for cytoband in cytobands:
            if cytoband not in cyto_t_dict:
                cyto_t_dict[cytoband] = set()
            cyto_t_dict[cytoband].add(frozenset(cytobands.difference(set([cytoband]))))
    
        if frozenset(cytobands) not in cyto_trip_t_dict:
            cyto_trip_t_dict[frozenset(cytobands)] = set()
            
        cyto_trip_t_dict[frozenset(cytobands)].add(frozenset(genes))
    
    
    

    sorted_genes = sorted(gene_t_dict.items(), key = lambda entry: len(entry[1]), reverse=True)
    sorted_cytobands = sorted(cyto_t_dict.items(), key = lambda entry: len(entry[1]), reverse=True)
    sorted_cytotuples = sorted(cyto_trip_t_dict.items(), key = lambda entry: len(entry[1]), reverse=True)

    print "\n**********SINGLE GENES**********"
    print_length = 15
    for gene in sorted_genes:
        if len(gene[0]) <= print_length + 4:
            print gene[0], "has", len(gene[1])
        else:
            print gene[0][0:print_length] + gene[0][-4:], "has\t", len(gene[1])

    print "\n**********SINGLE CYTOBANDS**********"
    for cytoband in sorted_cytobands:
        print cytoband[0], "has", len(cytoband[1])

    print "\n**********TRIPLET CYTOBANDS**********"
    for cytotuple in sorted_cytotuples:
        print  cytotuple[0], "has", len(cytotuple[1])


    os.system('say "finished"')
# Out:
# number of pairs  1
# Pair info of triplets initialized
# 0  triplets calculated in  0.000514030456543
# Including sorting time  0.000821828842163

# %% [markdown]
# # IGNORE THE BELOW
# # Run weSME
