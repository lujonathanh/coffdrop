# %% [markdown]
# # ----------------------------------------------------------------------
# # Mutex Runs
# # ----------------------------------------------------------------------
#
#
# Mutex is a software package for finding mutual exclusivity and co-occurrence in cancer genes.
#
# __To disregard the FDR and filtering method__, set:
# 1. leastPatientThreshold to 100
# 2. test_gene_threshold to 0
# 3. mpairPercntile to 100
# 4. cpairPercentile to 100

# %% [markdown]
# # Set parameters

# %%
mutationmatrix = '/Users/jlu96/maf/new/PAAD_ucsc/PAAD_ucsc-seg-jl.m2'
# Set to name of tab-delimited matrix file. First column of each row should be Patient ID. Remaining row entries are names of present mutations

patientFile = '/Users/jlu96/maf/new/PAAD_ucsc/shared_patients.plst'
# only load patients listed in this file. Set to None to use all the patients.

geneFile = None
# Only load genes listed in this file. Set to None to use all the patients


output_prefix =  "output/PAAD-ucsc-seg-jl-FDR-" # Prefix for "OUTPUT FILES", below:



#OUTPUT FILES-------
pairfile = output_prefix + 'pairs-min_cohort.txt' #Pair statistics within the least mutated patients
new_pairfile = output_prefix + "-pairs-min_cohort_filtered.txt" #Pair statistics over all patients
new_cpairfile = output_prefix + "-cpairs-min_cohort_filtered.txt" #Co-occurringPair statistics over all patients
new_mpairfile = output_prefix + "-mpairs-min_cohort_filtered.txt"#Mutually exclusive Pair statistics over all patients
triplet_output_prefix = output_prefix + '-triplets-'
segment_info_file = output_prefix + "segment_info.txt" # Name of file to write segmentation information to
network_c_file = new_cpairfile[:-4] + "_network.txt"
network_m_file = new_mpairfile[:-4] + "_network.txt"

# %% [markdown]
# # If you want to test all pairs without first using the least mutated patients, run the following cell.

# %%
minFreq = 0
leastPatientThreshold = 100
test_gene_threshold = 0
closer_than_distance = 100000000
only_filter_copy_distance = True
cFDRthreshold = 0.05
mFDRthreshold = 0.05
pairs_have_dependencies = True

# %% [markdown]
# # Otherwise, set the parameters in the following cell and run it.

# %%
minFreq = 0
# Only load genes mutated at least this many times.


leastPatientThreshold = 30
# To choose which genes to test, first consider only the patients below this percentile. e.g. if set to 50, the bottom 50% of patients
# are called least mutated.

test_gene_threshold = 2
# Test genes that are mutated in at least this percentage of the least mutated patients.



closer_than_distance = 100000000
# Minimum distance between genes to test them, in bp. Set to None to prevent any filtering.


only_filter_copy_distance = True
# only filter the distance between copy number segements if True. Default is False.

cFDRthreshold = 0.05
# FDR threshold for c-pvalues.

mFDRthreshold = 0.05
# FDR threshold for mutually exclusive pairs.

pairs_have_dependencies = True

# %% [markdown]
# # 1) Plot the distribution of mutations across genes and across patients
# # 2) Plot distribution over the least mutated patients
# # 3) Generate the gene pairs to be tested
#
# A good rule of thumb is to

# %%
import mutex as mex
import csv
import mutex_triangles as met
import chisquared as chi
import bingenesbypairs as bgbp
import time
import os
import scipy.stats as stats
import partition as par
import numpy as np
import multi_testing as mt
# %matplotlib inline

COSMIC_pair_insertion_index = 8
COSMIC_triplet_insertion_index = 5
compute_mutex = True

numGenes, numCases, genes, patients, geneToCases, patientToGenes = mex.load_mutation_data(mutationmatrix, patientFile, geneFile, minFreq)

print '%s genes x %s patients' % (numGenes, numCases)


print "*******************************************************************"
print "*                   PLOT MUTATION DISTRIBUTIONS                   *"
print "*******************************************************************"

print "GENE MUTATION DISTRIBUTION"
mex.graph_mutation_distribution(numCases, genes, geneToCases, filename=mutationmatrix + " Genes", bins=100, zoomin_percentile=95)


print "\nPATIENT MUTATION DISTRIBUTION"
mex.graph_patient_distribution(len(genes), patients, patientToGenes, mutationmatrix + " Patients", bottom_percentile=leastPatientThreshold, zoomin_percentile=95)


print "*******************************************************************"
print "*         PLOT DISTRIBUTIONS AMONG LEAST MUTATED PATIENTS         *"
print "*******************************************************************"




D = [len(patientToGenes[p]) for p in patientToGenes]
minThreshold = stats.scoreatpercentile(D, leastPatientThreshold)

c0patients = [p for p in patientToGenes if len(patientToGenes[p]) <= minThreshold]

c0cohort_dict = {0: c0patients}

c0genes, c0geneToCases, c0patientToGenes = par.get_cluster_gTC_pTG(geneToCases, patientToGenes, c0patients)

print "GENE MUTATION DISTRIBUTION IN LEAST MUTATED PATIENTS"
mex.graph_mutation_distribution(len(c0patients), c0genes, c0geneToCases, filename=mutationmatrix + " genes in least mutated", bins=100)

print "\nPATIENT MUTATION DISTRIBUTION IN LEAST MUTATED PATIENTS"
mex.graph_patient_distribution(len(genes), c0patients, c0patientToGenes, filename=mutationmatrix + " patients in least mutated")



print "*******************************************************************"
print "*                   GETTING TEST GENE PAIRS                       *"
print "*******************************************************************"
print "The least mutated patients are the bottom ", leastPatientThreshold, " % of patients"
print "Least mutated patients: %s genes x %s patients" % (len(c0genes), len(c0patients) )


test_minFreq = int( test_gene_threshold * 0.01 * len(c0patients))
print "The test gene threshold is ", test_gene_threshold, "% of the least mutated patients"
print "Test genes are mutated at least ", test_minFreq, " in th least mutated patients"

print "Number of test genes: ", len([g for g in c0genes if len(c0geneToCases[g]) >= test_minFreq])

print "FAM230C IN?", len(c0geneToCases["FAM230Closs"]) >= test_minFreq

reload(bgbp)
t = time.time()
genepairs = bgbp.getgenepairs(c0geneToCases, c0genes, test_minFreq=test_minFreq, closer_than_distance=closer_than_distance, only_filter_copy_distance=only_filter_copy_distance)
print "Number of pairs is ", len(genepairs), " retrieved in time : ", time.time() - t

os.system('say "exploration finished"')
# Out:
# 1044 genes x 158 patients
# *******************************************************************
# *                   PLOT MUTATION DISTRIBUTIONS                   *
# *******************************************************************
# GENE MUTATION DISTRIBUTION
# Zoomed into bottom 95 percent region
# PATIENT MUTATION DISTRIBUTION
# Zoomed into bottom 95 percent region
# *******************************************************************
# *         PLOT DISTRIBUTIONS AMONG LEAST MUTATED PATIENTS         *
# *******************************************************************
# GENE MUTATION DISTRIBUTION IN LEAST MUTATED PATIENTS
# PATIENT MUTATION DISTRIBUTION IN LEAST MUTATED PATIENTS
# *******************************************************************
# *                   GETTING TEST GENE PAIRS                       *
# *******************************************************************
# The least mutated patients are the bottom  30  % of patients
# Least mutated patients: 692 genes x 48 patients
# The test gene threshold is  2 % of the least mutated patients
# Test genes are mutated at least  0  in th least mutated patients
# Number of test genes:  692
# FAM230C IN? True
# Number of pairs to test:  224748
# Number of pairs is  224748  retrieved in time :  9.53534197807
# 0

# %% [markdown]
# ## Perform statistical tests of each of the pairs
# ### This cell's runtime is usually about (number of pairs)/ 900 seconds.

# %%
print "Getting normal statistics..."
t = time.time()
pairsdict, genedict = met.cooccurpairs(numCases, geneToCases, patientToGenes, genepairs, compute_mutex=compute_mutex)
print "Finished in ", time.time() - t

print "Testing among least mutated patients..."
t = time.time()
pairsdict = chi.add_BinomP_cohorts_all_pairs(pairsdict, geneToCases, patientToGenes, c0cohort_dict, c0patients)
print "Finished in ", time.time() - t
print "All pairs tested in least mutated patients written to ",  pairfile

fieldnames = (pairsdict.values()[0]).keys()
fieldnames.remove('MutationFrequencies')
fieldnames.remove('MutationFrequencyDifference')
fieldnames.remove('MutationFrequencyDifferenceRatio')
fieldnames.remove('CooccurrenceRatio')
fieldnames.remove('Coverage')
fieldnames.remove('SetScore')
fieldnames.remove('AverageOverlapPMN')
fieldnames.remove('CombinedScore')
fieldnames.remove('Concordance')
fieldnames.remove('Somatic')
fieldnames.remove('RoundedLogPCov')
fieldnames.remove('GeneSet')
fieldnames.remove('Type')


fieldnames.insert(2, 'Type')
fieldnames.insert(3, '1CBinomProb0')
fieldnames.insert(3, '1MBinomProb0')

met.writeanydict(pairsdict, pairfile, fieldnames=fieldnames)
print "Pairs in least mutated patients finished"
os.system('say "Pairs in least mutated patients finished"')
# Out:
# Getting normal statistics...
# Finished in  97.2962958813
# Testing among least mutated patients...
# Finished in  298.082042933
# All pairs tested in least mutated patients written to  output/PAAD-ucsc-seg-jl-FDR-pairs-min_cohort.txt
# Pairs in least mutated patients finished
# 0

# %% [markdown]
# # Plot the distribution of p-values.

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
cpvalues = np.array([pairsdict[c]['1CBinomProb0'] for c in pairsdict])
logcp = np.log10(cpvalues)
mpvalues = np.array([pairsdict[c]['1MBinomProb0'] for c in pairsdict])
logmp = np.log10(mpvalues)


plt.figure()
plt.hist(logcp, bins=50)
plt.title("Distribution of " + str(len(logcp)) + " Co-occurring Pairs over " + str(leastPatientThreshold) + "% Least mut. patients", fontsize=20)
plt.xlabel("Log-10 P-values", fontsize=20)
plt.legend(loc='best')
plt.show()

plt.figure()
plt.hist(logmp, bins=50)
plt.title("Distribution of " + str(len(logmp))  + " Mutually Exclusive Pairs over " + str(leastPatientThreshold) + "% Least mut. patients", fontsize=20)
plt.xlabel("Log-10 P-values", fontsize=20)
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Set the cutoff of significant pairs to test over the whole distribution

# %%
cpairPercentile = 1
# Percentile of most significant co-occurring pairs to test

mpairPercentile = 1

# %% [markdown]
# # Visualize the cutoff
# ## Go back and adjust if you'd like!

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
cpvalues = np.array([pairsdict[c]['1CBinomProb0'] for c in pairsdict])
logcp = np.log10(cpvalues)
mpvalues = np.array([pairsdict[c]['1MBinomProb0'] for c in pairsdict])
logmp = np.log10(mpvalues)


cthreshold = stats.scoreatpercentile(cpvalues, cpairPercentile)
mthreshold = stats.scoreatpercentile(mpvalues, mpairPercentile)
print "Top ", cpairPercentile, "percent of cooccurring pairs: ", cthreshold
print "Top ", mpairPercentile, "percent of mutually exclusive pairs : ", mthreshold

# Let's get the top 10 percent of pairs

goodcpairs = [c for c in pairsdict if (pairsdict[c]['1CBinomProb0'] <= cthreshold)]
goodmpairs = [c for c in pairsdict if (pairsdict[c]['1MBinomProb0'] <= mthreshold)]
goodpairs = goodcpairs + goodmpairs
goodgenes = set.union(*(set(goodpair) for goodpair in goodpairs))
print "Now number of mutex pairs to test ", len(goodmpairs)
print "Now number of coocurr pairs to test ", len(goodcpairs)
print "Number of genes ", len(goodgenes)

plt.figure()
plt.hist(logcp, bins=50)
plt.axvline(x= np.log10(cthreshold), label="Top " + str(cpairPercentile) + "%")
plt.title("Distribution of " + str(len(logcp)) + " Co-occurring Pairs over " + str(leastPatientThreshold) + "% Least mut. patients", fontsize=20)
plt.xlabel("Log-10 P-values", fontsize=20)
plt.legend(loc='best')
plt.show()



plt.figure()
plt.hist(logmp, bins=50)
plt.axvline(x= np.log10(mthreshold), label="Top " + str(mpairPercentile) + "%")
plt.title("Distribution of " + str(len(logmp))  + " Mutually Exclusive Pairs over " + str(leastPatientThreshold) + "% Least mut. patients", fontsize=20)
plt.xlabel("Log-10 P-values", fontsize=20)
plt.legend(loc='best')
plt.show()
# Out:
# Top  1 percent of cooccurring pairs:  0.0408278992317
# Top  1 percent of mutually exclusive pairs :  0.335441935541
# Now number of mutex pairs to test  2306
# Now number of coocurr pairs to test  3500
# Number of genes  623

# %% [markdown]
# ### Test new pairs

# %%
print "Getting normal statistics across whole distribution"

new_mpairsdict, new_mgenedict = met.cooccurpairs(numCases, geneToCases, patientToGenes, goodmpairs, compute_mutex=compute_mutex)
new_cpairsdict, new_cgenedict = met.cooccurpairs(numCases, geneToCases, patientToGenes, goodcpairs, compute_mutex=compute_mutex)

print "Testing across the whole distribution"

new_mpairsdict = chi.add_BinomP_cohorts_all_pairs(new_mpairsdict, geneToCases, patientToGenes, c0cohort_dict, c0patients)
new_cpairsdict = chi.add_BinomP_cohorts_all_pairs(new_cpairsdict, geneToCases, patientToGenes, c0cohort_dict, c0patients)

new_pairsdict = new_mpairsdict.copy()
new_pairsdict.update(new_mpairsdict)


print "All tested pairs have been written to ", new_pairfile

fieldnames = (new_pairsdict.values()[0]).keys()
fieldnames.remove('MutationFrequencies')
fieldnames.remove('MutationFrequencyDifference')
fieldnames.remove('MutationFrequencyDifferenceRatio')
fieldnames.remove('CooccurrenceRatio')
fieldnames.remove('Coverage')
fieldnames.remove('SetScore')
fieldnames.remove('AverageOverlapPMN')
fieldnames.remove('CombinedScore')
fieldnames.remove('Concordance')
fieldnames.remove('Somatic')
fieldnames.remove('RoundedLogPCov')
fieldnames.remove('GeneSet')
fieldnames.remove('Type')

fieldnames.insert(2, 'Type')
fieldnames.insert(3, 'AllMBinomProb')
fieldnames.insert(3, 'AllCBinomProb')

met.writeanydict(new_pairsdict, new_pairfile, fieldnames=fieldnames)

os.system('say "whole distribution pairs finished"')
# Out:
# Getting normal statistics across whole distribution
# Testing across the whole distribution
# All tested pairs have been written to  output/PAAD-ucsc-seg-jl-FDR--pairs-min_cohort_filtered.txt
# 0

# %% [markdown]
# ### Plot results

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

cpairs = [c for c in new_cpairsdict]
cpvalues = np.array([new_cpairsdict[c]['AllCBinomProb'] for c in new_cpairsdict])
sig_cpairs, sig_cpvalues, cthreshold = mt.BH(cpairs, cpvalues, Q=cFDRthreshold, use_dependencies=pairs_have_dependencies)

not_sig_cpairs = set(new_cpairsdict.keys()).difference(set(sig_cpairs))

new_sig_c_dict = new_cpairsdict.copy()
for not_sig_cpair in not_sig_cpairs:
    del new_sig_c_dict[not_sig_cpair]

logcp = np.log10(cpvalues)

if len(logcp) > 1:
    plt.figure()
    plt.hist(logcp, bins=50)
    plt.axvline(x=np.log10(cthreshold), label="FDR Threshold", c='r')
    plt.title("Distribution of " + str(len(logcp)) + " Co-occurring Pairs over all", fontsize=20)
    plt.xlabel("Log-10 P-values", fontsize=20)
    plt.legend(loc='best')
    plt.show()
elif len(logcp) == 1:
    print "One tested co-occurring pair with p=", cpvalues[0]


mpairs = [c for c in new_mpairsdict]
mpvalues = np.array([new_mpairsdict[c]['AllMBinomProb'] for c in new_mpairsdict])
sig_mpairs, sig_mpvalues, mthreshold = mt.BH(mpairs, mpvalues, Q=mFDRthreshold, use_dependencies=pairs_have_dependencies)

not_sig_mpairs = set(new_mpairsdict.keys()).difference(set(sig_mpairs))

new_sig_m_dict = new_mpairsdict.copy()
for not_sig_mpair in not_sig_mpairs:
    del new_sig_m_dict[not_sig_mpair]

logmp = np.log10(mpvalues)

if len(logmp) > 1:
    plt.figure()
    plt.hist(logmp, bins=50)
    plt.axvline(x=np.log10(mthreshold), label="FDR Threshold", c='r')
    plt.title("Distribution of " + str(len(logmp)) + " Mutually Exclusive Pairs over all", fontsize=20)
    plt.xlabel("Log-10 P-values", fontsize=20)
    plt.legend(loc='best')
    plt.show()
elif len(logmp) == 1:
    print "One tested mutex pair with p=", mpvalues[0]




print "Number significant mutex", len(new_sig_m_dict)
print "Number significant coocurr", len(new_sig_c_dict)


new_sig_dict = new_sig_m_dict.copy()
new_sig_dict.update(new_sig_c_dict)
# Out:
# Number significant mutex 0
# Number significant coocurr 522

# %% [markdown]
# ## Mutual exclusivity info

# %%
bgbp.write_segment_infos(goodgenes, segment_info_file)



print "*********MUTUAL EXCLUSIVITY INFO**********\n"

print len(new_sig_m_dict), " Mutually exclusive pairs"

mfieldnames = ['Gene0', 'Gene1', 'Gene0Cytobands', 'Gene1Cytobands', 'AllMBinomProb', 
                'AllFreqs', 'AllOverlap', 'AllSize','1MBinomProb0', '1Freqs0', '1Overlap0',
               '1Size0']


gene_m_dict = {}
cyto_m_dict = {}
cyto_pair_m_dict = {}

for pair in new_sig_m_dict:
    if new_sig_m_dict[pair]['Gene0'][-4:] in {'loss', 'gain'}:
        suffix0 = new_sig_m_dict[pair]['Gene0'][-4:]
    else:
        suffix0 = ""

    if new_sig_m_dict[pair]['Gene1'][-4:] in {'loss', 'gain'}:
        suffix1 = new_sig_m_dict[pair]['Gene1'][-4:]
    else:
        suffix1 = ""
    
    
    info0 = bgbp.get_segment_gene_info(new_sig_m_dict[pair]['Gene0'])
    new_sig_m_dict[pair]['Gene0Loc'] = str(info0['Chromosome']) + ':' + str(info0['Start'])
    info1 = bgbp.get_segment_gene_info(new_sig_m_dict[pair]['Gene1'])
    new_sig_m_dict[pair]['Gene1Loc'] = str(info1['Chromosome']) + ':' + str(info1['Start'])
    new_sig_m_dict[pair]['Gene0Cytobands'] = str(info0['Cytobands'])
    new_sig_m_dict[pair]['Gene1Cytobands'] = str(info1['Cytobands'])
    
    
    if new_sig_m_dict[pair]['Gene0'] not in gene_m_dict:
        gene_m_dict[new_sig_m_dict[pair]['Gene0']] = set()
    gene_m_dict[new_sig_m_dict[pair]['Gene0']].add(pair)
    if new_sig_m_dict[pair]['Gene1'] not in gene_m_dict:
        gene_m_dict[new_sig_m_dict[pair]['Gene1']] = set()
    gene_m_dict[new_sig_m_dict[pair]['Gene1']].add(pair)
    
    
    
    if str(info0['Cytobands']) + suffix0 not in cyto_m_dict:
        cyto_m_dict[str(info0['Cytobands']) + suffix0] = set()
    cyto_m_dict[str(info0['Cytobands'])].add(pair)
    if str(info1['Cytobands']) + suffix1 not in cyto_m_dict:
        cyto_m_dict[str(info1['Cytobands']) + suffix1] = set()
    cyto_m_dict[str(info1['Cytobands'])].add(pair)
    
    
    
    cyto_pair = frozenset([str(info0['Cytobands']) + suffix0, str(info1['Cytobands']) + suffix1])
    
    if cyto_pair not in cyto_pair_m_dict:
        cyto_pair_m_dict[cyto_pair] = set()
        
    cyto_pair_m_dict[cyto_pair].add(pair)


if new_sig_m_dict:
    for key in new_sig_m_dict[pair].keys():
        if key not in mfieldnames:
            mfieldnames.append(key)
    

orderedmpairs = sorted(new_sig_m_dict.keys(), key=lambda entry: (new_sig_m_dict[entry]['AllMBinomProb'],))
    
met.writeanydict(new_sig_m_dict, new_mpairfile, fieldnames=mfieldnames, orderedkeys=orderedmpairs)
print "updated with segment info ", new_mpairfile
# !python add_COSMIC.py -ic Gene0 Gene1 -ip $COSMIC_pair_insertion_index -i $new_mpairfile -o $new_mpairfile
print "updated with COSMIC info ", new_mpairfile


# Writing gene infos
    

sorted_genes = sorted(gene_m_dict.items(), key = lambda entry: len(entry[1]), reverse=True)
sorted_cytobands = sorted(cyto_m_dict.items(), key = lambda entry: len(entry[1]), reverse=True)
sorted_cytotuples = sorted(cyto_pair_m_dict.items(), key = lambda entry: len(entry[1]), reverse=True)

print "\n**********SINGLE GENES**********"
print_length = 15
for gene in sorted_genes:
    if len(gene[0]) <= print_length + 4:
        print gene[0], "has", len(gene[1])
    else:
        print gene[0][0:print_length] + gene[0][-4:], "has\t", len(gene[1])

print "\n**********SINGLE CYTOBANDS**********"
for cytoband in sorted_cytobands:
    print cytoband[0], "has", len(cytoband[1])

print "\n**********PAIRED CYTOBANDS**********"
for cytotuple in sorted_cytotuples:
    print  cytotuple[0], "has", len(cytotuple[1])


os.system('say "finished"')
# Out:
# *********MUTUAL EXCLUSIVITY INFO**********
#
# 0  Mutually exclusive pairs
# updated with segment info  output/PAAD-ucsc-seg-jl-FDR--mpairs-min_cohort_filtered.txt
# updated with COSMIC info  output/PAAD-ucsc-seg-jl-FDR--mpairs-min_cohort_filtered.txt
#
# **********SINGLE GENES**********
#
# **********SINGLE CYTOBANDS**********
#
# **********PAIRED CYTOBANDS**********
# 0

# %% [markdown]
# # Draw mutual exclusivity network

# %%
import networkx as nx
import csv

G=nx.Graph()
for pair in new_sig_m_dict:
    pair_type = new_sig_m_dict[pair]['Type']
    
    G.add_edge(tuple(pair)[0], tuple(pair)[1], {"Type": pair_type})

pos = nx.spring_layout(G)
nx.draw(G, pos)

# show graph
plt.show()

graphs = list(nx.connected_component_subgraphs(G))
graphs = sorted(graphs, key = lambda entry: entry.number_of_nodes(), reverse=True)

top_number = 3

for i in range(len(graphs)):
    print "\n***********************"
    print "COMPONENT " + str(i) 
    print "***********************"
    graph = graphs[i]
    print "Number of nodes ", graph.number_of_nodes()
    print "Number of edges ", graph.number_of_edges()
    
    node_items = [g + (graph.degree(g[0]),) for g in nx.degree_centrality(graph).items()]
    node_items = sorted(node_items, key=lambda entry: entry[1], reverse = True)
    

    print "---"
    print "Top", top_number, "nodes by degree centraliy in component", i
    print "Gene: Degree Centrality   Degree"
    for j in range(min(top_number, len(node_items))):
        print node_items[j][0], ":", np.round(node_items[j][1], 2), node_items[j][2]
    
    component_file = network_m_file[:-4] + "_comp" + str(i) + ".txt"
    
    print "---"
    print "Writing nodes to: ", component_file
    with open(component_file, 'w') as csvfile:
        writer = csv.writer(csvfile, delimiter='\t')
        writer.writerow(["Node", "Degreee Centrality", "Degree"])
        for node_item in node_items:
            writer.writerow(node_item)

# %% [markdown]
# ## Co-occurrence info

# %%
bgbp.write_segment_infos(goodgenes, segment_info_file)




print "*********COOCCURRENCE INFO**********\n"

print len(new_sig_c_dict), " Co-occurring pairs"

cfieldnames = ['Gene0', 'Gene1', 'Gene0Cytobands', 'Gene1Cytobands', 'AllCBinomProb', 
               'AllFreqs', 'AllOverlap', 'AllSize','1CBinomProb0', '1Freqs0', '1Overlap0',
               '1Size0']


gene_c_dict = {}
cyto_c_dict = {}
cyto_pair_c_dict = {}

for pair in new_sig_c_dict:
    if new_sig_c_dict[pair]['Gene0'][-4:] in {'loss', 'gain'}:
        suffix0 = new_sig_c_dict[pair]['Gene0'][-4:]
    else:
        suffix0 = ""

    if new_sig_c_dict[pair]['Gene1'][-4:] in {'loss', 'gain'}:
        suffix1 = new_sig_c_dict[pair]['Gene1'][-4:]
    else:
        suffix1 = ""
    
    
    info0 = bgbp.get_segment_gene_info(new_sig_c_dict[pair]['Gene0'])
    new_sig_c_dict[pair]['Gene0Loc'] = str(info0['Chromosome']) + ':' + str(info0['Start'])
    info1 = bgbp.get_segment_gene_info(new_sig_c_dict[pair]['Gene1'])
    new_sig_c_dict[pair]['Gene1Loc'] = str(info1['Chromosome']) + ':' + str(info1['Start'])
    new_sig_c_dict[pair]['Gene0Cytobands'] = str(info0['Cytobands'])
    new_sig_c_dict[pair]['Gene1Cytobands'] = str(info1['Cytobands'])
    
    
    if new_sig_c_dict[pair]['Gene0'] not in gene_c_dict:
        gene_c_dict[new_sig_c_dict[pair]['Gene0']] = set()
    gene_c_dict[new_sig_c_dict[pair]['Gene0']].add(pair)
    if new_sig_c_dict[pair]['Gene1'] not in gene_c_dict:
        gene_c_dict[new_sig_c_dict[pair]['Gene1']] = set()
    gene_c_dict[new_sig_c_dict[pair]['Gene1']].add(pair)
    
    
    
    if str(info0['Cytobands']) + suffix0 not in cyto_c_dict:
        cyto_c_dict[str(info0['Cytobands']) + suffix0] = set()
    cyto_c_dict[str(info0['Cytobands']) + suffix0].add(pair)
    if str(info1['Cytobands']) + suffix1 not in cyto_c_dict:
        cyto_c_dict[str(info1['Cytobands']) + suffix1] = set()
    cyto_c_dict[str(info1['Cytobands']) + suffix1].add(pair)
    
    
    
    cyto_pair = frozenset([str(info0['Cytobands']) + suffix0, str(info1['Cytobands']) + suffix1])
    
    if cyto_pair not in cyto_pair_c_dict:
        cyto_pair_c_dict[cyto_pair] = set()
        
    cyto_pair_c_dict[cyto_pair].add(pair)
    
# Writing to file
if new_sig_c_dict:
    for key in new_sig_c_dict[pair].keys():
        if key not in cfieldnames:
            cfieldnames.append(key)
    
orderedcpairs = sorted(new_sig_c_dict.keys(), key=lambda entry: (new_sig_c_dict[entry]['AllCBinomProb'],))
    
met.writeanydict(new_sig_c_dict, new_cpairfile, fieldnames=cfieldnames, orderedkeys=orderedcpairs)
print "updated with segment info ", new_cpairfile
# !python add_COSMIC.py -ic Gene0 Gene1 -ip $COSMIC_pair_insertion_index -i $new_cpairfile -o $new_cpairfile
print "updated with COSMIC info ", new_cpairfile


# Writing gene infos
    

sorted_genes = sorted(gene_c_dict.items(), key = lambda entry: len(entry[1]), reverse=True)
sorted_cytobands = sorted(cyto_c_dict.items(), key = lambda entry: len(entry[1]), reverse=True)
sorted_cytotuples = sorted(cyto_pair_c_dict.items(), key = lambda entry: len(entry[1]), reverse=True)

print "\n**********SINGLE GENES**********"
print_length = 15
for gene in sorted_genes:
    if len(gene[0]) <= print_length + 4:
        print gene[0], "has", len(gene[1])
    else:
        print gene[0][0:print_length] + gene[0][-4:], "has\t", len(gene[1])

print "\n**********SINGLE CYTOBANDS**********"
for cytoband in sorted_cytobands:
    print cytoband[0], "has", len(cytoband[1])

print "\n**********PAIRED CYTOBANDS**********"
for cytotuple in sorted_cytotuples:
    print  cytotuple[0], "has", len(cytotuple[1])


os.system('say "finished"')
# Out:
# *********COOCCURRENCE INFO**********
#
# 522  Co-occurring pairs
# updated with segment info  output/PAAD-ucsc-seg-jl-FDR--cpairs-min_cohort_filtered.txt
# updated with COSMIC info  output/PAAD-ucsc-seg-jl-FDR--cpairs-min_cohort_filtered.txt
#
# **********SINGLE GENES**********
# RN7SL605Ploss has 36
# ABCA2_C9orf139_loss has	36
# PACRG_CAHM_QKI_loss has	31
# OSTCP1_C6orf99_loss has	29
# PSMB1_TBP_PDCD2loss has 23
# LINC00473_T_PRRloss has	23
# SNORD22loss has 22
# AIG1_ADAT2_RNA5loss has	22
# MIR4465loss has 20
# APOD_LINC00969_loss has	20
# RN7SKP106_NMBR_loss has	20
# FAM230Closs has 19
# PARK2loss has 19
# TMEM181_DYNLT1_loss has	19
# LPP_MIR28_TPRG1loss has	17
# EPM2A_FBXO30_SHloss has	16
# CENPW_MIR588_PRloss has	15
# RPL22L1_EIF5A2_loss has	13
# AFF2_RN7SKP267loss has 12
# CHL1_RN7SL120P_loss has	11
# TPRXL_CHCHD4_TMloss has	11
# IDS_LINC00893_Closs has	11
# BRD2loss has 10
# MIR5004_ZBTB9_Gloss has	10
# C6orf15_PSORS1Closs has	10
# JARID2_DTNBP1_Mloss has	10
# BTBD9_GLO1_DNAHloss has	10
# TCP11_SCUBE3_ZNloss has	10
# ITPR3_MIR3934_Iloss has	10
# MIR1275_GRM4_HMloss has	10
# MICA_HCP5_MICB_loss has	10
# MECOM_TERC_ACTRloss has	10
# TDRG1_LINC00951loss has	10
# HCG24_COL11A2_Rloss has	10
# MIR586loss has 9
# SAMD3_TMEM200A_loss has	9
# RN7SL73Ploss has 9
# UBR2loss has 8
# ID4_MBOAT1loss has 8
# UNC5CL_OARD1_TSloss has	8
# SOX4_RN7SKP240_loss has	8
# CAP2_FAM8A1_NUPloss has	8
# CHRDL1_PAK3_CAPloss has	8
# HDGFL1loss has 8
# CDKAL1loss has 8
# E2F3_RN7SL128Ploss has 8
# RN7SKP56_HINT3_loss has	7
# PRPH2_TBCC_GLTSloss has	7
# SLC29A1_HSP90ABloss has	7
# MIR4642_SUPT3Hloss has 7
# RUNX2_CLIC5_ENPloss has	6
# HCRTR2_GFRAL_HMloss has	6
# GADL1_RNA5SP127loss has	6
# HIST1H2BL_HIST1loss has	6
# NRSN1_DCDC2_KAAloss has	6
# PRIM2_MIR548U_Lloss has	6
# RBMS3loss has 6
# HCG14_TRIM27_RNloss has	5
# SLC25A26_RN7SL4loss has	4
# MGMT_EBF3_MIR42loss has	4
# GABRG3_RNA5SP39loss has	4
# AGTR1_CPB1_CPA3loss has	4
# PTPRG_C3orf14_Floss has	4
# RNA5SP142_SOX14loss has	4
# MAGI1loss has 4
# PLOD2_PLSCR4_PLloss has	4
# RN7SKP46_SHOX2_loss has	4
# LINC00698_SYNPRloss has	4
# KHDRBS2loss has 3
# ACTL7B_ACTL7A_Iloss has	3
# FRMD4Bloss has 3
# FAM83G_GRAP_SNOloss has	3
# KCNQ1DNloss has 3
# KBTBD8_SUCLG2_Floss has	3
# MTRNR2L9loss has 3
# MITF_RN7SL418Ploss has 3
# EPAS1_TMEM247_Rloss has	2
# IGLL1_GUSBP11_Rloss has	2
# XG_GYG2_ARSD_ARloss has	2
# HCCS_ARHGAP6_AMloss has	2
# PLEKHA8P1_ANO6loss has 2
# LINC00877loss has 2
# TPRA1_MCM2_PODXloss has	2
# FAM47A_TMEM47_Floss has	2
# APOO_CXorf58_KLloss has	2
# CXorf57_MIR548Aloss has	2
# EGFL6_RN7SKP20_loss has	2
# FHITloss has 2
# CNTN3loss has 2
# LRRK2_MUC19_CNTloss has	2
# RN7SL294Ploss has 2
# RPGR_OTC_TSPAN7loss has	2
# PRDX4_ACOT9_SATloss has	2
# LSAMPloss has 2
# FKBP1C_LGSN_PTPloss has	2
# FOXP1_MIR1284_Eloss has	2
# DDX53_PTCHD1loss has 2
# GBE1loss has 2
# ATXN3Lloss has 2
# RN7SL815P_LINC0loss has	2
# snoZ40loss has 2
# FAM86DP_MIR1324loss has	2
# TBL1X_GPR143_SHloss has	2
# LINC00971_CADM2loss has	2
# MN1_PITPNB_TTC2loss has	2
# SMARCA2_RN7SL59loss has	2
# IL33_TPD52L3_UHloss has	2
# IGSF11_C3orf30_loss has	2
# LINC00870_RYBP_loss has	2
# FAM138C_FOXD4_Closs has	2
# RN7SL163P_CXADRloss has	2
# GNL3_SNORD69_GLloss has	2
# RN7SKP284_VGLL3loss has	2
# EYSloss has 2
# AGAP1_RN7SL204Ploss has	2
# KBTBD12_RNA5SP1loss has	2
# RNA5SP501_MIR39loss has	2
# MAPK1_RNA5SP493loss has	2
# FAM46A_RNA5SP21loss has	2
# LINC00307_CLDN8loss has	2
# RN7SKP169_SEZ6Lloss has	2
# DBX2_RNA5SP361loss has 1
# IFNA21loss has 1
# DCT_TGDS_GPR180loss has	1
# MED9_RASD1_PEMTloss has 1
# KIF2Bloss has 1
# ITSN1_ATP5O_LINloss has	1
# FOCADloss has 1
# LINC00457loss has 1
# NBEA_MAB21L1_LIloss has	1
# ANKFN1_NOGloss has 1
# HTR1A_RNF180loss has 1
# TYRP1_RN7SL849Ploss has	1
# LIMK2_PIK3IP1_Rloss has	1
# KIF21A_ABCD2loss has 1
# CDC42EP1_LGALS2loss has	1
# HS6ST3loss has 1
# UPF3AP2_USP32P3loss has	1
# KDM6A_CXorf36loss has 1
# RN7SL5Ploss has 1
# OR11H1_POTEH_KCloss has	1
# GRIA1_RN7SL177Ploss has	1
# RNA5SP489_LINC0loss has	1
# TOB2_PHF5A_ACO2loss has	1
# LINC00583_NFIB_loss has	1
# SMIM11loss has 1
# TBX22_FAM46D_BRloss has	1
# MIR603_ARHGAP21loss has	1
# LINC00676_IRS2_loss has	1
# NDUFAF2_SMIM15_loss has	1
# HSPH1_B3GALTLloss has 1
# MIR99A_MIRLET7Closs has	1
# COL4A2_RAB20_CAloss has	1
# TUSC1loss has 1
# RMRPP5_RN7SKP12loss has	1
# RNF43_HSF5_MTMRloss has	1
# ARID2_RN7SL246Ploss has	1
# RN7SL449Ploss has 1
# B9D1_MIR1180_MAloss has	1
# GMDSloss has 1
# DHX40_CLTC_PTRHloss has	1
# GPC6loss has 1
# RN7SKP14loss has 1
# SGSM3loss has 1
# HIVEP1_EDN1_RN7loss has	1
# LINC00395_LINC0loss has	1
# MYOCD_ARHGAP44_loss has	1
# AIPL1_FAM64A_KIloss has	1
# IFNK_C9orf72loss has 1
# CBS_U2AF1_CRYAAloss has 1
# ADAMTS20_PUS7L_loss has	1
# RN7SKP114_DCAF1loss has	1
# MPP7loss has 1
# DNAH9_ZNF18_RPLloss has	1
# PARVB_PARVG_KIAloss has	1
# OFCC1_RNU6ATAC2loss has	1
# KLF12_LINC00402loss has	1
# C17orf47loss has 1
# CAAP1_RN7SL100Ploss has	1
# LINC00333_LINC0loss has	1
# RFC3loss has 1
# TEAD1_LINC00958loss has	1
# IFNB1loss has 1
# TIAM1_SOD1_SCAFloss has	1
# DOC2B_RPH3AL_C1loss has	1
# KIAA1045_DNAJB5loss has	1
# LINC00359_RN7SKloss has	1
# VMP1loss has 1
# RNA5SP94_MIR443loss has	1
# RXFP2_EEF1DP3_Floss has	1
# RN7SKP39_WAC_RNloss has	1
# TEKT4P2_RN7SL52loss has	1
# MIR21loss has 1
# TOM1L1_COX11_STloss has	1
# PROS1_ARL13B_STloss has	1
# KCNMB2_RNA5SP14loss has	1
# ADRBK2_RNA5SP49loss has	1
# UBAP2loss has 1
# DNAH5_TRIO_FAM1loss has	1
# RNA5SP35loss has 1
# IFNA4loss has 1
# LINC00670loss has 1
# ISL1_RNA5SP182_loss has	1
# YWHAE_CRK_MYO1Closs has	1
# C17orf67_DGKE_Tloss has	1
# RN7SL741P_RNY1Ploss has	1
# MKL1loss has 1
# RNA5SP281_ACO1_loss has	1
# ELAVL2loss has 1
# LARGEloss has 1
# VRK2_FANCLloss has 1
# DUSP22_IRF4_EXOloss has	1
# TEX14_RAD51Closs has 1
# MIR3152_RN7SKP2loss has	1
# PDZRN4_RNA5SP36loss has	1
# BET1L_SCGB1C1_Oloss has	1
# MIR4764loss has 1
# MLLT3_MIR4473_Mloss has	1
# TGFBR2loss has 1
# SLC5A10loss has 1
# PPM1E_TRIM37_RNloss has	1
# ISX_HMGXB4_TOM1loss has	1
# LINGO2loss has 1
# SPECC1_CCDC144Closs has	1
# RGS7BP_RN7SL169loss has	1
# SLC35B3_HULCloss has 1
# CYB5D1_CHD3_KCNloss has	1
# IFNW1loss has 1
# C6orf195_MYLK4_loss has	1
# MTMR3_HORMAD2loss has 1
# RN7SL164Ploss has 1
# SGSM1_TMEM211_Kloss has	1
# C9orf92_BNC2_RNloss has	1
# MIR876_MIR873loss has 1
# FAM205CPloss has 1
# EPHA3loss has 1
# SNORD121B_SNORDloss has	1
# MIR744loss has 1
# ZIC5_ZIC2_LINC0loss has	1
# DNAI1_RN7SKP24_loss has	1
# MELKloss has 1
# EPS8L2_TMEM80_Tloss has	1
# SHISA6loss has 1
# LPAR6_RCBTB2_LIloss has	1
# RN7SL352P_FOXC1loss has 1
# ADAMTSL1loss has 1
# LIG4_ABHD13_TNFloss has	1
# PCDH9_LINC00364loss has	1
# SYNGR1_TAB1_MGAloss has	1
# MIR491loss has 1
# TEK_RNA5SP280_Lloss has	1
# RNU6ATAC6P_HTR1loss has	1
# C17orf64_RPL12Ploss has	1
# RNF38loss has 1
# SMCR2_RAI1_SMCRloss has	1
# ATP8A2loss has 1
# PHACTR1_TBC1D7_loss has	1
# RN7SKP94_MRPS23loss has	1
# WSCD1loss has 1
# SKA2_MIR454_MIRloss has	1
# DACH2loss has 1
# ASCC2loss has 1
# KIAA1217loss has 1
# C12orf40_SLC2A1loss has	1
# TUBD1_RPS6KB1_Rloss has	1
# RRAGA_HAUS6_SCAloss has	1
# RN7SKP18_RN7SKPloss has	1
# MSI2loss has 1
# GOPC_DCBLD1_NUSloss has	1
# HLF_MMD_TMEM100loss has	1
# MOB3Bloss has 1
# IZUMO3loss has 1
#
# **********SINGLE CYTOBANDS**********
# ['6p22.3']loss has 58
# ['6q27']loss has 46
# ['6p21.1']loss has 46
# ['9q34.2', '9q34.3']loss has 36
# ['11q12.1']loss has 36
# ['6q26', '6q27']loss has 31
# ['6q25.3', '6q26']loss has 29
# ['3q29']loss has 29
# ['Xq28']loss has 23
# ['11q12.3']loss has 22
# ['6q24.2']loss has 22
# ['6q24.1']loss has 20
# ['6q24.1', '6q24.2']loss has 20
# ['6p21.32']loss has 20
# ['6p21.31']loss has 20
# ['13q11']loss has 19
# ['6q26']loss has 19
# ['6q25.3']loss has 19
# ['3q28', '3q29']loss has 17
# ['6q24.2', '6q24.3', '6q25.1', '6q25.2', '6q25.3']loss has 16
# ['6q22.32', '6q22.33']loss has 15
# ['3p14.1']loss has 14
# ['3q26.2', '3q26.31', '3q26.32']loss has 13
# ['3p25.1']loss has 11
# ['3p26.3', '3p26.2', '3p26.1', '3p25.3', '3p25.2', '3p25.1']loss has 11
# ['6p21.33']loss has 10
# ['6p21.32', '6p21.31']loss has 10
# ['6p21.2', '6p21.1']loss has 10
# ['3q26.2']loss has 10
# ['6p21.2']loss has 10
# ['6p21.33', '6p21.32']loss has 10
# ['12q12']loss has 10
# ['9p21.3']loss has 10
# ['6p21.31', '6p21.2']loss has 10
# ['17p11.2']loss has 9
# ['6q22.33', '6q23.1', '6q23.2', '6q23.3', '6q24.1']loss has 9
# ['17q23.2']loss has 9
# ['Xq23']loss has 8
# ['3p24.1']loss has 7
# ['6q22.31']loss has 7
# ['3p13']loss has 6
# ['6p12.1', '6p11.2']loss has 6
# ['6p22.3', '6p22.2', '6p22.1']loss has 6
# ['3p14.2']loss has 6
# ['3p24.1', '3p23', '3p22.3']loss has 6
# ['3p12.3']loss has 6
# ['6p22.1']loss has 6
# ['6p11.2']loss has 6
# ['6p21.1', '6p12.3', '6p12.2', '6p12.1']loss has 6
# ['17q22']loss has 6
# ['6q11.1']loss has 6
# ['9p21.2']loss has 5
# ['6p22.1', '6p21.33']loss has 5
# ['9p13.3']loss has 5
# ['10q26.2', '10q26.3']loss has 4
# ['3q24', '3q25.1', '3q25.2', '3q25.31', '3q25.32']loss has 4
# ['Xp22.11']loss has 4
# ['3q24']loss has 4
# ['15q12', '15q13.1', '15q13.2', '15q13.3', '15q14', '15q15.1', '15q15.2', '15q15.3', '15q21.1']loss has 4
# ['3p12.1']loss has 4
# ['3q25.32', '3q25.33', '3q26.1', '3q26.2']loss has 4
# ['17p12']loss has 4
# ['3p14.2', '3p14.1']loss has 4
# ['3q13.31']loss has 4
# ['Xp22.2']loss has 4
# ['3q22.3', '3q23', '3q24']loss has 4
# ['10q24.1']loss has 3
# ['22q13.1']loss has 3
# ['22q11.23']loss has 3
# ['3p14.1', '3p13']loss has 3
# ['22q12.3']loss has 3
# ['9q31.2', '9q31.3', '9q32', '9q33.1', '9q33.2', '9q33.3', '9q34.11', '9q34.12', '9q34.13', '9q34.2']loss has 3
# ['21q21.1']loss has 3
# ['6p25.3']loss has 3
# ['Xp22.2', 'Xp22.13', 'Xp22.12', 'Xp22.11']loss has 2
# ['3p12.2']loss has 2
# ['22q12.1']loss has 2
# ['9p23']loss has 2
# ['3p21.1', '3p14.3', '3p14.2']loss has 2
# ['Xp21.1', 'Xp11.4']loss has 2
# ['21q21.3']loss has 2
# ['2q37.1', '2q37.2', '2q37.3']loss has 2
# ['2p21', '2p16.3', '2p16.2']loss has 2
# ['Xp11.4', 'Xp11.3']loss has 2
# ['13q31.3']loss has 2
# ['3p11.1']loss has 2
# ['9p24.1']loss has 2
# ['Xp22.11', 'Xp21.3', 'Xp21.2']loss has 2
# ['3p12.1', '3p11.2']loss has 2
# ['9p13.2']loss has 2
# ['6q12']loss has 2
# ['Xq22.3', 'Xq23']loss has 2
# ['13q32.1']loss has 2
# ['3q21.3']loss has 2
# ['9p22.1']loss has 2
# ['9p24.3', '9p24.2', '9p24.1']loss has 2
# ['22q12.2']loss has 2
# ['22q11.21', '22q11.22']loss has 2
# ['22q12.1', '22q12.2']loss has 2
# ['6q14.1']loss has 2
# ['10p12.1']loss has 2
# ['Xp22.33', 'Xp22.32', 'Xp22.31']loss has 2
# ['3q21.3', '3q22.1', '3q22.2', '3q22.3']loss has 2
# ['3q13.32', '3q13.33', '3q21.1', '3q21.2', '3q21.3']loss has 2
# ['Xp21.1']loss has 2
# ['Xp22.31', 'Xp22.2']loss has 2
# ['6q11.1', '6q11.2', '6q12']loss has 2
# ['9p24.3']loss has 2
# ['17p13.3', '17p13.2']loss has 1
# ['13q32.3', '13q33.1', '13q33.2', '13q33.3']loss has 1
# ['13q12.12', '13q12.13']loss has 1
# ['9p21.1']loss has 1
# ['17p13.2', '17p13.1']loss has 1
# ['21p11.2', '21p11.1', '21q11.1', '21q11.2']loss has 1
# ['9p21.1', '9p13.3']loss has 1
# ['Xq21.1', 'Xq21.2']loss has 1
# ['13q31.1', '13q31.2', '13q31.3']loss has 1
# ['3q11.1', '3q11.2']loss has 1
# ['6p25.2', '6p25.1', '6p24.3']loss has 1
# ['22q13.2', '22q13.31']loss has 1
# ['5q33.2', '5q33.3', '5q34', '5q35.1', '5q35.2']loss has 1
# ['13q13.1']loss has 1
# ['11p15.3', '11p15.2']loss has 1
# ['13q31.3', '13q32.1']loss has 1
# ['2p16.1']loss has 1
# ['9p13.3', '9p13.2']loss has 1
# ['17q22', '17q23.1']loss has 1
# ['10p12.2', '10p12.1']loss has 1
# ['9p23', '9p22.3']loss has 1
# ['6q22.1', '6q22.2', '6q22.31']loss has 1
# ['6p24.1', '6p23']loss has 1
# ['13q21.32', '13q21.33', '13q22.1']loss has 1
# ['10p12.2']loss has 1
# ['6p24.3', '6p24.2', '6p24.1']loss has 1
# ['9p21.2', '9p21.1']loss has 1
# ['22q12.2', '22q12.3']loss has 1
# ['11p15.5']loss has 1
# ['13q13.2', '13q13.3', '13q14.11', '13q14.12', '13q14.13', '13q14.2']loss has 1
# ['9p22.2', '9p22.1']loss has 1
# ['17q23.1']loss has 1
# ['17q23.1', '17q23.2']loss has 1
# ['21q21.3', '21q22.11']loss has 1
# ['6q22.1']loss has 1
# ['13q12.3', '13q13.1']loss has 1
# ['5q12.3']loss has 1
# ['5q12.1']loss has 1
# ['13q21.31', '13q21.32']loss has 1
# ['6p24.1']loss has 1
# ['13q33.3']loss has 1
# ['13q33.3', '13q34']loss has 1
# ['21q21.2', '21q21.3']loss has 1
# ['13q34']loss has 1
# ['21p11.2']loss has 1
# ['22q11.23', '22q12.1']loss has 1
# ['9p22.3', '9p22.2']loss has 1
# ['17p13.1', '17p12']loss has 1
# ['13q32.1', '13q32.2', '13q32.3']loss has 1
# ['13q22.1', '13q22.2', '13q22.3', '13q31.1']loss has 1
# ['2p16.1', '2p15', '2p14', '2p13.3', '2p13.2', '2p13.1', '2p12']loss has 1
# ['22q11.1', '22q11.21']loss has 1
# ['13q14.2', '13q14.3', '13q21.1', '13q21.2', '13q21.31']loss has 1
# ['17q23.2', '17q23.3']loss has 1
# ['5p15.2', '5p15.1', '5p14.3']loss has 1
# ['17p13.3']loss has 1
# ['21p12']loss has 1
# ['17p12', '17p11.2']loss has 1
# ['22q12.3', '22q13.1']loss has 1
# ['11p15.5', '11p15.4', '11p15.3']loss has 1
# ['6p24.3']loss has 1
# ['13q12.13', '13q12.2', '13q12.3']loss has 1
# ['17p13.2']loss has 1
# ['3q26.32', '3q26.33', '3q27.1', '3q27.2', '3q27.3']loss has 1
# ['5q11.2', '5q12.1']loss has 1
# ['Xp11.3']loss has 1
# ['Xq21.2', 'Xq21.31']loss has 1
# ['21q22.11', '21q22.12', '21q22.13', '21q22.2', '21q22.3']loss has 1
# ['22q13.2']loss has 1
# ['13q13.2']loss has 1
# ['5q12.3', '5q13.1', '5q13.2', '5q13.3']loss has 1
# ['13q12.3']loss has 1
#
# **********PAIRED CYTOBANDS**********
# frozenset(["['6q27']loss", "['6p21.1']loss"]) has 12
# frozenset(["['9p21.3']loss", "['9q34.2', '9q34.3']loss"]) has 10
# frozenset(["['17q23.2']loss", "['11q12.1']loss"]) has 9
# frozenset(["['12q12']loss", "['Xq23']loss"]) has 8
# frozenset(["['6p22.3']loss", "['6q24.1', '6q24.2']loss"]) has 7
# frozenset(["['6p22.3']loss", "['6q22.31']loss"]) has 7
# frozenset(["['6p22.3']loss", "['6q25.3', '6q26']loss"]) has 7
# frozenset(["['6q26', '6q27']loss", "['6p22.3']loss"]) has 7
# frozenset(["['6p22.3']loss", "['6q22.32', '6q22.33']loss"]) has 7
# frozenset(["['6p22.3']loss", "['6q24.1']loss"]) has 7
# frozenset(["['6p22.3']loss", "['6q22.33', '6q23.1', '6q23.2', '6q23.3', '6q24.1']loss"]) has 7
# frozenset(["['6p22.3']loss", "['6q24.2']loss"]) has 7
# frozenset(["['11q12.1']loss", "['17p11.2']loss"]) has 7
# frozenset(["['6q25.3', '6q26']loss", "['6p21.1']loss"]) has 6
# frozenset(["['6q26', '6q27']loss", "['6p21.1']loss"]) has 6
# frozenset(["['6q24.2', '6q24.3', '6q25.1', '6q25.2', '6q25.3']loss", "['6p21.1']loss"]) has 6
# frozenset(["['17q22']loss", "['11q12.1']loss"]) has 6
# frozenset(["['6q25.3']loss", "['6p21.1']loss"]) has 6
# frozenset(["['6q26']loss", "['6p21.1']loss"]) has 6
# frozenset(["['9p21.2']loss", "['9q34.2', '9q34.3']loss"]) has 5
# frozenset(["['9p13.3']loss", "['9q34.2', '9q34.3']loss"]) has 5
# frozenset(["['Xp22.11']loss", "['Xq28']loss"]) has 4
# frozenset(["['3q28', '3q29']loss", "['3p14.1']loss"]) has 4
# frozenset(["['3q26.2', '3q26.31', '3q26.32']loss", "['3p14.1']loss"]) has 4
# frozenset(["['6q27']loss", "['6p21.31']loss"]) has 4
# frozenset(["['6q27']loss", "['6p21.32']loss"]) has 4
# frozenset(["['11q12.1']loss", "['17p12']loss"]) has 4
# frozenset(["['Xp22.2']loss", "['Xq28']loss"]) has 4
# frozenset(["['6q27']loss", "['6q11.1']loss"]) has 4
# frozenset(["['3p14.1']loss", "['3q29']loss"]) has 4
# frozenset(["['3p13']loss", "['3q29']loss"]) has 3
# frozenset(["['6p25.3']loss", "['6q22.32', '6q22.33']loss"]) has 3
# frozenset(["['3p12.3']loss", "['3q29']loss"]) has 3
# frozenset(["['3p12.3']loss", "['3q28', '3q29']loss"]) has 3
# frozenset(["['3q28', '3q29']loss", "['3p13']loss"]) has 3
# frozenset(["['22q13.1']loss", "['13q11']loss"]) has 3
# frozenset(["['13q11']loss", "['22q12.3']loss"]) has 3
# frozenset(["['6q27']loss", "['6q11.1', '6q11.2', '6q12']loss"]) has 2
# frozenset(["['9p23']loss", "['9q34.2', '9q34.3']loss"]) has 2
# frozenset(["['6p21.31', '6p21.2']loss", "['6q27']loss"]) has 2
# frozenset(["['6p21.32']loss", "['6q24.2', '6q24.3', '6q25.1', '6q25.2', '6q25.3']loss"]) has 2
# frozenset(["['6q26']loss", "['6p21.31']loss"]) has 2
# frozenset(["['3q28', '3q29']loss", "['3p12.1']loss"]) has 2
# frozenset(["['6q27']loss", "['6q12']loss"]) has 2
# frozenset(["['6q27']loss", "['6p21.2']loss"]) has 2
# frozenset(["['6p21.31']loss", "['6q24.1', '6q24.2']loss"]) has 2
# frozenset(["['3p25.1']loss", "['3q13.31']loss"]) has 2
# frozenset(["['6p21.31']loss", "['6q24.2', '6q24.3', '6q25.1', '6q25.2', '6q25.3']loss"]) has 2
# frozenset(["['6q26', '6q27']loss", "['6p21.32']loss"]) has 2
# frozenset(["['6q26', '6q27']loss", "['6q11.1']loss"]) has 2
# frozenset(["['6q25.3']loss", "['6p21.31']loss"]) has 2
# frozenset(["['Xq28']loss", "['Xp21.1']loss"]) has 2
# frozenset(["['6q27']loss", "['6p21.32', '6p21.31']loss"]) has 2
# frozenset(["['Xp22.33', 'Xp22.32', 'Xp22.31']loss", "['Xq28']loss"]) has 2
# frozenset(["['12q12']loss", "['Xq22.3', 'Xq23']loss"]) has 2
# frozenset(["['Xp22.2', 'Xp22.13', 'Xp22.12', 'Xp22.11']loss", "['Xq28']loss"]) has 2
# frozenset(["['3q26.2']loss", "['3p14.2']loss"]) has 2
# frozenset(["['22q12.2']loss", "['13q11']loss"]) has 2
# frozenset(["['Xq28']loss", "['Xp21.1', 'Xp11.4']loss"]) has 2
# frozenset(["['13q32.1']loss", "['11q12.3']loss"]) has 2
# frozenset(["['9q34.2', '9q34.3']loss", "['9p22.1']loss"]) has 2
# frozenset(["['3p26.3', '3p26.2', '3p26.1', '3p25.3', '3p25.2', '3p25.1']loss", "['3q13.31']loss"]) has 2
# frozenset(["['21q21.1']loss", "['3q29']loss"]) has 2
# frozenset(["['6q27']loss", "['6p21.33', '6p21.32']loss"]) has 2
# frozenset(["['6q24.2']loss", "['6p21.1']loss"]) has 2
# frozenset(["['6q27']loss", "['6p21.33']loss"]) has 2
# frozenset(["['6p12.1', '6p11.2']loss", "['6q27']loss"]) has 2
# frozenset(["['6p21.31']loss", "['6q24.2']loss"]) has 2
# frozenset(["['6p21.31']loss", "['6q25.3', '6q26']loss"]) has 2
# frozenset(["['Xq28']loss", "['Xp22.31', 'Xp22.2']loss"]) has 2
# frozenset(["['10p12.1']loss", "['10q26.2', '10q26.3']loss"]) has 2
# frozenset(["['6p21.32']loss", "['6q24.2']loss"]) has 2
# frozenset(["['6q27']loss", "['6p21.2', '6p21.1']loss"]) has 2
# frozenset(["['Xp11.4', 'Xp11.3']loss", "['Xq28']loss"]) has 2
# frozenset(["['3q29']loss", "['3p11.1']loss"]) has 2
# frozenset(["['6q25.3']loss", "['6p21.32']loss"]) has 2
# frozenset(["['6p21.31']loss", "['6q24.1']loss"]) has 2
# frozenset(["['6q26', '6q27']loss", "['6p21.31']loss"]) has 2
# frozenset(["['3q26.2', '3q26.31', '3q26.32']loss", "['3p14.2']loss"]) has 2
# frozenset(["['6q27']loss", "['6p21.1', '6p12.3', '6p12.2', '6p12.1']loss"]) has 2
# frozenset(["['6q26']loss", "['6p21.32']loss"]) has 2
# frozenset(["['Xq28']loss", "['Xp22.11', 'Xp21.3', 'Xp21.2']loss"]) has 2
# frozenset(["['9p13.2']loss", "['9q34.2', '9q34.3']loss"]) has 2
# frozenset(["['6q27']loss", "['6p11.2']loss"]) has 2
# frozenset(["['6p21.32']loss", "['6q24.1', '6q24.2']loss"]) has 2
# frozenset(["['13q31.3']loss", "['11q12.3']loss"]) has 2
# frozenset(["['13q11']loss", "['22q11.23']loss"]) has 2
# frozenset(["['3p12.1']loss", "['3q29']loss"]) has 2
# frozenset(["['6p21.32']loss", "['6q25.3', '6q26']loss"]) has 2
# frozenset(["['6p21.32']loss", "['6q24.1']loss"]) has 2
# frozenset(["['3q26.2']loss", "['3p14.1']loss"]) has 2
# frozenset(["['21q21.3', '21q22.11']loss", "['3q29']loss"]) has 1
# frozenset(["['6p21.33', '6p21.32']loss", "['6q24.1', '6q24.2']loss"]) has 1
# frozenset(["['3p24.1']loss", "['3q24', '3q25.1', '3q25.2', '3q25.31', '3q25.32']loss"]) has 1
# frozenset(["['6p22.1']loss", "['6q22.33', '6q23.1', '6q23.2', '6q23.3', '6q24.1']loss"]) has 1
# frozenset(["['6q25.3']loss", "['6p21.2', '6p21.1']loss"]) has 1
# frozenset(["['17q22', '17q23.1']loss", "['11q12.1']loss"]) has 1
# frozenset(["['3q24', '3q25.1', '3q25.2', '3q25.31', '3q25.32']loss", "['3p26.3', '3p26.2', '3p26.1', '3p25.3', '3p25.2', '3p25.1']loss"]) has 1
# frozenset(["['6p21.2', '6p21.1']loss", "['6q24.1']loss"]) has 1
# frozenset(["['6q22.1', '6q22.2', '6q22.31']loss", "['6p22.3']loss"]) has 1
# frozenset(["['6p21.31', '6p21.2']loss", "['6q24.1']loss"]) has 1
# frozenset(["['6p22.1', '6p21.33']loss", "['6q24.1']loss"]) has 1
# frozenset(["['5p15.2', '5p15.1', '5p14.3']loss", "['5q33.2', '5q33.3', '5q34', '5q35.1', '5q35.2']loss"]) has 1
# frozenset(["['6p21.2']loss", "['6q24.1']loss"]) has 1
# frozenset(["['6p21.2']loss", "['6q25.3', '6q26']loss"]) has 1
# frozenset(["['6p22.1']loss", "['6q24.1']loss"]) has 1
# frozenset(["['3q13.32', '3q13.33', '3q21.1', '3q21.2', '3q21.3']loss", "['3p25.1']loss"]) has 1
# frozenset(["['9p24.3']loss", "['9q31.2', '9q31.3', '9q32', '9q33.1', '9q33.2', '9q33.3', '9q34.11', '9q34.12', '9q34.13', '9q34.2']loss"]) has 1
# frozenset(["['13q33.3', '13q34']loss", "['11q12.3']loss"]) has 1
# frozenset(["['22q11.1', '22q11.21']loss", "['13q11']loss"]) has 1
# frozenset(["['9p21.1']loss", "['9q34.2', '9q34.3']loss"]) has 1
# frozenset(["['3q29']loss", "['3p14.1', '3p13']loss"]) has 1
# frozenset(["['6p21.2']loss", "['6q24.1', '6q24.2']loss"]) has 1
# frozenset(["['3q29']loss", "['21q22.11', '21q22.12', '21q22.13', '21q22.2', '21q22.3']loss"]) has 1
# frozenset(["['6p21.31', '6p21.2']loss", "['6q24.2']loss"]) has 1
# frozenset(["['6q24.2']loss", "['6p21.2', '6p21.1']loss"]) has 1
# frozenset(["['13q21.32', '13q21.33', '13q22.1']loss", "['11q12.3']loss"]) has 1
# frozenset(["['3q13.32', '3q13.33', '3q21.1', '3q21.2', '3q21.3']loss", "['3p26.3', '3p26.2', '3p26.1', '3p25.3', '3p25.2', '3p25.1']loss"]) has 1
# frozenset(["['9p24.3']loss", "['9q34.2', '9q34.3']loss"]) has 1
# frozenset(["['6p21.31', '6p21.2']loss", "['6q24.2', '6q24.3', '6q25.1', '6q25.2', '6q25.3']loss"]) has 1
# frozenset(["['15q12', '15q13.1', '15q13.2', '15q13.3', '15q14', '15q15.1', '15q15.2', '15q15.3', '15q21.1']loss", "['5q12.3', '5q13.1', '5q13.2', '5q13.3']loss"]) has 1
# frozenset(["['3q24']loss", "['3p26.3', '3p26.2', '3p26.1', '3p25.3', '3p25.2', '3p25.1']loss"]) has 1
# frozenset(["['3q11.1', '3q11.2']loss", "['3q29']loss"]) has 1
# frozenset(["['3q26.2', '3q26.31', '3q26.32']loss", "['3p24.1', '3p23', '3p22.3']loss"]) has 1
# frozenset(["['6q26']loss", "['6p21.2', '6p21.1']loss"]) has 1
# frozenset(["['6q22.32', '6q22.33']loss", "['6p24.3', '6p24.2', '6p24.1']loss"]) has 1
# frozenset(["['3p25.1']loss", "['3q21.3', '3q22.1', '3q22.2', '3q22.3']loss"]) has 1
# frozenset(["['3p24.1']loss", "['3q25.32', '3q25.33', '3q26.1', '3q26.2']loss"]) has 1
# frozenset(["['6q24.2', '6q24.3', '6q25.1', '6q25.2', '6q25.3']loss", "['6p21.33', '6p21.32']loss"]) has 1
# frozenset(["['6q26', '6q27']loss", "['6p21.33']loss"]) has 1
# frozenset(["['6q24.2', '6q24.3', '6q25.1', '6q25.2', '6q25.3']loss", "['6p21.32', '6p21.31']loss"]) has 1
# frozenset(["['17p13.3', '17p13.2']loss", "['11q12.1']loss"]) has 1
# frozenset(["['6p22.1', '6p21.33']loss", "['6q24.1', '6q24.2']loss"]) has 1
# frozenset(["['13q11']loss", "['22q12.3', '22q13.1']loss"]) has 1
# frozenset(["['3p25.1']loss", "['3q25.32', '3q25.33', '3q26.1', '3q26.2']loss"]) has 1
# frozenset(["['13q14.2', '13q14.3', '13q21.1', '13q21.2', '13q21.31']loss", "['11q12.3']loss"]) has 1
# frozenset(["['6q24.2', '6q24.3', '6q25.1', '6q25.2', '6q25.3']loss", "['6p21.2', '6p21.1']loss"]) has 1
# frozenset(["['6p21.31', '6p21.2']loss", "['6q25.3']loss"]) has 1
# frozenset(["['10p12.2', '10p12.1']loss", "['10q26.2', '10q26.3']loss"]) has 1
# frozenset(["['3q26.2']loss", "['3p25.1']loss"]) has 1
# frozenset(["['6q26', '6q27']loss", "['6p21.1', '6p12.3', '6p12.2', '6p12.1']loss"]) has 1
# frozenset(["['17q23.2', '17q23.3']loss", "['11q12.1']loss"]) has 1
# frozenset(["['6p21.33']loss", "['6q25.3', '6q26']loss"]) has 1
# frozenset(["['3q26.2', '3q26.31', '3q26.32']loss", "['3p25.1']loss"]) has 1
# frozenset(["['6p21.32', '6p21.31']loss", "['6q24.1', '6q24.2']loss"]) has 1
# frozenset(["['5q12.3']loss", "['15q12', '15q13.1', '15q13.2', '15q13.3', '15q14', '15q15.1', '15q15.2', '15q15.3', '15q21.1']loss"]) has 1
# frozenset(["['3p26.3', '3p26.2', '3p26.1', '3p25.3', '3p25.2', '3p25.1']loss", "['3q21.3']loss"]) has 1
# frozenset(["['13q22.1', '13q22.2', '13q22.3', '13q31.1']loss", "['11q12.3']loss"]) has 1
# frozenset(["['6q26']loss", "['6p21.33']loss"]) has 1
# frozenset(["['17p13.1', '17p12']loss", "['11q12.1']loss"]) has 1
# frozenset(["['6q25.3']loss", "['6p21.33', '6p21.32']loss"]) has 1
# frozenset(["['5q11.2', '5q12.1']loss", "['15q12', '15q13.1', '15q13.2', '15q13.3', '15q14', '15q15.1', '15q15.2', '15q15.3', '15q21.1']loss"]) has 1
# frozenset(["['3q28', '3q29']loss", "['3p14.2', '3p14.1']loss"]) has 1
# frozenset(["['6q25.3']loss", "['6p21.2']loss"]) has 1
# frozenset(["['13q21.31', '13q21.32']loss", "['11q12.3']loss"]) has 1
# frozenset(["['6q26']loss", "['6p21.1', '6p12.3', '6p12.2', '6p12.1']loss"]) has 1
# frozenset(["['3q26.2']loss", "['3p14.2', '3p14.1']loss"]) has 1
# frozenset(["['13q12.3', '13q13.1']loss", "['11q12.3']loss"]) has 1
# frozenset(["['13q31.1', '13q31.2', '13q31.3']loss", "['11q12.3']loss"]) has 1
# frozenset(["['13q32.3', '13q33.1', '13q33.2', '13q33.3']loss", "['11q12.3']loss"]) has 1
# frozenset(["['6q25.3']loss", "['6p12.1', '6p11.2']loss"]) has 1
# frozenset(["['6q26']loss", "['6p21.32', '6p21.31']loss"]) has 1
# frozenset(["['13q11']loss", "['22q12.1']loss"]) has 1
# frozenset(["['6q26', '6q27']loss", "['6p12.1', '6p11.2']loss"]) has 1
# frozenset(["['6q25.3']loss", "['6p21.1', '6p12.3', '6p12.2', '6p12.1']loss"]) has 1
# frozenset(["['3q29']loss", "['21p11.2', '21p11.1', '21q11.1', '21q11.2']loss"]) has 1
# frozenset(["['21p12']loss", "['3q29']loss"]) has 1
# frozenset(["['3q26.2', '3q26.31', '3q26.32']loss", "['3p14.2', '3p14.1']loss"]) has 1
# frozenset(["['6q25.3']loss", "['6p11.2']loss"]) has 1
# frozenset(["['3p26.3', '3p26.2', '3p26.1', '3p25.3', '3p25.2', '3p25.1']loss", "['3q25.32', '3q25.33', '3q26.1', '3q26.2']loss"]) has 1
# frozenset(["['22q12.2', '22q12.3']loss", "['13q11']loss"]) has 1
# frozenset(["['6p22.1']loss", "['6q26', '6q27']loss"]) has 1
# frozenset(["['6q24.2']loss", "['6p22.3', '6p22.2', '6p22.1']loss"]) has 1
# frozenset(["['21q21.3']loss", "['3q29']loss"]) has 1
# frozenset(["['6q24.2']loss", "['6p21.2']loss"]) has 1
# frozenset(["['17p12', '17p11.2']loss", "['11q12.1']loss"]) has 1
# frozenset(["['3q26.2']loss", "['3p26.3', '3p26.2', '3p26.1', '3p25.3', '3p25.2', '3p25.1']loss"]) has 1
# frozenset(["['13q13.2', '13q13.3', '13q14.11', '13q14.12', '13q14.13', '13q14.2']loss", "['11q12.3']loss"]) has 1
# frozenset(["['3q24', '3q25.1', '3q25.2', '3q25.31', '3q25.32']loss", "['3p25.1']loss"]) has 1
# frozenset(["['3q29']loss", "['21p11.2']loss"]) has 1
# frozenset(["['10q24.1']loss", "['11p15.5']loss"]) has 1
# frozenset(["['6q26']loss", "['6p21.2']loss"]) has 1
# frozenset(["['9q31.2', '9q31.3', '9q32', '9q33.1', '9q33.2', '9q33.3', '9q34.11', '9q34.12', '9q34.13', '9q34.2']loss", "['9p24.1']loss"]) has 1
# frozenset(["['6p22.1', '6p21.33']loss", "['6q25.3', '6q26']loss"]) has 1
# frozenset(["['6p22.3', '6p22.2', '6p22.1']loss", "['6q24.1', '6q24.2']loss"]) has 1
# frozenset(["['3p24.1']loss", "['3q22.3', '3q23', '3q24']loss"]) has 1
# frozenset(["['6q25.3', '6q26']loss", "['6p22.3', '6p22.2', '6p22.1']loss"]) has 1
# frozenset(["['3p24.1']loss", "['3q26.32', '3q26.33', '3q27.1', '3q27.2', '3q27.3']loss"]) has 1
# frozenset(["['6q25.3']loss", "['6p21.32', '6p21.31']loss"]) has 1
# frozenset(["['13q12.3']loss", "['11q12.3']loss"]) has 1
# frozenset(["['6q26', '6q27']loss", "['6p11.2']loss"]) has 1
# frozenset(["['13q11']loss", "['22q11.21', '22q11.22']loss"]) has 1
# frozenset(["['2p16.1']loss", "['2q37.1', '2q37.2', '2q37.3']loss"]) has 1
# frozenset(["['6p21.32', '6p21.31']loss", "['6q25.3', '6q26']loss"]) has 1
# frozenset(["['6p21.31', '6p21.2']loss", "['6q24.1', '6q24.2']loss"]) has 1
# frozenset(["['22q12.1', '22q12.2']loss", "['6q14.1']loss"]) has 1
# frozenset(["['6q26', '6q27']loss", "['6p21.33', '6p21.32']loss"]) has 1
# frozenset(["['6q22.32', '6q22.33']loss", "['6p24.1']loss"]) has 1
# frozenset(["['9p24.3', '9p24.2', '9p24.1']loss", "['9q34.2', '9q34.3']loss"]) has 1
# frozenset(["['6p21.1', '6p12.3', '6p12.2', '6p12.1']loss", "['6q25.3', '6q26']loss"]) has 1
# frozenset(["['6q26']loss", "['6p21.33', '6p21.32']loss"]) has 1
# frozenset(["['3q29']loss", "['3p14.2']loss"]) has 1
# frozenset(["['17p13.3']loss", "['11q12.1']loss"]) has 1
# frozenset(["['22q12.1', '22q12.2']loss", "['13q11']loss"]) has 1
# frozenset(["['Xp11.3']loss", "['Xq28']loss"]) has 1
# frozenset(["['6p12.1', '6p11.2']loss", "['6q25.3', '6q26']loss"]) has 1
# frozenset(["['21q21.1']loss", "['17p11.2']loss"]) has 1
# frozenset(["['17p13.2']loss", "['11q12.1']loss"]) has 1
# frozenset(["['3q29']loss", "['3p14.2', '3p14.1']loss"]) has 1
# frozenset(["['6q24.2']loss", "['6p21.32', '6p21.31']loss"]) has 1
# frozenset(["['2p21', '2p16.3', '2p16.2']loss", "['Xq21.2', 'Xq21.31']loss"]) has 1
# frozenset(["['6q26', '6q27']loss", "['6p21.2', '6p21.1']loss"]) has 1
# frozenset(["['21q21.3']loss", "['17p11.2']loss"]) has 1
# frozenset(["['6p22.1']loss", "['6q24.2']loss"]) has 1
# frozenset(["['22q11.23']loss", "['6p21.1']loss"]) has 1
# frozenset(["['3p26.3', '3p26.2', '3p26.1', '3p25.3', '3p25.2', '3p25.1']loss", "['3q21.3', '3q22.1', '3q22.2', '3q22.3']loss"]) has 1
# frozenset(["['9q34.2', '9q34.3']loss", "['9p13.3', '9p13.2']loss"]) has 1
# frozenset(["['3q28', '3q29']loss", "['3p14.1', '3p13']loss"]) has 1
# frozenset(["['13q12.13', '13q12.2', '13q12.3']loss", "['11q12.3']loss"]) has 1
# frozenset(["['3p24.1', '3p23', '3p22.3']loss", "['3q22.3', '3q23', '3q24']loss"]) has 1
# frozenset(["['21q21.2', '21q21.3']loss", "['3q29']loss"]) has 1
# frozenset(["['6q24.2', '6q24.3', '6q25.1', '6q25.2', '6q25.3']loss", "['6p21.33']loss"]) has 1
# frozenset(["['3q26.2', '3q26.31', '3q26.32']loss", "['3p24.1']loss"]) has 1
# frozenset(["['9q34.2', '9q34.3']loss", "['9p23', '9p22.3']loss"]) has 1
# frozenset(["['3q26.2', '3q26.31', '3q26.32']loss", "['3p14.1', '3p13']loss"]) has 1
# frozenset(["['11q12.1']loss", "['17q23.1', '17q23.2']loss"]) has 1
# frozenset(["['17p13.2', '17p13.1']loss", "['11q12.1']loss"]) has 1
# frozenset(["['22q11.23', '22q12.1']loss", "['13q11']loss"]) has 1
# frozenset(["['6p21.33', '6p21.32']loss", "['6q24.1']loss"]) has 1
# frozenset(["['3p26.3', '3p26.2', '3p26.1', '3p25.3', '3p25.2', '3p25.1']loss", "['3q22.3', '3q23', '3q24']loss"]) has 1
# frozenset(["['3q24', '3q25.1', '3q25.2', '3q25.31', '3q25.32']loss", "['3p24.1', '3p23', '3p22.3']loss"]) has 1
# frozenset(["['3q21.3']loss", "['3p25.1']loss"]) has 1
# frozenset(["['3p24.1']loss", "['3q24']loss"]) has 1
# frozenset(["['22q11.21', '22q11.22']loss", "['6p21.1']loss"]) has 1
# frozenset(["['13q33.3']loss", "['11q12.3']loss"]) has 1
# frozenset(["['6p21.2', '6p21.1']loss", "['6q24.1', '6q24.2']loss"]) has 1
# frozenset(["['6p21.31', '6p21.2']loss", "['6q26', '6q27']loss"]) has 1
# frozenset(["['9q34.2', '9q34.3']loss", "['9p21.2', '9p21.1']loss"]) has 1
# frozenset(["['3p12.1', '3p11.2']loss", "['3q29']loss"]) has 1
# frozenset(["['17q23.1']loss", "['11q12.1']loss"]) has 1
# frozenset(["['6q25.3']loss", "['6p21.33']loss"]) has 1
# frozenset(["['3q28', '3q29']loss", "['3p12.1', '3p11.2']loss"]) has 1
# frozenset(["['10q24.1']loss", "['11p15.5', '11p15.4', '11p15.3']loss"]) has 1
# frozenset(["['3p12.2']loss", "['3q29']loss"]) has 1
# frozenset(["['22q13.2', '22q13.31']loss", "['13q11']loss"]) has 1
# frozenset(["['9q34.2', '9q34.3']loss", "['9p22.3', '9p22.2']loss"]) has 1
# frozenset(["['3q24']loss", "['3p25.1']loss"]) has 1
# frozenset(["['9p21.1', '9p13.3']loss", "['9q34.2', '9q34.3']loss"]) has 1
# frozenset(["['13q31.3', '13q32.1']loss", "['11q12.3']loss"]) has 1
# frozenset(["['10p12.2']loss", "['10q26.2', '10q26.3']loss"]) has 1
# frozenset(["['9q31.2', '9q31.3', '9q32', '9q33.1', '9q33.2', '9q33.3', '9q34.11', '9q34.12', '9q34.13', '9q34.2']loss", "['9p24.3', '9p24.2', '9p24.1']loss"]) has 1
# frozenset(["['6q26', '6q27']loss", "['6p21.32', '6p21.31']loss"]) has 1
# frozenset(["['3q26.2', '3q26.31', '3q26.32']loss", "['3p21.1', '3p14.3', '3p14.2']loss"]) has 1
# frozenset(["['6q22.32', '6q22.33']loss", "['6p24.1', '6p23']loss"]) has 1
# frozenset(["['6p22.1', '6p21.33']loss", "['6q26', '6q27']loss"]) has 1
# frozenset(["['6p21.31', '6p21.2']loss", "['6q26']loss"]) has 1
# frozenset(["['6q24.2', '6q24.3', '6q25.1', '6q25.2', '6q25.3']loss", "['6p21.2']loss"]) has 1
# frozenset(["['2p16.1', '2p15', '2p14', '2p13.3', '2p13.2', '2p13.1', '2p12']loss", "['2q37.1', '2q37.2', '2q37.3']loss"]) has 1
# frozenset(["['6p22.1', '6p21.33']loss", "['6q24.2']loss"]) has 1
# frozenset(["['6p22.1']loss", "['6q24.1', '6q24.2']loss"]) has 1
# frozenset(["['6q25.3', '6q26']loss", "['6p21.2', '6p21.1']loss"]) has 1
# frozenset(["['6p21.33']loss", "['6q24.1', '6q24.2']loss"]) has 1
# frozenset(["['6q26', '6q27']loss", "['6p22.3', '6p22.2', '6p22.1']loss"]) has 1
# frozenset(["['22q13.2']loss", "['13q11']loss"]) has 1
# frozenset(["['3q26.2']loss", "['3p24.1', '3p23', '3p22.3']loss"]) has 1
# frozenset(["['6q25.3', '6q26']loss", "['6p11.2']loss"]) has 1
# frozenset(["['6q14.1']loss", "['22q12.1']loss"]) has 1
# frozenset(["['6q26']loss", "['6p11.2']loss"]) has 1
# frozenset(["['3q24']loss", "['3p24.1', '3p23', '3p22.3']loss"]) has 1
# frozenset(["['13q34']loss", "['11q12.3']loss"]) has 1
# frozenset(["['6p22.3', '6p22.2', '6p22.1']loss", "['6q24.1']loss"]) has 1
# frozenset(["['6p24.3']loss", "['6q22.32', '6q22.33']loss"]) has 1
# frozenset(["['6p22.1']loss", "['6q25.3', '6q26']loss"]) has 1
# frozenset(["['6q26']loss", "['6p12.1', '6p11.2']loss"]) has 1
# frozenset(["['13q13.1']loss", "['11q12.3']loss"]) has 1
# frozenset(["['13q12.12', '13q12.13']loss", "['11q12.3']loss"]) has 1
# frozenset(["['Xq21.1', 'Xq21.2']loss", "['2p21', '2p16.3', '2p16.2']loss"]) has 1
# frozenset(["['6p21.32', '6p21.31']loss", "['6q24.1']loss"]) has 1
# frozenset(["['6p21.33']loss", "['6q24.2']loss"]) has 1
# frozenset(["['9p22.2', '9p22.1']loss", "['9q34.2', '9q34.3']loss"]) has 1
# frozenset(["['6p25.2', '6p25.1', '6p24.3']loss", "['6q22.32', '6q22.33']loss"]) has 1
# frozenset(["['3p25.1']loss", "['3q22.3', '3q23', '3q24']loss"]) has 1
# frozenset(["['3p24.1', '3p23', '3p22.3']loss", "['3q25.32', '3q25.33', '3q26.1', '3q26.2']loss"]) has 1
# frozenset(["['3q28', '3q29']loss", "['3p12.2']loss"]) has 1
# frozenset(["['6p21.33', '6p21.32']loss", "['6q25.3', '6q26']loss"]) has 1
# frozenset(["['11p15.3', '11p15.2']loss", "['10q24.1']loss"]) has 1
# frozenset(["['6p21.33']loss", "['6q24.1']loss"]) has 1
# frozenset(["['13q32.1', '13q32.2', '13q32.3']loss", "['11q12.3']loss"]) has 1
# frozenset(["['13q13.2']loss", "['11q12.3']loss"]) has 1
# frozenset(["['9p24.1']loss", "['9q34.2', '9q34.3']loss"]) has 1
# frozenset(["['6q22.1']loss", "['6p22.3']loss"]) has 1
# frozenset(["['3q26.2']loss", "['3p21.1', '3p14.3', '3p14.2']loss"]) has 1
# frozenset(["['6q26', '6q27']loss", "['6p21.2']loss"]) has 1
# frozenset(["['6p22.3', '6p22.2', '6p22.1']loss", "['6q22.33', '6q23.1', '6q23.2', '6q23.3', '6q24.1']loss"]) has 1
# frozenset(["['3q26.2']loss", "['3p24.1']loss"]) has 1
# frozenset(["['6p21.31', '6p21.2']loss", "['6q25.3', '6q26']loss"]) has 1
# frozenset(["['3q28', '3q29']loss", "['3p14.2']loss"]) has 1
# frozenset(["['6p21.33', '6p21.32']loss", "['6q24.2']loss"]) has 1
# frozenset(["['5q12.1']loss", "['15q12', '15q13.1', '15q13.2', '15q13.3', '15q14', '15q15.1', '15q15.2', '15q15.3', '15q21.1']loss"]) has 1
# frozenset(["['3q26.2', '3q26.31', '3q26.32']loss", "['3p26.3', '3p26.2', '3p26.1', '3p25.3', '3p25.2', '3p25.1']loss"]) has 1
# 0

# %% [markdown]
# # Draw co-occurrence network

# %%
import networkx as nx
import csv

G=nx.Graph()
for pair in new_sig_c_dict:
    pair_type = new_sig_c_dict[pair]['Type']
    
    G.add_edge(tuple(pair)[0], tuple(pair)[1], {"Type": pair_type})

pos = nx.spring_layout(G)
nx.draw(G, pos)

# show graph
plt.show()

graphs = list(nx.connected_component_subgraphs(G))
graphs = sorted(graphs, key = lambda entry: entry.number_of_nodes(), reverse=True)

top_number = 3

for i in range(len(graphs)):
    print "\n***********************"
    print "COMPONENT " + str(i) 
    print "***********************"
    graph = graphs[i]
    print "Number of nodes ", graph.number_of_nodes()
    print "Number of edges ", graph.number_of_edges()
    
    node_items = [g + (graph.degree(g[0]),) for g in nx.degree_centrality(graph).items()]
    node_items = sorted(node_items, key=lambda entry: entry[1], reverse = True)
    

    print "---"
    print "Top", top_number, "nodes by degree centraliy in component", i
    print "Gene: Degree Centrality   Degree"
    for j in range(min(top_number, len(node_items))):
        print node_items[j][0], ":", np.round(node_items[j][1], 2), node_items[j][2]
    
    component_file = network_c_file[:-4] + "_comp" + str(i) + ".txt"
    
    print "---"
    print "Writing nodes to: ", component_file
    with open(component_file, 'w') as csvfile:
        writer = csv.writer(csvfile, delimiter='\t')
        writer.writerow(["Node", "Degreee Centrality", "Degree"])
        for node_item in node_items:
            writer.writerow(node_item)
# Out:
# ***********************
# COMPONENT 0
# ***********************
# Number of nodes  77
# Number of edges  278
# ---
# Top 3 nodes by degree centraliy in component 0
# Gene: Degree Centrality   Degree
# PACRG_CAHM_QKI_RN7SL366P_C6orf118_PDE10A_RNA5SP226loss : 0.41 31
# OSTCP1_C6orf99_RSPH3_TAGAP_FNDC1_SOD2_RNU4ATAC18P_WTAP_ACAT2_TCP1_SNORA29_MRPL18_PNLDC1_MAS1_IGF2R_AIRN_SLC22A1_SLC22A2_SLC22A3_LPAL2_LPA_PLG_MAP3K4_AGPAT4loss : 0.38 29
# LINC00473_T_PRR18_SFT2D1_MPC1_RPS6KA2_MIR1913_RNASET2_MIR3939_FGFR1OP_CCR6_TCP10L2_GPR31_UNC93A_TTLL2_TCP10_MLLT4_KIF25_FRMD1_DACT2_SMOC2_THBS2_WDR27_C6orf120_PHF10_TCTE3_LINC00242_LINC00574_DLL1_FAM120B_MIR4644loss : 0.3 23
# ---
# Writing nodes to:  output/PAAD-ucsc-seg-jl-FDR--cpairs-min_cohort_filtered_network_comp0.txt
#
# ***********************
# COMPONENT 1
# ***********************
# Number of nodes  47
# Number of edges  47
# ---
# Top 3 nodes by degree centraliy in component 1
# Gene: Degree Centrality   Degree
# RN7SL605Ploss : 0.78 36
# RN7SL73Ploss : 0.2 9
# FAM83G_GRAP_SNORD3D_GRAPL_SNORD3A_SNORD3C_EPN2loss : 0.07 3
# ---
# Writing nodes to:  output/PAAD-ucsc-seg-jl-FDR--cpairs-min_cohort_filtered_network_comp1.txt
#
# ***********************
# COMPONENT 2
# ***********************
# Number of nodes  39
# Number of edges  86
# ---
# Top 3 nodes by degree centraliy in component 2
# Gene: Degree Centrality   Degree
# APOD_LINC00969_MIR570_MUC20_MUC4_TNK2_SDHAP1_TFRC_LINC00885_ZDHHC19_SLC51A_PCYT1A_TCTEX1D2_TM4SF19_UBXN7_RN7SL434P_RN7SL738P_RNF168_SMCO1_WDR53_FBXO45_NRROS_PIGX_CEP19_PAK2_SENP5_NCBP2_PIGZ_MFI2_DLG1_MIR4797_BDH1_KIAA0226_MIR922_FYTTD1_LRCH3_IQCG_RPL35A_LMLN_ANKRD18DP_FAM157Aloss : 0.53 20
# LPP_MIR28_TPRG1_TP63_MIR944_CLDN1_CLDN16_TMEM207_IL1RAP_RN7SKP296_GMNC_OSTN_UTS2B_CCDC50_PYDC2_RN7SKP222_FGF12_MB21D2_HRASLS_ATP13A5_ATP13A4_OPA1_RN7SL447P_HES1_RN7SL215P_LINC00887_CPN2_LRRC15_GP5_ATP13A3_LINC00884_TMEM44_LSG1_FAM43A_XXYLT1_MIR3137_RN7SL36P_ACAP2_PPP1R2_RNU6ATAC24Ploss : 0.45 17
# RPL22L1_EIF5A2_SLC2A2_TNIK_MIR569_PLD1_TMEM212_FNDC3B_RN7SL141P_GHSR_TNFSF10_NCEH1_ECT2_SPATA16_NLGN1_RN7SKP234_NAALADL2_RN7SKP40_MIR4789_RNA5SP147_TBL1XR1_LINC00501_LINC00578_RN7SKP52loss : 0.34 13
# ---
# Writing nodes to:  output/PAAD-ucsc-seg-jl-FDR--cpairs-min_cohort_filtered_network_comp2.txt
#
# ***********************
# COMPONENT 3
# ***********************
# Number of nodes  38
# Number of edges  39
# ---
# Top 3 nodes by degree centraliy in component 3
# Gene: Degree Centrality   Degree
# ABCA2_C9orf139_FUT7_NPDC1_ENTPD2_SAPCD2_UAP1L1_MAN1B1_SNORD62_DPP7_GRIN1_LRRC26_MIR3621_TMEM210_ANAPC2_SSNA1_TPRN_TMEM203_NDOR1_RNF208_RNF224_SLC34A3_TUBB4B_FAM166A_C9orf173_NELFB_TOR4A_NRARP_EXD3_NOXA1_ENTPD8_NSMF_PNPLA7_MRPL41_DPH7_ZMYND19_ARRDC1_EHMT1_MIR602_CACNA1B_TUBBP5_FAM157Bloss : 0.97 36
# ACTL7B_ACTL7A_IKBKAP_FAM206A_CTNNAL1_TMEM245_MIR32_FRRS1L_EPB41L4B_PTPN3_MIR3927_PALM2_AKAP2_C9orf152_TXN_TXNDC8_SVEP1_MUSK_LPAR1_RNY4P18_OR2K2_KIAA0368_RNA5SP294_ZNF483_PTGR1_LRRC37A5P_DNAJC25_GNG10_C9orf84_UGCG_MIR4668_SUSD1_PTBP3_RN7SL57P_RNA5SP295_RN7SL430P_HSDL2_C9orf147_KIAA1958_INIP_SNX30_SLC46A2_ZNF883_ZFP37_FAM225B_FAM225A_SLC31A2_FKBP15_SLC31A1_CDC26_PRPF4_RNF183_WDR31_BSPRY_HDHD3_ALAD_POLE3_C9orf43_RGS3_ZNF618_AMBP_KIF12_COL27A1_MIR455_ORM1_ORM2_AKNA_DFNB31_ATP6V1G1_C9orf91_TNFSF15_TNFSF8_TNC_LINC00474_PAPPA_ASTN2_TRIM32_SNORA70C_RN7SKP128_RN7SKP125_TLR4_MIR147A_CDK5RAP2_MEGF9_FBXW2_PSMD5_PHF19_TRAF1_C5_CNTRL_RAB14_RN7SL181P_GSN_STOM_GGTA1P_RN7SL187P_DAB2IP_TTLL11_MIR4478_NDUFA8_MORN5_LHX6_RBM18_MRRF_PTGS1_OR1J1_OR1J2_OR1J4_OR1N1_OR1N2_OR1L8_OR1Q1_OR1B1_OR1L1_OR1L3_OR1L4_OR1L6_OR5C1_PDCL_OR1K1_RC3H2_SNORD90_ZBTB6_ZBTB26_RABGAP1_GPR21_MIR600HG_STRBP_CRB2_DENND1A_MIR601_LHX2_NEK6_PSMB7_NR5A1_NR6A1_RN7SL302P_MIR181A2HG_MIR181A2_MIR181B2_OLFML2A_WDR38_RPL35_ARPC5L_GOLGA1_SCAI_PPP6C_RABEPK_HSPA5_GAPVD1_MAPKAP1_RN7SL30P_PBX3_MVB12B_NRON_LMX1B_ZBTB43_ZBTB34_RALGPS1_ANGPTL2_GARNL3_SLC2A8_ZNF79_RPL12_SNORA65_LRSAM1_FAM129B_STXBP1_MIR3911_PTRH1_C9orf117_TTC16_TOR2A_SH2D3C_CDK9_MIR3960_FPGS_ENG_RNA5SP296_AK1_MIR4672_ST6GALNAC6_ST6GALNAC4_PIP5KL1_DPM2_FAM102A_NAIF1_SLC25A25_PTGES2_LCN2_C9orf16_CIZ1_DNM1_MIR199B_GOLGA2_SWI5_TRUB2_COQ4_SLC27A4_URM1_CERCAM_ODF2_GLE1_SPTAN1_WDR34_HMGA1P4_SET_PKN3_RN7SL560P_ZDHHC12_ZER1_TBC1D13_ENDOG_C9orf114_CCBL1_LRRC8A_PHYHD1_DOLK_NUP188_SH3GLB2_FAM73B_DOLPP1_CRAT_PPP2R4_IER5L_C9orf106_RN7SL159P_LINC00963_NTMT1_C9orf50_ASB6_PRRX2_PTGES_TOR1B_TOR1A_C9orf78_USP20_FNBP1_GPR107_NCS1_HMCN2_RN7SL665P_ASS1_FUBP3_PRDM12_EXOSC2_ABL1_QRFP_FIBCD1_LAMC3_AIF1L_NUP214_FAM78A_PPAPDC3_PRRC2B_SNORD62A_SNORD62B_POMT1_UCK1_RAPGEF1_RN7SL328P_MED27_NTNG2_SETX_TTF1_C9orf171_BARHL1_DDX31_GTF3C4_AK8_C9orf9_TSC1_GFI1B_MIR548AW_GTF3C5_CEL_CELP_RALGDS_GBGT1_OBP2B_ABO_SURF6_MED22_RPL7A_SNORD24_SNORD36B_SNORD36A_SNORD36C_SURF1_SURF2_SURF4_REXO4_ADAMTS13_CACFD1_SLC2A6_TMEM8C_ADAMTSL2_FAM163B_DBH_SARDH_VAV2_LINC00094_BRD3_WDR5_RNU6ATAC_RXRA_MIR4669_COL5A1_MIR3689C_MIR3689A_MIR3689D1_MIR3689B_MIR3689D2_MIR3689E_MIR3689F_FCN2_FCN1_OLFM1_C9orf62_PPP1R26_C9orf116_MRPS2_LCN1_OBP2A_PAEP_GLT6D1_LCN9_SOHLH1_KCNT1_CAMSAP1_UBAC1_NACC2_C9orf69_LHX3_QSOX2_DKFZP434A062_GPSM1_DNLZ_CARD9_SNAPC4_SDCCAG3_PMPCA_INPP5E_SEC16A_C9orf163_NOTCH1_MIR4673_MIR4674_EGFL7_MIR126_AGPAT2_FAM69B_SNHG7_LCN10_LCN6_LCN8_LCN15_TMEM141_RABL6_MIR4292_C9orf172_PHPT1_MAMDC4_EDF1_TRAF2_MIR4479_FBXW5_C8G_LCN12_PTGDS_LCNL1_C9orf142_CLIC3loss : 0.08 3
# SMARCA2_RN7SL592P_VLDLR_KCNV2_KIAA0020_CARM1P1_RFX3_GLIS3_SLC1A1_SPATA6L_PPAPDC2_CDC37L1_AK3_RCL1_JAK2_INSL6_INSL4_RLN2_RLN1_PLGRKT_CD274_PDCD1LG2_ERMP1_KIAA2026_MLANA_MIR4665_RANBP6loss : 0.05 2
# ---
# Writing nodes to:  output/PAAD-ucsc-seg-jl-FDR--cpairs-min_cohort_filtered_network_comp3.txt
#
# ***********************
# COMPONENT 4
# ***********************
# Number of nodes  23
# Number of edges  22
# ---
# Top 3 nodes by degree centraliy in component 4
# Gene: Degree Centrality   Degree
# SNORD22loss : 1.0 22
# ZIC5_ZIC2_LINC00554_PCCA_GGACT_TMTC4_LINC00411_NALCN_ITGBL1_FGF14_MIR2681_RNY1P2_MIR4705_LINC00555_TPP2_METTL21C_CCDC168_LINC00283_TEX30_KDELC1_BIVM_ERCC5_METTL21EP_SLC10A2_DAOA_LINC00343_RNA5SP38_LINC00460_EFNB2_ARGLU1_LINC00551_LINC00443_FAM155A_SNORD31_MIR1267loss : 0.05 1
# GPC6loss : 0.05 1
# ---
# Writing nodes to:  output/PAAD-ucsc-seg-jl-FDR--cpairs-min_cohort_filtered_network_comp4.txt
#
# ***********************
# COMPONENT 5
# ***********************
# Number of nodes  14
# Number of edges  23
# ---
# Top 3 nodes by degree centraliy in component 5
# Gene: Degree Centrality   Degree
# AFF2_RN7SKP267loss : 0.92 12
# IDS_LINC00893_CXorf40A_MAGEA9B_HSFX2_TMEM185A_MAGEA11_HSFX1_MAGEA9_MAGEA8_CXorf40B_LINC00894loss : 0.85 11
# HCCS_ARHGAP6_AMELX_MIR548AX_MSL3_FRMPD4_PRPS2_TLR7_TLR8_TMSB4X_FAM9Closs : 0.15 2
# ---
# Writing nodes to:  output/PAAD-ucsc-seg-jl-FDR--cpairs-min_cohort_filtered_network_comp5.txt
#
# ***********************
# COMPONENT 6
# ***********************
# Number of nodes  10
# Number of edges  10
# ---
# Top 3 nodes by degree centraliy in component 6
# Gene: Degree Centrality   Degree
# CHRDL1_PAK3_CAPN6_DCXloss : 0.89 8
# PLEKHA8P1_ANO6loss : 0.22 2
# CXorf57_MIR548AN_RNF128_TBC1D8B_MORC4_RIPPLY1_CLDN2_RBM41_NUP62CL_PIH1D3_FRMPD3_PRPS1_TSC22D3_NCBP2L_MID2_TEX13B_VSIG1_PSMD10_ATG4A_COL4A6_COL4A5_IRS4_GUCY2F_NXT2_ACSL4_TMEM164_MIR652_MIR3978_AMMECR1_SNORD96B_GNG5P2_RGAG1_TDGF1P3loss : 0.22 2
# ---
# Writing nodes to:  output/PAAD-ucsc-seg-jl-FDR--cpairs-min_cohort_filtered_network_comp6.txt
#
# ***********************
# COMPONENT 7
# ***********************
# Number of nodes  5
# Number of edges  4
# ---
# Top 3 nodes by degree centraliy in component 7
# Gene: Degree Centrality   Degree
# GABRG3_RNA5SP391_OCA2_HERC2_GOLGA8F_RN7SL238P_GOLGA8G_HERC2P9_GOLGA8M_RN7SL719P_WHAMMP2_GOLGA6L7P_APBA2_FAM189A1_snoZ278_NDNL2_TJP1_GOLGA8J_RN7SL673P_ULK4P3_GOLGA8T_RN7SL469P_CHRFAM7A_GOLGA8R_RN7SL196P_GOLGA8Q_RN7SL796P_ULK4P2_GOLGA8H_RN7SL628P_ARHGAP11B_RN7SL82P_FAN1_MTMR10_TRPM1_MIR211_KLF13_OTUD7A_CHRNA7_GOLGA8K_RN7SL185P_ULK4P1_GOLGA8O_RN7SL539P_GOLGA8N_RN7SL286P_ARHGAP11A_SCG5_GREM1_FMN1_TMCO5B_RYR3_AVEN_CHRM5_EMC7_PGBD4_KATNBL1_EMC4_SLC12A6_NOP10_NUTM1_LPCAT4_GOLGA8A_GOLGA8B_GJD2_ACTC1_AQR_ZNF770_ANP32AP1_DPH6_MIR3942_C15orf41_CSNK1A1P1_MEIS2_TMCO5A_SPRED1_FAM98B_RASGRP1_C15orf53_C15orf54_THBS1_FSIP1_GPR176_EIF2AK4_SRP14_BMF_BUB1B_PAK6_C15orf56_PLCB2_ANKRD63_C15orf52_RNA5SP392_PHGR1_DISP2_KNSTRN_IVD_BAHD1_CHST14_C15orf57_RPUSD2_CASC5_RN7SL376P_RAD51_RMDN3_GCHFR_DNAJC17_C15orf62_ZFYVE19_PPP1R14D_SPINT1_RHOV_VPS18_DLL4_CHAC1_INO80_EXD1_RN7SL497P_CHP1_OIP5_NUSAP1_NDUFAF1_RTF1_ITPKA_LTK_RPAP1_TYRO3_MGA_MIR626_MAPKBP1_JMJD7_PLA2G4B_SPTBN5_RNA5SP393_MIR4310_EHD4_PLA2G4E_PLA2G4D_PLA2G4F_VPS39_MIR627_TMEM87A_GANC_CAPN3_ZNF106_SNAP23_LRRC57_HAUS2_STARD9_CDAN1_TTBK2_UBR1_EPB42_TMEM62_CCNDBP1_TGM5_TGM7_LCMT2_ADAL_ZSCAN29_TUBGCP4_RN7SL487P_TP53BP1_MAP1A_PPIP5K1_CKMT1B_STRC_CATSPER2_CKMT1A_CATSPER2P1_PDIA3_ELL3_SERF2_MIR1282_SERINC4_HYPK_MFAP1_WDR76_FRMD5_CASC4_CTDSPL2_EIF3J_SPG11_PATL2_B2M_TRIM69_C15orf43_SORD_DUOX2_DUOXA2_DUOXA1_DUOX1_SHF_SLC28A2_GATM_SPATA5L1_C15orf48_MIR147B_SLC30A4_HMGN2P46_BLOC1S6_SQRDL_RN7SKP101loss : 1.0 4
# HTR1A_RNF180loss : 0.25 1
# ISL1_RNA5SP182_ITGA1_PELO_ITGA2_MOCS2_FST_NDUFS4_ARL15_MIR581_RN7SL801P_MIR4459_HSPB3_SNX18_ESM1_GZMK_GZMA_CDC20B_GPX8_MIR449A_MIR449B_MIR449C_MCIDAS_CCNO_DHX29_SKIV2L2_PPAP2A_MIR5687_SLC38A9_DDX4_RNA5SP183_IL31RA_IL6ST_ANKRD55_RNA5SP184_RNA5SP185_RNU6ATAC2P_MAP3K1_SETD9_MIER3_GPBP1_ACTBL2_PLK2_GAPT_MIR548AE2_RAB3C_PDE4D_MIR582_FKSG52_PART1_DEPDC1B_ELOVL7_ERCC8loss : 0.25 1
# ---
# Writing nodes to:  output/PAAD-ucsc-seg-jl-FDR--cpairs-min_cohort_filtered_network_comp7.txt
#
# ***********************
# COMPONENT 8
# ***********************
# Number of nodes  5
# Number of edges  4
# ---
# Top 3 nodes by degree centraliy in component 8
# Gene: Degree Centrality   Degree
# MGMT_EBF3_MIR4297_LINC00959_GLRX3_MIR378C_TCERG1L_PPP2R2D_BNIP3_JAKMIP3_DPYSL4_STK32C_LRRC27_PWWP2B_C10orf91_INPP5A_KNDC1_UTF1_VENTX_MIR202_ADAM8_TUBGCP2_ZNF511_PRAP1_CALY_FUOM_ECHS1_MIR3944_PAOX_MTG1_SPRN_CYP2E1_SYCE1_FRG2Bloss : 1.0 4
# MIR603_ARHGAP21_RNA5SP305_PRTFDC1_RN7SKP241_ENKUR_THNSL1_GPR158_RN7SKP220_RNA5SP306_MYO3A_GAD2_APBB1IP_RNA5SP307_LINC00264_PDSS1_ABI1_LINC00614_ANKRD26_YME1L1_MASTL_ACBD5_LRRC37A6P_ARMC4P1_PTCHD3_RAB18_MKX_RN7SKP132_ARMC4loss : 0.25 1
# RN7SKP39_WAC_RNU4ATAC6P_BAMBIloss : 0.25 1
# ---
# Writing nodes to:  output/PAAD-ucsc-seg-jl-FDR--cpairs-min_cohort_filtered_network_comp8.txt
#
# ***********************
# COMPONENT 9
# ***********************
# Number of nodes  4
# Number of edges  3
# ---
# Top 3 nodes by degree centraliy in component 9
# Gene: Degree Centrality   Degree
# KCNQ1DNloss : 1.0 3
# TEAD1_LINC00958_ARNTL_RN7SKP151_BTBD10_PTH_FAR1loss : 0.33 1
# EPS8L2_TMEM80_TALDO1_PDDC1_CEND1_SLC25A22_RPLP2_SNORA52_PNPLA2_CD151_POLR2L_TSPAN4_CHID1_AP2A2_MUC6_MUC2_MUC5AC_MUC5B_TOLLIP_BRSK2_MOB2_DUSP8_FAM99A_FAM99B_IFITM10_CTSD_SYT8_TNNI2_MIR4298_TNNT3_MRPL23_H19_IGF2_MIR483_INS_TH_MIR4686_ASCL2_C11orf21_TSPAN32_RPL26P30_CD81_TSSC4_TRPM5_KCNQ1_KCNQ1OT1_CDKN1C_SLC22A18AS_SLC22A18_PHLDA2_NAP1L4_SNORA54_CARS_OSBPL5_MRGPRG_MRGPRE_ZNF195_TSSC2_TRPC2_ART5_ART1_CHRNA10_NUP98_PGAP2_RHOG_STIM1_MIR4687_RRM1_OR52B4_TRIM21_OR52K2_OR52K1_OR52M1_C11orf40_OR52I2_OR52I1_TRIM68_OR51D1_OR51E1_OR51E2_OR51C1P_MMP26_OR51F1_OR52R1_OR51F2_OR51S1_OR51T1_OR51A7_OR51G2_OR51G1_OR51A4_OR51A2_OR51L1_OR52J3_OR52E2_OR52A5_OR52A1_OR51V1_HBB_HBD_HBBP1_HBG1_HBG2_HBE1_OR51B4_OR51B2_OR51B5_OR51B6_OR51M1_OR51J1_OR51Q1_OR51I1_OR51I2_OR52D1_UBQLN3_UBQLNL_OR52H1_OR52B6_TRIM6_TRIM34_TRIM5_TRIM22_OR56B1_OR52N4_OR52N5_OR52N1_OR52N2_OR52E6_OR52E8_OR52E4_OR56A3_OR52L1_OR56A4_RNA5SP329_OR56A1_OR56B4_OR52B2_OR52W1_C11orf42_FAM160A2_CNGA4_CCKBR_PRKCDBP_SMPD1_APBB1_HPX_TRIM3_ARFIP2_TIMM10B_DNHD1_RRP8_ILK_TAF10_TPP1_DCHS1_MRPL17_GVINP1_OR2AG2_OR2AG1_OR6A2_OR10A5_OR10A2_OR10A4_OR2D2_OR2D3_ZNF215_ZNF214_NLRP14_RBMXL2_MIR302E_SYT9_OLFML1_PPFIBP2_CYB5R2_OVCH2_OR10AB1P_OR5P2_OR5P3_OR10A6_OR10A3_NLRP10_EIF3F_TUB_RIC3_LMO1_STK33_TRIM66_RPL27A_ST5_RNA5SP330_AKIP1_C11orf16_ASCL3_TMEM9B_NRIP3_SCUBE2_MIR5691_DENND5A_TMEM41B_IPO7_SNORA23_ZNF143_WEE1_SWAP70_RN7SKP50_SBF2_ADM_AMPD3_RNU6ATAC33P_MTRNR2L8_RNF141_LYVE1_MRVI1_CTR9_EIF4G2_SNORD97_ZBED5_GALNT18_CSNK2A3_MIR4299_USP47_DKK3_MICAL2_MICALCL_PARVAloss : 0.33 1
# ---
# Writing nodes to:  output/PAAD-ucsc-seg-jl-FDR--cpairs-min_cohort_filtered_network_comp9.txt
#
# ***********************
# COMPONENT 10
# ***********************
# Number of nodes  3
# Number of edges  2
# ---
# Top 3 nodes by degree centraliy in component 10
# Gene: Degree Centrality   Degree
# EPAS1_TMEM247_RN7SL817P_ATP6V1E2_RHOQ_PIGF_CRIPT_SOCS5_MCFD2_TTC7A_C2orf61_CALM2_BCYRN1_EPCAM_RN7SKP119_MIR559_MSH2_KCNK12_MSH6_FBXO11_RN7SKP224_FOXN2_PPP1R21_STON1_GTF2A1L_LHCGR_FSHR_NRXN1_MIR4431_CHAC2_ERLEC1_MIR3682_GPR75_PSME4_ACYP2_TSPYL6_C2orf73_SPTBN1loss : 1.0 2
# DACH2loss : 0.5 1
# TBX22_FAM46D_BRWD3_HMGN5_SH3BGRL_POU3F4_CYLC1_RPS6KA6_MIR548I4_HDX_UBE2DNL_APOOL_SATL1_ZNF711_POF1B_CHM_MIR361loss : 0.5 1
# ---
# Writing nodes to:  output/PAAD-ucsc-seg-jl-FDR--cpairs-min_cohort_filtered_network_comp10.txt
#
# ***********************
# COMPONENT 11
# ***********************
# Number of nodes  3
# Number of edges  2
# ---
# Top 3 nodes by degree centraliy in component 11
# Gene: Degree Centrality   Degree
# AGAP1_RN7SL204P_GBX2_ASB18_IQCA1_ACKR3_COPS8_COL6A3_MLPH_PRLH_RAB17_LRRFIP1_RBM44_RAMP1_UBE2F_SCLY_ESPNL_KLHL30_FAM132B_ILKAP_HES6_PER2_TRAF3IP1_ASB1_TWIST2_HDAC4_MIR4440_MIR4441_MIR4269_MIR2467_NDUFA10_MIR4786_OR6B2_PRR21_OR6B3_MYEOV2_OTOS_GPC1_MIR149_ANKMY1_DUSP28_RNPEPL1_CAPN10_GPR35_AQP12B_AQP12A_KIF1A_AGXT_C2orf54_SNED1_PASK_PPP1R7_ANO7_HDLBP_FARP2_MIR3133_STK25_BOK_THAP4_RNA5SP122_ATG4B_DTYMK_ING5_D2HGDH_GAL3ST2_NEU4_PDCD1loss : 1.0 2
# VRK2_FANCLloss : 0.5 1
# RNA5SP94_MIR4432_BCL11A_RN7SL361P_PAPOLG_RN7SL632P_REL_PUS10_RNA5SP95_PEX13_KIAA1841_C2orf74_AHSA2_USP34_SNORA70B_XPO1_FAM161A_CCT4_COMMD1_B3GNT2_MIR5192_RN7SL51P_RN7SL18P_TMEM17_EHBP1_OTX1_DBIL5P2_WDPCP_MDH1_RPS4XP5_UGP2_VPS54_PELI1_LINC00309_LGALSL_AFTPH_SERTAD2_RN7SL341P_RN7SL211P_SLC1A4_CEP68_RAB1A_ACTR2_SPRED2_RN7SL635P_MIR4778_MEIS1_ETAA1_C1D_WDR92_PNO1_PPP3R1_CNRIP1_PLEK_FBXO48_APLF_PROKR1_ARHGAP25_BMP10_GKN2_GKN1_ANTXR1_MIR3126_RNA5SP96_GFPT1_NFU1_AAK1_RN7SL604P_SNORA36C_ANXA4_GMCL1_SNRNP27_MXD1_ASPRV1_RN7SL470P_PCBP1_C2orf42_TIA1_PCYOX1_SNRPG_FAM136A_TGFA_ADD2_FIGLA_CLEC4F_CD207_VAX2_ATP6V1B1_RN7SL160P_ANKRD53_TEX261_NAGK_MCEE_MPHOSPH10_PAIP2B_ZNF638_DYSF_CYP26B1_EXOC6B_SPR_EMX1_SFXN5_RAB11FIP5_NOTO_SMYD5_PRADC1_CCT7_FBXO41_EGR4_ALMS1_NAT8_ALMS1P_TPRKB_DUSP11_C2orf78_STAMBP_ACTG2_DGUOK_RNA5SP97_TET3_BOLA3_MOB1A_MTHFD2_SLC4A5_DCTN1_C2orf81_WDR54_RTKN_INO80B_WBP1_MOGS_MRPL53_CCDC142_TTC31_LBX2_PCGF1_TLX2_DQX1_AUP1_HTRA2_LOXL3_DOK1_M1AP_SEMA4F_HK2_POLE4_TACR1_MIR5000_EVA1A_MRPL19_GCFC2_RN7SKP203_RN7SKP164_LRRTM4_RNA5SP98_REG3G_REG1B_REG1A_REG1P_REG3Aloss : 0.5 1
# ---
# Writing nodes to:  output/PAAD-ucsc-seg-jl-FDR--cpairs-min_cohort_filtered_network_comp11.txt
#
# ***********************
# COMPONENT 12
# ***********************
# Number of nodes  2
# Number of edges  1
# ---
# Top 3 nodes by degree centraliy in component 12
# Gene: Degree Centrality   Degree
# DNAH5_TRIO_FAM105A_ANKH_MIR4637_FBXL7_MIR887_RNA5SP178_ZNF622_FAM134B_MYO10_RNA5SP179_BASP1_RNA5SP180_RN7SKP133_FTH1P10_RN7SL58Ploss : 1.0 1
# GRIA1_RN7SL177P_FAM114A2_MFAP3_GALNT10_MIR1294_RN7SL655P_SAP30L_HAND1_MIR3141_MIR1303_LARP1_FAXDC2_MIR378H_CNOT8_GEMIN5_MRPL22_KIF4B_RNA5SP199_SGCD_TIMD4_HAVCR1_HAVCR2_MED7_ITK_FAM71B_CYFIP2_FNDC9_ADAM19_NIPAL4_SOX30_C5orf52_THG1L_LSM11_CLINT1_EBF1_RNF145_UBLCP1_IL12B_RNU4ATAC2P_ADRA1B_TTC1_PWWP2A_FABP6_CCNJL_C1QTNF2_SLU7_PTTG1_MIR3142_MIR146A_ATP10B_GABRB2_GABRA6_GABRA1_GABRG2_CCNG1_NUDCD2_HMMR_MAT2B_RN7SKP60_TENM2_WWC1_RARS_FBLL1_PANK3_MIR103A1_SLIT3_MIR585_SPDL1_DOCK2_FAM196B_MIR378E_FOXI1_C5orf58_LCP2_KCNIP1_KCNMB1_GABRP_RANBP17_RN7SL623P_TLX3_RN7SL339P_MIR3912_NPM1_FGF18_FBXW11_STK10_EFCAB9_UBTD2_SH3PXD2B_NEURL1B_MIR5003_DUSP1_ERGIC1_RPL26L1_ATP6V0E1_SNORA74B_CREBRF_BNIP1_RNA5SP200_STC2_BOD1_CPEB4_C5orf47_MSX2_MIR4634_DRD1_SFXN1loss : 1.0 1
# ---
# Writing nodes to:  output/PAAD-ucsc-seg-jl-FDR--cpairs-min_cohort_filtered_network_comp12.txt
#
# ***********************
# COMPONENT 13
# ***********************
# Number of nodes  2
# Number of edges  1
# ---
# Top 3 nodes by degree centraliy in component 13
# Gene: Degree Centrality   Degree
# KCNMB2_RNA5SP148_ZMAT3_PIK3CA_KCNMB3_ZNF639_MFN1_GNB4_ACTL6A_MRPL47_NDUFB5_USP13_PEX5L_RNA5SP149_TTC14_CCDC39_RN7SL229P_FXR1_DNAJC19_SOX2_RN7SL703P_RNA5SP150_RN7SKP265_ATP11B_DCUN1D1_MCCC1_LAMP3_MCF2L2_B3GNT5_RNA5SP151_LINC00888_KLHL6_KLHL24_YEATS2_MAP6D1_PARL_MIR4448_CYP2AB1P_ABCC5_HTR3D_HTR3C_HTR3E_EIF2B5_DVL3_AP2M1_ABCF3_VWA5B2_MIR1224_ALG3_ECE2_CAMK2N2_PSMD2_EIF4G1_FAM131A_CLCN2_POLR2H_THPO_CHRD_EPHB3_MAGEF1_VPS8_C3orf70_EHHADH_MAP3K13_TMEM41A_LIPH_SENP2_IGF2BP2_MIR548AQ_TRA2B_ETV5_DGKG_CRYGS_TBCCD1_DNAJB11_AHSG_FETUB_HRG_KNG1_EIF4A2_RFC4_ADIPOQ_ST6GAL1_RPL39L_RTP1_MASP1_RTP4_SST_RTP2_BCL6loss : 1.0 1
# TGFBR2loss : 1.0 1
# ---
# Writing nodes to:  output/PAAD-ucsc-seg-jl-FDR--cpairs-min_cohort_filtered_network_comp13.txt

# %% [markdown]
# ## Search for triplets from among the pairs

# %%
# Search for triplets
import mutex_triangles as met
import edgereader as edg


        
    
    
# Search for triplets
import mutex_triangles as met
import edgereader as edg

genedict = edg.get_gene_dict(new_sig_dict)
Triplets, pairsdict_Triplets, sorted_pairs, genesdict_Triplets, sorted_genes = met.getTriplets(new_sig_dict, genedict, new_sig_dict, numCases, geneToCases=geneToCases, patientToGenes=patientToGenes)
Triplet_dict = met.sort_triplets_by_type(Triplets)

for t_type in Triplet_dict:
    print len(Triplet_dict[t_type]), " of type ",  t_type
    Triplet_dict[t_type] = sorted(Triplet_dict[t_type], key=lambda entry: entry.stats['Count'], reverse=True)
    triplet_file_name = triplet_output_prefix + t_type + '.txt'
    met.writeTriplets2(Triplet_dict[t_type], triplet_file_name)
    # !python add_COSMIC.py -ic Gene0 Gene1 Gene2 -ip $COSMIC_triplet_insertion_index -i $triplet_file_name -o $triplet_file_name
    print "updated with COSMIC info ", triplet_file_name
    
    
    
    print "*********" + str(t_type) + "INFO**********\n"
    gene_t_dict = {}
    cyto_t_dict = {}
    cyto_trip_t_dict = {}
    
    
    # LEFT OFF HERE-JLU
    
    for triplet in Triplet_dict[t_type]:
        genes = triplet.genes
        suffixes = [gene[-4:] if gene[-4:] in {'loss', 'gain'} else "" for gene in genes]
        
        cytobands = set([str(bgbp.get_segment_gene_info(gene)['Cytobands']) for gene, suffix in zip(genes, suffixes)])
        
        for gene in genes:
            if gene not in gene_t_dict:
                gene_t_dict[gene] = set()
            gene_t_dict[gene].add(frozenset(genes.difference(set([gene]))))
    
        
        for cytoband in cytobands:
            if cytoband not in cyto_t_dict:
                cyto_t_dict[cytoband] = set()
            cyto_t_dict[cytoband].add(frozenset(cytobands.difference(set([cytoband]))))
    
        if frozenset(cytobands) not in cyto_trip_t_dict:
            cyto_trip_t_dict[frozenset(cytobands)] = set()
            
        cyto_trip_t_dict[frozenset(cytobands)].add(frozenset(genes))
    
    
    

    sorted_genes = sorted(gene_t_dict.items(), key = lambda entry: len(entry[1]), reverse=True)
    sorted_cytobands = sorted(cyto_t_dict.items(), key = lambda entry: len(entry[1]), reverse=True)
    sorted_cytotuples = sorted(cyto_trip_t_dict.items(), key = lambda entry: len(entry[1]), reverse=True)

    print "\n**********SINGLE GENES**********"
    print_length = 15
    for gene in sorted_genes:
        if len(gene[0]) <= print_length + 4:
            print gene[0], "has", len(gene[1])
        else:
            print gene[0][0:print_length] + gene[0][-4:], "has\t", len(gene[1])

    print "\n**********SINGLE CYTOBANDS**********"
    for cytoband in sorted_cytobands:
        print cytoband[0], "has", len(cytoband[1])

    print "\n**********TRIPLET CYTOBANDS**********"
    for cytotuple in sorted_cytotuples:
        print  cytotuple[0], "has", len(cytotuple[1])


    os.system('say "finished"')
# Out:
# number of pairs  522
# Pair info of triplets initialized
# 0  triplets calculated in  0.040894985199
# Including sorting time  0.0419609546661

# %% [markdown]
# # Run weSME

# %%
num_samples = 1000
pthresh = 0.05
num_permute = 100

bin_threshold = test_minFreq

cancer_name = mutationmatrix.split("/")[-1][:-3]

weSME_folder = '/Users/jlu96/conte/wsampling/'
weSME_data_folder = '/Users/jlu96/conte/wsampling/data/' + cancer_name + '/'
weSME_file = weSME_data_folder + cancer_name + "-list.txt"
weSME_freq_file = weSME_data_folder + cancer_name + "-freqs.txt"
weSME_sampling_folder = weSME_data_folder + 'sampling/'
weSME_permute_folder = weSME_data_folder + 'permute/'
weSME_permute_prefix = weSME_permute_folder + "permute"
me_output = weSME_data_folder + "ME_" + str(pthresh) + ".txt"
co_output = weSME_data_folder + "CO_" + str(pthresh) + ".txt"
permute_me_output_prefix = weSME_permute_folder + "permute_output_ME_" + str(pthresh)
permute_co_output_prefix = weSME_permute_folder + "permute_output_CO_" + str(pthresh)
fdr_me_output = weSME_data_folder + "ME_FDR.txt"
fdr_co_output = weSME_data_folder + "CO_FDR.txt"
pv_fdr_me_output = weSME_data_folder + "pv_ME_FDR.txt"
pv_fdr_co_output = weSME_data_folder + "pv_CO_FDR.txt"


comp_sample_weights = weSME_folder + 'comp_sample_weights.py'
comp_me_for_all_pairs = weSME_folder + 'comp_me_for_all_pairs.py'
comp_co_for_all_pairs = weSME_folder + 'comp_co_for_all_pairs.py'
comp_fdr = weSME_folder + 'comp_fdr.py'
run_permute_data = weSME_folder + 'run_permute_data.py'
run_weighted_sampling = weSME_folder + 'run_weighted_sampling.py'

# %%
# convert the mutationmatirx to weSME format

# !mkdir $weSME_data_folder
# !python preprocessing/matrixToMut_list.py -i $mutationmatrix -o $weSME_file
# Out:
# mkdir: /Users/jlu96/conte/wsampling/data/BRCA_wustl-som/: File exists
# WeSME mut_list written to  /Users/jlu96/conte/wsampling/data/BRCA_wustl-som/BRCA_wustl-som-list.txt

# %%
# sample

# !python $comp_sample_weights $cancer_name $cancer_name -i $weSME_file -o $weSME_freq_file
# !mkdir $weSME_sampling_folder

print "Making samples"
# !time python $run_weighted_sampling $cancer_name $cancer_name $num_samples -m $weSME_file -f $weSME_freq_file -o $weSME_sampling_folder
# !echo "Sampling written to " $weSME_sampling_folder
# Out:
# INFO:root:BRCA_wustl-som
# mkdir: /Users/jlu96/conte/wsampling/data/BRCA_wustl-som/sampling/: File exists
# Making samples
# INFO:root:BRCA_wustl-som
# INFO:root:for all observed k's
#
# real	0m35.182s
# user	0m30.644s
# sys	0m1.076s
# Sampling written to  /Users/jlu96/conte/wsampling/data/BRCA_wustl-som/sampling/

# %%
# Get mutex + co-occurrence
# !time python $comp_me_for_all_pairs $cancer_name $cancer_name $pthresh -m $weSME_file -s $weSME_sampling_folder -o $me_output
# !echo "Mutex written to " $me_output
# !time python $comp_co_for_all_pairs $cancer_name $cancer_name $pthresh -m $weSME_file -s $weSME_sampling_folder -o $co_output
# !echo "Cooccur written to " $co_output

os.system('Pairs completed"')
# Out:
# DEBUG:root:comp ME for BRCA_wustl-som, BRCA_wustl-som
# INFO:root:0
# INFO:root:1000
# INFO:root:2000
# INFO:root:3000
# INFO:root:4000
# INFO:root:5000
# INFO:root:6000
# INFO:root:7000
# INFO:root:8000
# INFO:root:9000
# INFO:root:10000
# INFO:root:11000
# INFO:root:12000
# INFO:root:13000
# INFO:root:14000
# INFO:root:15000
# INFO:root:16000
# INFO:root:17000
#
# real	180m36.426s
# user	111m56.695s
# sys	1m43.464s
# Mutex written to  /Users/jlu96/conte/wsampling/data/BRCA_wustl-som/ME_0.05.txt
# DEBUG:root:comp CO for BRCA_wustl-som, BRCA_wustl-som
#
# real	121m52.402s
# user	107m36.800s
# sys	2m12.414s
# Cooccur written to  /Users/jlu96/conte/wsampling/data/BRCA_wustl-som/CO_0.05.txt
# 512

# %%
# compute FDR
# CHECK TO MAKE SURE ME AND CO ARE WRITTEN TO THE RIGHT FILES ANDL OADED RIGHT BY FDR
import time 
# !mkdir $weSME_permute_folder

t = time.time()
for i in range(num_permute):
    permute_file = weSME_permute_prefix  + "_" + str(i) + ".txt"
    me_output_file = permute_me_output_prefix + str(i) + ".txt"
    co_output_file = permute_co_output_prefix + str(i) + ".txt"
    
    print "FILE ", i
    print "Permuting"
    # !time python $run_permute_data $cancer_name $cancer_name $i $num_permute -i $weSME_file -p $weSME_permute_prefix
    print "ME"
    # !time python $comp_me_for_all_pairs $cancer_name $cancer_name $pthresh -m $permute_file -s $weSME_sampling_folder -o $me_output_file
    print "CO"
    # !time python $comp_co_for_all_pairs $cancer_name $cancer_name $pthresh -m $permute_file -s $weSME_sampling_folder -o $co_output_file
print "Time used for running over permutes: ", time.time() - t    

os.system('Permutes completed"')

print "FDR ME"
# !time python $comp_fdr $cancer_name $cancer_name me $num_permute $bin_threshold -m $weSME_file -p $me_output -n $permute_me_output_prefix -f $fdr_me_output -pf $pv_fdr_me_output

print "FDR CO"
# !time python $comp_fdr $cancer_name $cancer_name co $num_permute $bin_threshold -m $weSME_file -p $co_output -n $permute_co_output_prefix -f $fdr_co_output -pf $pv_fdr_co_output
# Out:
# mkdir: /Users/jlu96/conte/wsampling/data/BRCA_wustl-som/permute/: File exists
# FILE  0
# Permuting
# INFO:root:0-th permutation.. (permute 100 times)
# INFO:root:
# ****** reading mutation data files (BRCA_wustl-som)...
#
# DEBUG:root:10000 swaps..
#
# DEBUG:root:20000 swaps..
#
# DEBUG:root:30000 swaps..
#
# DEBUG:root:40000 swaps..
#
# DEBUG:root:50000 swaps..
#
# DEBUG:root:60000 swaps..
#
# DEBUG:root:70000 swaps..
#
# DEBUG:root:80000 swaps..
#
# DEBUG:root:90000 swaps..
#
# DEBUG:root:100000 swaps..
#
# DEBUG:root:110000 swaps..
#
# DEBUG:root:120000 swaps..
#
# DEBUG:root:130000 swaps..
#
# DEBUG:root:140000 swaps..
#
# DEBUG:root:150000 swaps..
#
# DEBUG:root:160000 swaps..
#
# DEBUG:root:170000 swaps..
#
# DEBUG:root:180000 swaps..
#
# DEBUG:root:190000 swaps..
#
# DEBUG:root:200000 swaps..
#
# DEBUG:root:210000 swaps..
#
# DEBUG:root:220000 swaps..
#
# DEBUG:root:230000 swaps..
#
# DEBUG:root:240000 swaps..
#
# DEBUG:root:250000 swaps..
#
# DEBUG:root:260000 swaps..
#
# DEBUG:root:270000 swaps..
#
# DEBUG:root:280000 swaps..
#
# DEBUG:root:290000 swaps..
#
# DEBUG:root:300000 swaps..
#
# DEBUG:root:310000 swaps..
#
# DEBUG:root:320000 swaps..
#
# DEBUG:root:330000 swaps..
#
# DEBUG:root:340000 swaps..
#
# DEBUG:root:350000 swaps..
#
# DEBUG:root:360000 swaps..
#
# DEBUG:root:370000 swaps..
#
# DEBUG:root:380000 swaps..
#
# DEBUG:root:390000 swaps..
#
# DEBUG:root:400000 swaps..
#
# DEBUG:root:410000 swaps..
#
# DEBUG:root:420000 swaps..
#
# DEBUG:root:430000 swaps..
#
# DEBUG:root:440000 swaps..
#
# DEBUG:root:450000 swaps..
#
# DEBUG:root:460000 swaps..
#
# DEBUG:root:470000 swaps..
#
# DEBUG:root:480000 swaps..
#
# DEBUG:root:490000 swaps..
#
# DEBUG:root:500000 swaps..
#
# DEBUG:root:510000 swaps..
#
# DEBUG:root:520000 swaps..
#
# DEBUG:root:530000 swaps..
#
# DEBUG:root:540000 swaps..
#
# DEBUG:root:550000 swaps..
#
# DEBUG:root:560000 swaps..
#
# DEBUG:root:570000 swaps..
#
# DEBUG:root:580000 swaps..
#
# DEBUG:root:590000 swaps..
#
# DEBUG:root:600000 swaps..
#
# DEBUG:root:610000 swaps..
#
# DEBUG:root:620000 swaps..
#
# DEBUG:root:630000 swaps..
#
# DEBUG:root:640000 swaps..
#
# DEBUG:root:650000 swaps..
#
# DEBUG:root:660000 swaps..
#
# DEBUG:root:670000 swaps..
#
# DEBUG:root:680000 swaps..
#
# DEBUG:root:690000 swaps..
#
# DEBUG:root:700000 swaps..
#
# DEBUG:root:710000 swaps..
#
# DEBUG:root:720000 swaps..
#
# DEBUG:root:730000 swaps..
#
# DEBUG:root:740000 swaps..
#
# DEBUG:root:750000 swaps..
#
# DEBUG:root:760000 swaps..
#
# DEBUG:root:770000 swaps..
#
# DEBUG:root:780000 swaps..
#
# DEBUG:root:790000 swaps..
#
# DEBUG:root:800000 swaps..
#
# DEBUG:root:810000 swaps..
#
# DEBUG:root:820000 swaps..
#
# DEBUG:root:830000 swaps..
#
# DEBUG:root:840000 swaps..
#
# DEBUG:root:850000 swaps..
#
# DEBUG:root:860000 swaps..
#
# DEBUG:root:870000 swaps..
#
# DEBUG:root:880000 swaps..
#
# DEBUG:root:890000 swaps..
#
# DEBUG:root:900000 swaps..
#
# DEBUG:root:910000 swaps..
#
# DEBUG:root:920000 swaps..
#
# DEBUG:root:930000 swaps..
#
# DEBUG:root:940000 swaps..
#
# DEBUG:root:950000 swaps..
#
# DEBUG:root:960000 swaps..
#
# DEBUG:root:970000 swaps..
#
# DEBUG:root:980000 swaps..
#
# DEBUG:root:990000 swaps..
#
# DEBUG:root:1000000 swaps..
#
# DEBUG:root:1010000 swaps..
#
# DEBUG:root:1020000 swaps..
#
# DEBUG:root:1030000 swaps..
#
# DEBUG:root:1040000 swaps..
#
# DEBUG:root:1050000 swaps..
#
# DEBUG:root:1060000 swaps..
#
# DEBUG:root:1070000 swaps..
#
# DEBUG:root:1080000 swaps..
#
# DEBUG:root:1090000 swaps..
#
# DEBUG:root:1100000 swaps..
#
# DEBUG:root:1110000 swaps..
#
# DEBUG:root:1120000 swaps..
#
# DEBUG:root:1130000 swaps..
#
# DEBUG:root:1140000 swaps..
#
# DEBUG:root:1150000 swaps..
#
# DEBUG:root:1160000 swaps..
#
# DEBUG:root:1170000 swaps..
#
# DEBUG:root:1180000 swaps..
#
# DEBUG:root:1190000 swaps..
#
# DEBUG:root:1200000 swaps..
#
# DEBUG:root:1210000 swaps..
#
# DEBUG:root:1220000 swaps..
#
# DEBUG:root:1230000 swaps..
#
# DEBUG:root:1240000 swaps..
#
# DEBUG:root:1250000 swaps..
#
# DEBUG:root:1260000 swaps..
#
# DEBUG:root:1270000 swaps..
#
# DEBUG:root:1280000 swaps..
#
# DEBUG:root:1290000 swaps..
#
# DEBUG:root:1300000 swaps..
#
# DEBUG:root:1310000 swaps..
#
# DEBUG:root:1320000 swaps..
#
# DEBUG:root:1330000 swaps..
#
# DEBUG:root:1340000 swaps..
#
# DEBUG:root:1350000 swaps..
#
# DEBUG:root:1360000 swaps..
#
# DEBUG:root:1370000 swaps..
#
# DEBUG:root:1380000 swaps..
#
# DEBUG:root:1390000 swaps..
#
# DEBUG:root:1400000 swaps..
#
# DEBUG:root:1410000 swaps..
#
# DEBUG:root:1420000 swaps..
#
# DEBUG:root:1430000 swaps..
#
# DEBUG:root:1440000 swaps..
#
# DEBUG:root:1450000 swaps..
#
# DEBUG:root:1460000 swaps..
#
# DEBUG:root:1470000 swaps..
#
# DEBUG:root:1480000 swaps..
#
# DEBUG:root:1490000 swaps..
#
# DEBUG:root:1500000 swaps..
#
# DEBUG:root:1510000 swaps..
#
# DEBUG:root:1520000 swaps..
#
# DEBUG:root:1530000 swaps..
#
# DEBUG:root:1540000 swaps..
#
# DEBUG:root:1550000 swaps..
#
# DEBUG:root:1560000 swaps..
#
# DEBUG:root:1570000 swaps..
#
# DEBUG:root:1580000 swaps..
#
# DEBUG:root:1590000 swaps..
#
# DEBUG:root:1600000 swaps..
#
# DEBUG:root:1610000 swaps..
#
# DEBUG:root:1620000 swaps..
#
# DEBUG:root:1630000 swaps..
#
# DEBUG:root:1640000 swaps..
#
# DEBUG:root:1650000 swaps..
#
# DEBUG:root:1660000 swaps..
#
# DEBUG:root:1670000 swaps..
#
# DEBUG:root:1680000 swaps..
#
# DEBUG:root:1690000 swaps..
#
# DEBUG:root:1700000 swaps..
#
# DEBUG:root:1710000 swaps..
#
# DEBUG:root:1720000 swaps..
#
# DEBUG:root:1730000 swaps..
#
# DEBUG:root:1740000 swaps..
#
# DEBUG:root:1750000 swaps..
#
# DEBUG:root:1760000 swaps..
#
# DEBUG:root:1770000 swaps..
#
# DEBUG:root:1780000 swaps..
#
# DEBUG:root:1790000 swaps..
#
# DEBUG:root:1800000 swaps..
#
# DEBUG:root:1810000 swaps..
#
# DEBUG:root:1820000 swaps..
#
# DEBUG:root:1830000 swaps..
#
# DEBUG:root:1840000 swaps..
#
# DEBUG:root:1850000 swaps..
#
# DEBUG:root:1860000 swaps..
#
# DEBUG:root:1870000 swaps..
#
# DEBUG:root:1880000 swaps..
#
# DEBUG:root:1890000 swaps..
#
# DEBUG:root:1900000 swaps..
#
# DEBUG:root:1910000 swaps..
#
# DEBUG:root:1920000 swaps..
#
# DEBUG:root:1930000 swaps..
#
# DEBUG:root:1940000 swaps..
#
# DEBUG:root:1950000 swaps..
#
# DEBUG:root:1960000 swaps..
#
# DEBUG:root:1970000 swaps..
#
# DEBUG:root:1980000 swaps..
#
# DEBUG:root:1990000 swaps..
#
# DEBUG:root:2000000 swaps..
#
# DEBUG:root:2010000 swaps..
#
# DEBUG:root:2020000 swaps..
#
# DEBUG:root:2030000 swaps..
#
# DEBUG:root:2040000 swaps..
#
# DEBUG:root:2050000 swaps..
#
# DEBUG:root:2060000 swaps..
#
# DEBUG:root:2070000 swaps..
#
# DEBUG:root:2080000 swaps..
#
# DEBUG:root:2090000 swaps..
#
# DEBUG:root:2100000 swaps..
#
# DEBUG:root:2110000 swaps..
#
# DEBUG:root:2120000 swaps..
#
# DEBUG:root:2130000 swaps..
#
# DEBUG:root:2140000 swaps..
#
# DEBUG:root:2150000 swaps..
#
# DEBUG:root:2160000 swaps..
#
# DEBUG:root:2170000 swaps..
#
# DEBUG:root:2180000 swaps..
#
# DEBUG:root:2190000 swaps..
#
# DEBUG:root:2200000 swaps..
#
# DEBUG:root:2210000 swaps..
#
# DEBUG:root:2220000 swaps..
#
# DEBUG:root:2230000 swaps..
#
# DEBUG:root:2240000 swaps..
#
# DEBUG:root:2250000 swaps..
#
# DEBUG:root:2260000 swaps..
#
# DEBUG:root:2270000 swaps..
#
# DEBUG:root:2280000 swaps..
#
# DEBUG:root:2290000 swaps..
#
# DEBUG:root:2300000 swaps..
#
# DEBUG:root:2310000 swaps..
#
# DEBUG:root:2320000 swaps..
#
# DEBUG:root:2330000 swaps..
#
# DEBUG:root:2340000 swaps..
#
# DEBUG:root:2350000 swaps..
#
# DEBUG:root:2360000 swaps..
#
# DEBUG:root:2370000 swaps..
#
# DEBUG:root:2380000 swaps..
#
# DEBUG:root:2390000 swaps..
#
# DEBUG:root:2400000 swaps..
#
# DEBUG:root:2410000 swaps..
#
# DEBUG:root:2420000 swaps..
#
# DEBUG:root:2430000 swaps..
#
# DEBUG:root:2440000 swaps..
#
# DEBUG:root:2450000 swaps..
#
# DEBUG:root:2460000 swaps..
#
# DEBUG:root:2470000 swaps..
#
# DEBUG:root:2480000 swaps..
#
# DEBUG:root:2490000 swaps..
#
# DEBUG:root:2500000 swaps..
#
# DEBUG:root:2510000 swaps..
#
# DEBUG:root:2520000 swaps..
#
# DEBUG:root:2530000 swaps..
#
# DEBUG:root:2540000 swaps..
#
# DEBUG:root:2550000 swaps..
#
# DEBUG:root:2560000 swaps..
#
# DEBUG:root:2570000 swaps..
#
# DEBUG:root:2580000 swaps..
#
# DEBUG:root:2590000 swaps..
#
# DEBUG:root:2600000 swaps..
#
# DEBUG:root:2610000 swaps..
#
# DEBUG:root:2620000 swaps..
#
# DEBUG:root:2630000 swaps..
#
# DEBUG:root:2640000 swaps..
#
# DEBUG:root:2650000 swaps..
#
# DEBUG:root:2660000 swaps..
#
# DEBUG:root:2670000 swaps..
#
# DEBUG:root:2680000 swaps..
#
# DEBUG:root:2690000 swaps..
#
# DEBUG:root:2700000 swaps..
#
# DEBUG:root:2710000 swaps..
#
# DEBUG:root:2720000 swaps..
#
# DEBUG:root:2730000 swaps..
#
# DEBUG:root:2740000 swaps..
#
# DEBUG:root:2750000 swaps..
#
# DEBUG:root:2760000 swaps..
#
# DEBUG:root:2770000 swaps..
#
# DEBUG:root:2780000 swaps..
#
# DEBUG:root:2790000 swaps..
#
# DEBUG:root:2800000 swaps..
#
# DEBUG:root:2810000 swaps..
#
# DEBUG:root:2820000 swaps..
#
# DEBUG:root:2830000 swaps..
#
# DEBUG:root:2840000 swaps..
#
# DEBUG:root:2850000 swaps..
#
# DEBUG:root:2860000 swaps..
#
# DEBUG:root:2870000 swaps..
#
# DEBUG:root:2880000 swaps..
#
# DEBUG:root:2890000 swaps..
#
# DEBUG:root:2900000 swaps..
#
# DEBUG:root:2910000 swaps..
#
# DEBUG:root:2920000 swaps..
#
# DEBUG:root:2930000 swaps..
#
# DEBUG:root:2940000 swaps..
#
# DEBUG:root:2950000 swaps..
#
# DEBUG:root:2960000 swaps..
#
# DEBUG:root:2970000 swaps..
#
# DEBUG:root:2980000 swaps..
#
# DEBUG:root:2990000 swaps..
#
# DEBUG:root:3000000 swaps..
#
# DEBUG:root:3010000 swaps..
#
# DEBUG:root:3020000 swaps..
#
# DEBUG:root:3030000 swaps..
#
# DEBUG:root:3040000 swaps..
#
# DEBUG:root:3050000 swaps..
#
# DEBUG:root:3060000 swaps..
#
# DEBUG:root:3070000 swaps..
#
# DEBUG:root:3080000 swaps..
#
# DEBUG:root:3090000 swaps..
#
# DEBUG:root:3100000 swaps..
#
# DEBUG:root:3110000 swaps..
#
# DEBUG:root:3120000 swaps..
#
# DEBUG:root:3130000 swaps..
#
# DEBUG:root:3140000 swaps..
#
# DEBUG:root:3150000 swaps..
#
# DEBUG:root:3160000 swaps..
#
# DEBUG:root:3170000 swaps..
#
# DEBUG:root:3180000 swaps..
#
# DEBUG:root:3190000 swaps..
#
# DEBUG:root:3200000 swaps..
#
# DEBUG:root:3210000 swaps..
#
# DEBUG:root:3220000 swaps..
#
# DEBUG:root:3230000 swaps..
#
# DEBUG:root:3240000 swaps..
#
# DEBUG:root:3250000 swaps..
#
# DEBUG:root:3260000 swaps..
#
# DEBUG:root:3270000 swaps..
#
# DEBUG:root:3280000 swaps..
#
# DEBUG:root:3290000 swaps..
#
# DEBUG:root:3300000 swaps..
#
# DEBUG:root:3310000 swaps..
#
# DEBUG:root:3320000 swaps..
#
# DEBUG:root:3330000 swaps..
#
# DEBUG:root:3340000 swaps..
#
# DEBUG:root:3350000 swaps..
#
# DEBUG:root:3360000 swaps..
#
# DEBUG:root:3370000 swaps..
#
# DEBUG:root:3380000 swaps..
#
# DEBUG:root:3390000 swaps..
#
# DEBUG:root:3400000 swaps..
#
# DEBUG:root:3410000 swaps..
#
# DEBUG:root:3420000 swaps..
#
# DEBUG:root:3430000 swaps..
#
# DEBUG:root:3440000 swaps..
#
# DEBUG:root:3450000 swaps..
#
# DEBUG:root:3460000 swaps..
#
# DEBUG:root:3470000 swaps..
#
# DEBUG:root:3480000 swaps..
#
# DEBUG:root:3490000 swaps..
#
# DEBUG:root:3500000 swaps..
#
# DEBUG:root:3510000 swaps..
#
# DEBUG:root:3520000 swaps..
#
# DEBUG:root:3530000 swaps..
#
# DEBUG:root:3540000 swaps..
#
# DEBUG:root:3550000 swaps..
#
# DEBUG:root:3560000 swaps..
#
# DEBUG:root:3570000 swaps..
#
# DEBUG:root:3580000 swaps..
#
# DEBUG:root:3590000 swaps..
#
# DEBUG:root:3600000 swaps..
#
# DEBUG:root:3610000 swaps..
#
# DEBUG:root:3620000 swaps..
#
# DEBUG:root:3630000 swaps..
#
# DEBUG:root:3640000 swaps..
#
# DEBUG:root:3650000 swaps..
#
# DEBUG:root:3660000 swaps..
#
# DEBUG:root:3670000 swaps..
#
# DEBUG:root:3680000 swaps..
#
# DEBUG:root:3690000 swaps..
#
# DEBUG:root:3700000 swaps..
#
# DEBUG:root:3710000 swaps..
#
# DEBUG:root:3720000 swaps..
#
# DEBUG:root:3730000 swaps..
#
# DEBUG:root:3740000 swaps..
#
# DEBUG:root:3750000 swaps..
#
# DEBUG:root:3760000 swaps..
#
# DEBUG:root:3770000 swaps..
#
# DEBUG:root:3780000 swaps..
#
# DEBUG:root:3790000 swaps..
#
# DEBUG:root:3800000 swaps..
#
# DEBUG:root:3810000 swaps..
#
# DEBUG:root:3820000 swaps..
#
# DEBUG:root:3830000 swaps..
#
# DEBUG:root:3840000 swaps..
#
# DEBUG:root:3850000 swaps..
#
# DEBUG:root:3860000 swaps..
#
# DEBUG:root:3870000 swaps..
#
# DEBUG:root:3880000 swaps..
#
# DEBUG:root:3890000 swaps..
#
# DEBUG:root:3900000 swaps..
#
# DEBUG:root:3910000 swaps..
#
# DEBUG:root:3920000 swaps..
#
# DEBUG:root:3930000 swaps..
#
# DEBUG:root:3940000 swaps..
#
# DEBUG:root:3950000 swaps..
#
# DEBUG:root:3960000 swaps..
#
# DEBUG:root:3970000 swaps..
#
# DEBUG:root:3980000 swaps..
#
# DEBUG:root:3990000 swaps..
#
# DEBUG:root:4000000 swaps..
#
# DEBUG:root:4010000 swaps..
#
# DEBUG:root:4020000 swaps..
#
# DEBUG:root:4030000 swaps..
#
# DEBUG:root:4040000 swaps..
#
# DEBUG:root:4050000 swaps..
#
# DEBUG:root:4060000 swaps..
#
# DEBUG:root:4070000 swaps..
#
# DEBUG:root:4080000 swaps..
#
# DEBUG:root:4090000 swaps..
#
# DEBUG:root:4100000 swaps..
#
# DEBUG:root:4110000 swaps..
#
# DEBUG:root:4120000 swaps..
#
# DEBUG:root:4130000 swaps..
#
# DEBUG:root:4140000 swaps..
#
# DEBUG:root:4150000 swaps..
#
# DEBUG:root:4160000 swaps..
#
# DEBUG:root:4170000 swaps..
#
# DEBUG:root:4180000 swaps..
#
# DEBUG:root:4190000 swaps..
#
# DEBUG:root:4200000 swaps..
#
# DEBUG:root:4210000 swaps..
#
# DEBUG:root:4220000 swaps..
#
# DEBUG:root:4230000 swaps..
#
# DEBUG:root:4240000 swaps..
#
# DEBUG:root:4250000 swaps..
#
# DEBUG:root:4260000 swaps..
#
# DEBUG:root:4270000 swaps..
#
# DEBUG:root:4280000 swaps..
#
# DEBUG:root:4290000 swaps..
#
# DEBUG:root:4300000 swaps..
#
# DEBUG:root:4310000 swaps..
#
# DEBUG:root:4320000 swaps..
#
# DEBUG:root:4330000 swaps..
#
# DEBUG:root:4340000 swaps..
#
# DEBUG:root:4350000 swaps..
#
# DEBUG:root:4360000 swaps..
#
# DEBUG:root:4370000 swaps..
#
# DEBUG:root:4380000 swaps..
#
# DEBUG:root:4390000 swaps..
#
# DEBUG:root:4400000 swaps..
#
# DEBUG:root:4410000 swaps..
#
# DEBUG:root:4420000 swaps..
#
# DEBUG:root:4430000 swaps..
#
# DEBUG:root:4440000 swaps..
#
# DEBUG:root:4450000 swaps..
#
# DEBUG:root:4460000 swaps..
#
# DEBUG:root:4470000 swaps..
#
# DEBUG:root:4480000 swaps..
#
# DEBUG:root:4490000 swaps..
#
# DEBUG:root:4500000 swaps..
#
# DEBUG:root:4510000 swaps..
#
# DEBUG:root:4520000 swaps..
#
# DEBUG:root:4530000 swaps..
#
# DEBUG:root:4540000 swaps..
#
# DEBUG:root:4550000 swaps..
#
# DEBUG:root:4560000 swaps..
#
# DEBUG:root:4570000 swaps..
#
# DEBUG:root:4580000 swaps..
#
# DEBUG:root:4590000 swaps..
#
# DEBUG:root:4600000 swaps..
#
# DEBUG:root:4610000 swaps..
#
# DEBUG:root:4620000 swaps..
#
# DEBUG:root:4630000 swaps..
#
# DEBUG:root:4640000 swaps..
#
# DEBUG:root:4650000 swaps..
#
# DEBUG:root:4660000 swaps..
#
# DEBUG:root:4670000 swaps..
#
# DEBUG:root:4680000 swaps..
#
# DEBUG:root:4690000 swaps..
#
# DEBUG:root:4700000 swaps..
#
# DEBUG:root:4710000 swaps..
#
# DEBUG:root:4720000 swaps..
#
# DEBUG:root:4730000 swaps..
#
# DEBUG:root:4740000 swaps..
#
# DEBUG:root:4750000 swaps..
#
# DEBUG:root:4760000 swaps..
#
# DEBUG:root:4770000 swaps..
#
# DEBUG:root:4780000 swaps..
#
# DEBUG:root:4790000 swaps..
#
# DEBUG:root:4800000 swaps..
#
# DEBUG:root:4810000 swaps..
#
# DEBUG:root:4820000 swaps..
#
# DEBUG:root:4830000 swaps..
#
# DEBUG:root:4840000 swaps..
#
# DEBUG:root:4850000 swaps..
#
# DEBUG:root:4860000 swaps..
#
# DEBUG:root:4870000 swaps..
#
# DEBUG:root:4880000 swaps..
#
# DEBUG:root:4890000 swaps..
#
# DEBUG:root:4900000 swaps..
#
# DEBUG:root:4910000 swaps..
#
# DEBUG:root:4920000 swaps..
#
# DEBUG:root:4930000 swaps..
#
# DEBUG:root:4940000 swaps..
#
# DEBUG:root:4950000 swaps..
#
# DEBUG:root:4960000 swaps..
#
# DEBUG:root:4970000 swaps..
#
# DEBUG:root:4980000 swaps..
#
# DEBUG:root:4990000 swaps..
#
# DEBUG:root:5000000 swaps..
#
# DEBUG:root:5010000 swaps..
#
# DEBUG:root:5020000 swaps..
#
# DEBUG:root:5030000 swaps..
#
# DEBUG:root:5040000 swaps..
#
# DEBUG:root:5050000 swaps..
#
# DEBUG:root:5060000 swaps..
#
# DEBUG:root:5070000 swaps..
#
# DEBUG:root:5080000 swaps..
#
# DEBUG:root:5090000 swaps..
#
# DEBUG:root:5100000 swaps..
#
# DEBUG:root:5110000 swaps..
#
# DEBUG:root:5120000 swaps..
#
# DEBUG:root:5130000 swaps..
#
# DEBUG:root:5140000 swaps..
#
# DEBUG:root:5150000 swaps..
#
# DEBUG:root:5160000 swaps..
#
# DEBUG:root:5170000 swaps..
#
# DEBUG:root:5180000 swaps..
#
# DEBUG:root:5190000 swaps..
#
# DEBUG:root:5200000 swaps..
#
# DEBUG:root:5210000 swaps..
#
# DEBUG:root:5220000 swaps..
#
# DEBUG:root:5230000 swaps..
#
# DEBUG:root:5240000 swaps..
#
# DEBUG:root:5250000 swaps..
#
# DEBUG:root:5260000 swaps..
#
# DEBUG:root:5270000 swaps..
#
# DEBUG:root:5280000 swaps..
#
# DEBUG:root:5290000 swaps..
#
# DEBUG:root:5300000 swaps..
#
# DEBUG:root:5310000 swaps..
#
# DEBUG:root:5320000 swaps..
#
# DEBUG:root:5330000 swaps..
#
# DEBUG:root:5340000 swaps..
#
# DEBUG:root:5350000 swaps..
#
# DEBUG:root:5360000 swaps..
#
# DEBUG:root:5370000 swaps..
#
# DEBUG:root:5380000 swaps..
#
# DEBUG:root:5390000 swaps..
#
# DEBUG:root:5400000 swaps..
#
# DEBUG:root:5410000 swaps..
#
# DEBUG:root:5420000 swaps..
#
# DEBUG:root:5430000 swaps..
#
# DEBUG:root:5440000 swaps..
#
# DEBUG:root:5450000 swaps..
#
# DEBUG:root:5460000 swaps..
#
# DEBUG:root:5470000 swaps..
#
# DEBUG:root:5480000 swaps..
#
# DEBUG:root:5490000 swaps..
#
# DEBUG:root:5500000 swaps..
#
# DEBUG:root:5510000 swaps..
#
# DEBUG:root:5520000 swaps..
#
# DEBUG:root:5530000 swaps..
#
# DEBUG:root:5540000 swaps..
#
# DEBUG:root:5550000 swaps..
#
# DEBUG:root:5560000 swaps..
#
# DEBUG:root:5570000 swaps..
#
# DEBUG:root:5580000 swaps..
#
# DEBUG:root:5590000 swaps..
#
# DEBUG:root:5600000 swaps..
#
# DEBUG:root:5610000 swaps..
#
# DEBUG:root:5620000 swaps..
#
# DEBUG:root:5630000 swaps..
#
# DEBUG:root:5640000 swaps..
#
# DEBUG:root:5650000 swaps..
#
# DEBUG:root:5660000 swaps..
#
# DEBUG:root:5670000 swaps..
#
# DEBUG:root:5680000 swaps..
#
# DEBUG:root:5690000 swaps..
#
# DEBUG:root:5700000 swaps..
#
# DEBUG:root:5710000 swaps..
#
# DEBUG:root:5720000 swaps..
#
# DEBUG:root:5730000 swaps..
#
# DEBUG:root:5740000 swaps..
#
# DEBUG:root:5750000 swaps..
#
# DEBUG:root:5760000 swaps..
#
# DEBUG:root:5770000 swaps..
#
# DEBUG:root:5780000 swaps..
#
# DEBUG:root:5790000 swaps..
#
# DEBUG:root:5800000 swaps..
#
# DEBUG:root:5810000 swaps..
#
# DEBUG:root:5820000 swaps..
#
# DEBUG:root:5830000 swaps..
#
# DEBUG:root:5840000 swaps..
#
# DEBUG:root:5850000 swaps..
#
# DEBUG:root:5860000 swaps..
#
# DEBUG:root:5870000 swaps..
#
# DEBUG:root:5880000 swaps..
#
# DEBUG:root:5890000 swaps..
#
# DEBUG:root:5900000 swaps..
#
# DEBUG:root:5910000 swaps..
#
# DEBUG:root:5920000 swaps..
#
# DEBUG:root:5930000 swaps..
#
# DEBUG:root:5940000 swaps..
#
# DEBUG:root:5950000 swaps..
#
# DEBUG:root:5960000 swaps..
#
# DEBUG:root:5970000 swaps..
#
# DEBUG:root:5980000 swaps..
#
# DEBUG:root:5990000 swaps..
#
# DEBUG:root:6000000 swaps..
#
# DEBUG:root:6010000 swaps..
#
# DEBUG:root:6020000 swaps..
#
# DEBUG:root:6030000 swaps..
#
# DEBUG:root:6040000 swaps..
#
# DEBUG:root:6050000 swaps..
#
# DEBUG:root:6060000 swaps..
#
# DEBUG:root:6070000 swaps..
#
# DEBUG:root:6080000 swaps..
#
# DEBUG:root:6090000 swaps..
#
# DEBUG:root:6100000 swaps..
#
# DEBUG:root:6110000 swaps..
#
# DEBUG:root:6120000 swaps..
#
# DEBUG:root:6130000 swaps..
#
# DEBUG:root:6140000 swaps..
#
# DEBUG:root:6150000 swaps..
#
# DEBUG:root:6160000 swaps..
#
# DEBUG:root:6170000 swaps..
#
# DEBUG:root:6180000 swaps..
#
# DEBUG:root:6190000 swaps..
#
# DEBUG:root:6200000 swaps..
#
# DEBUG:root:6210000 swaps..
#
# DEBUG:root:6220000 swaps..
#
# DEBUG:root:6230000 swaps..
#
# DEBUG:root:6240000 swaps..
#
# DEBUG:root:6250000 swaps..
#
# DEBUG:root:6260000 swaps..
#
# DEBUG:root:6270000 swaps..
#
# DEBUG:root:6280000 swaps..
#
# DEBUG:root:6290000 swaps..
#
# DEBUG:root:6300000 swaps..
#
# DEBUG:root:6310000 swaps..
#
# DEBUG:root:6320000 swaps..
#
# DEBUG:root:6330000 swaps..
#
# DEBUG:root:6340000 swaps..
#
# DEBUG:root:6350000 swaps..
#
# DEBUG:root:6360000 swaps..
#
# DEBUG:root:6370000 swaps..
#
# DEBUG:root:6380000 swaps..
#
# DEBUG:root:6390000 swaps..
#
# DEBUG:root:6400000 swaps..
#
# DEBUG:root:6410000 swaps..
#
# DEBUG:root:6420000 swaps..
#
# DEBUG:root:6430000 swaps..
#
# DEBUG:root:6440000 swaps..
#
# DEBUG:root:6450000 swaps..
#
# DEBUG:root:6460000 swaps..
#
# DEBUG:root:6470000 swaps..
#
# DEBUG:root:6480000 swaps..
#
# DEBUG:root:6490000 swaps..
#
# DEBUG:root:6500000 swaps..
#
# DEBUG:root:6510000 swaps..
#
# DEBUG:root:6520000 swaps..
#
# DEBUG:root:6530000 swaps..
#
# DEBUG:root:6540000 swaps..
#
# DEBUG:root:6550000 swaps..
#
# DEBUG:root:6560000 swaps..
#
# DEBUG:root:6570000 swaps..
#
# DEBUG:root:6580000 swaps..
#
# DEBUG:root:6590000 swaps..
#
# DEBUG:root:6600000 swaps..
#
# DEBUG:root:6610000 swaps..
#
# DEBUG:root:6620000 swaps..
#
# DEBUG:root:6630000 swaps..
#
# DEBUG:root:6640000 swaps..
#
# DEBUG:root:6650000 swaps..
#
# DEBUG:root:6660000 swaps..
#
# DEBUG:root:6670000 swaps..
#
# DEBUG:root:6680000 swaps..
#
# DEBUG:root:6690000 swaps..
#
# DEBUG:root:6700000 swaps..
#
# DEBUG:root:6710000 swaps..
#
# DEBUG:root:6720000 swaps..
#
# DEBUG:root:6730000 swaps..
#
# DEBUG:root:6740000 swaps..
#
# DEBUG:root:6750000 swaps..
#
# DEBUG:root:6760000 swaps..
#
# DEBUG:root:6770000 swaps..
#
# DEBUG:root:6780000 swaps..
#
# DEBUG:root:6790000 swaps..
#
# DEBUG:root:6800000 swaps..
#
# DEBUG:root:6810000 swaps..
#
# DEBUG:root:6820000 swaps..
#
# DEBUG:root:6830000 swaps..
#
# DEBUG:root:6840000 swaps..
#
# DEBUG:root:6850000 swaps..
#
# DEBUG:root:6860000 swaps..
#
# DEBUG:root:6870000 swaps..
#
# DEBUG:root:6880000 swaps..
#
# DEBUG:root:6890000 swaps..
#
# DEBUG:root:6900000 swaps..
#
# DEBUG:root:6910000 swaps..
#
# DEBUG:root:6920000 swaps..
#
# DEBUG:root:6930000 swaps..
#
# DEBUG:root:6940000 swaps..
#
# DEBUG:root:6950000 swaps..
#
# DEBUG:root:6960000 swaps..
#
# DEBUG:root:6970000 swaps..
#
# DEBUG:root:6980000 swaps..
#
# DEBUG:root:6990000 swaps..
#
# DEBUG:root:7000000 swaps..
#
# DEBUG:root:7010000 swaps..
#
# DEBUG:root:7020000 swaps..
#
# DEBUG:root:7030000 swaps..
#
# DEBUG:root:7040000 swaps..
#
# DEBUG:root:7050000 swaps..
#
# DEBUG:root:7060000 swaps..
#
# DEBUG:root:7070000 swaps..
#
# DEBUG:root:7080000 swaps..
#
# DEBUG:root:7090000 swaps..
#
# DEBUG:root:7100000 swaps..
#
# DEBUG:root:7110000 swaps..
#
# DEBUG:root:7120000 swaps..
#
# DEBUG:root:7130000 swaps..
#
# DEBUG:root:7140000 swaps..
#
# DEBUG:root:7150000 swaps..
#
# DEBUG:root:7160000 swaps..
#
# DEBUG:root:7170000 swaps..
#
# DEBUG:root:7180000 swaps..
#
# DEBUG:root:7190000 swaps..
#
# DEBUG:root:7200000 swaps..
#
# DEBUG:root:7210000 swaps..
#
# DEBUG:root:7220000 swaps..
#
# DEBUG:root:7230000 swaps..
#
# DEBUG:root:7240000 swaps..
#
# DEBUG:root:7250000 swaps..
#
# DEBUG:root:7260000 swaps..
#
# DEBUG:root:7270000 swaps..
#
# DEBUG:root:7280000 swaps..
#
# DEBUG:root:7290000 swaps..
#
# DEBUG:root:7300000 swaps..
#
# DEBUG:root:7310000 swaps..
#
# DEBUG:root:7320000 swaps..
#
# DEBUG:root:7330000 swaps..
#
# DEBUG:root:7340000 swaps..
#
# DEBUG:root:7350000 swaps..
#
# DEBUG:root:7360000 swaps..
#
# DEBUG:root:7370000 swaps..
#
# DEBUG:root:7380000 swaps..
#
# DEBUG:root:7390000 swaps..
#
# DEBUG:root:7400000 swaps..
#
# DEBUG:root:7410000 swaps..
#
# DEBUG:root:7420000 swaps..
#
# DEBUG:root:7430000 swaps..
#
# DEBUG:root:7440000 swaps..
#
# DEBUG:root:7450000 swaps..
#
# DEBUG:root:7460000 swaps..
#
# DEBUG:root:7470000 swaps..
#
# DEBUG:root:7480000 swaps..
#
# DEBUG:root:7490000 swaps..
#
# DEBUG:root:7500000 swaps..
#
# DEBUG:root:7510000 swaps..
#
# DEBUG:root:7520000 swaps..
#
# DEBUG:root:7530000 swaps..
#
# DEBUG:root:7540000 swaps..
#
# DEBUG:root:7550000 swaps..
#
# DEBUG:root:7560000 swaps..
#
# DEBUG:root:7570000 swaps..
#
# DEBUG:root:7580000 swaps..
#
# DEBUG:root:7590000 swaps..
#
# DEBUG:root:7600000 swaps..
#
# DEBUG:root:7610000 swaps..
#
# DEBUG:root:7620000 swaps..
#
# DEBUG:root:7630000 swaps..
#
# DEBUG:root:7640000 swaps..
#
# DEBUG:root:7650000 swaps..
#
# DEBUG:root:7660000 swaps..
#
# DEBUG:root:7670000 swaps..
#
# DEBUG:root:7680000 swaps..
#
# DEBUG:root:7690000 swaps..
#
# DEBUG:root:7700000 swaps..
#
# DEBUG:root:7710000 swaps..
#
# DEBUG:root:7720000 swaps..
#
# DEBUG:root:7730000 swaps..
#
# DEBUG:root:7740000 swaps..
#
# DEBUG:root:7750000 swaps..
#
# DEBUG:root:7760000 swaps..
#
# DEBUG:root:7770000 swaps..
#
# DEBUG:root:7780000 swaps..
#
# DEBUG:root:7790000 swaps..
#
# DEBUG:root:7800000 swaps..
#
# DEBUG:root:7810000 swaps..
#
# DEBUG:root:7820000 swaps..
#
# DEBUG:root:7830000 swaps..
#
# DEBUG:root:7840000 swaps..
#
# DEBUG:root:7850000 swaps..
#
# DEBUG:root:7860000 swaps..
#
# DEBUG:root:7870000 swaps..
#
# DEBUG:root:7880000 swaps..
#
# DEBUG:root:7890000 swaps..
#
# DEBUG:root:7900000 swaps..
#
# DEBUG:root:7910000 swaps..
#
# DEBUG:root:7920000 swaps..
#
# DEBUG:root:7930000 swaps..
#
# DEBUG:root:7940000 swaps..
#
# DEBUG:root:7950000 swaps..
#
# DEBUG:root:7960000 swaps..
#
# DEBUG:root:7970000 swaps..
#
# DEBUG:root:7980000 swaps..
#
# DEBUG:root:7990000 swaps..
#
# DEBUG:root:8000000 swaps..
#
# DEBUG:root:8010000 swaps..
#
# DEBUG:root:8020000 swaps..
#
# DEBUG:root:8030000 swaps..
#
# DEBUG:root:8040000 swaps..
#
# DEBUG:root:8050000 swaps..
#
# DEBUG:root:8060000 swaps..
#
# DEBUG:root:8070000 swaps..
#
# DEBUG:root:8080000 swaps..
#
# DEBUG:root:8090000 swaps..
#
# DEBUG:root:8100000 swaps..
#
# DEBUG:root:8110000 swaps..
#
# DEBUG:root:8120000 swaps..
#
# DEBUG:root:8130000 swaps..
#
# DEBUG:root:8140000 swaps..
#
# DEBUG:root:8150000 swaps..
#
# DEBUG:root:8160000 swaps..
#
# DEBUG:root:8170000 swaps..
#
# DEBUG:root:8180000 swaps..
#
# DEBUG:root:8190000 swaps..
#
# DEBUG:root:8200000 swaps..
#
# DEBUG:root:8210000 swaps..
#
# DEBUG:root:8220000 swaps..
#
# DEBUG:root:8230000 swaps..
#
# DEBUG:root:8240000 swaps..
#
# DEBUG:root:8250000 swaps..
#
# DEBUG:root:8260000 swaps..
#
# DEBUG:root:8270000 swaps..
#
# DEBUG:root:8280000 swaps..
#
# DEBUG:root:8290000 swaps..
#
# DEBUG:root:8300000 swaps..
#
# DEBUG:root:8310000 swaps..
#
# DEBUG:root:8320000 swaps..
#
# DEBUG:root:8330000 swaps..
#
# DEBUG:root:8340000 swaps..
#
# DEBUG:root:8350000 swaps..
#
# DEBUG:root:8360000 swaps..
#
# DEBUG:root:8370000 swaps..
#
# DEBUG:root:8380000 swaps..
#
# DEBUG:root:8390000 swaps..
#
# DEBUG:root:8400000 swaps..
#
# DEBUG:root:8410000 swaps..
#
# DEBUG:root:8420000 swaps..
#
# DEBUG:root:8430000 swaps..
#
# DEBUG:root:8440000 swaps..
#
# DEBUG:root:8450000 swaps..
#
# DEBUG:root:8460000 swaps..
#
# DEBUG:root:8470000 swaps..
#
# DEBUG:root:8480000 swaps..
#
# DEBUG:root:8490000 swaps..
#
# DEBUG:root:8500000 swaps..
#
# DEBUG:root:8510000 swaps..
#
# DEBUG:root:8520000 swaps..
#
# DEBUG:root:8530000 swaps..
#
# DEBUG:root:8540000 swaps..
#
# DEBUG:root:8550000 swaps..
#
# DEBUG:root:8560000 swaps..
#
# DEBUG:root:8570000 swaps..
#
# DEBUG:root:8580000 swaps..
#
# DEBUG:root:8590000 swaps..
#
# DEBUG:root:8600000 swaps..
#
# DEBUG:root:8610000 swaps..
#
# DEBUG:root:8620000 swaps..
#
# DEBUG:root:8630000 swaps..
#
# DEBUG:root:8640000 swaps..
#
# DEBUG:root:8650000 swaps..
#
# DEBUG:root:8660000 swaps..
#
# DEBUG:root:8670000 swaps..
#
# DEBUG:root:8680000 swaps..
#
# DEBUG:root:8690000 swaps..
#
# DEBUG:root:8700000 swaps..
#
# DEBUG:root:8710000 swaps..
#
# DEBUG:root:8720000 swaps..
#
# DEBUG:root:8730000 swaps..
#
# DEBUG:root:8740000 swaps..
#
# DEBUG:root:8750000 swaps..
#
# DEBUG:root:8760000 swaps..
#
# DEBUG:root:8770000 swaps..
#
# DEBUG:root:8780000 swaps..
#
# DEBUG:root:8790000 swaps..
#
# DEBUG:root:8800000 swaps..
#
# DEBUG:root:8810000 swaps..
#
# DEBUG:root:8820000 swaps..
#
# DEBUG:root:8830000 swaps..
#
# DEBUG:root:8840000 swaps..
#
# DEBUG:root:8850000 swaps..
#
# DEBUG:root:8860000 swaps..
#
# DEBUG:root:8870000 swaps..
#
# DEBUG:root:8880000 swaps..
#
# DEBUG:root:8890000 swaps..
#
# DEBUG:root:8900000 swaps..
#
# DEBUG:root:8910000 swaps..
#
# DEBUG:root:8920000 swaps..
#
# DEBUG:root:8930000 swaps..
#
# DEBUG:root:8940000 swaps..
#
# DEBUG:root:8950000 swaps..
#
# DEBUG:root:8960000 swaps..
#
# DEBUG:root:8970000 swaps..
#
# DEBUG:root:8980000 swaps..
#
# DEBUG:root:8990000 swaps..
#
# DEBUG:root:9000000 swaps..
#
# DEBUG:root:9010000 swaps..
#
# DEBUG:root:9020000 swaps..
#
# DEBUG:root:9030000 swaps..
#
# DEBUG:root:9040000 swaps..
#
# DEBUG:root:9050000 swaps..
#
# DEBUG:root:9060000 swaps..
#
# DEBUG:root:9070000 swaps..
#
# DEBUG:root:9080000 swaps..
#
# DEBUG:root:9090000 swaps..
#
# DEBUG:root:9100000 swaps..
#
# DEBUG:root:9110000 swaps..
#
# DEBUG:root:9120000 swaps..
#
# DEBUG:root:9130000 swaps..
#
# DEBUG:root:9140000 swaps..
#
# DEBUG:root:9150000 swaps..
#
# DEBUG:root:9160000 swaps..
#
# DEBUG:root:9170000 swaps..
#
# DEBUG:root:9180000 swaps..
#
# DEBUG:root:9190000 swaps..
#
# DEBUG:root:9200000 swaps..
#
# DEBUG:root:9210000 swaps..
#
# DEBUG:root:9220000 swaps..
#
# DEBUG:root:9230000 swaps..
#
# DEBUG:root:9240000 swaps..
#
# DEBUG:root:9250000 swaps..
#
# DEBUG:root:9260000 swaps..
#
# DEBUG:root:9270000 swaps..
#
# DEBUG:root:9280000 swaps..
#
# DEBUG:root:9290000 swaps..
#
# DEBUG:root:9300000 swaps..
#
# DEBUG:root:9310000 swaps..
#
# DEBUG:root:9320000 swaps..
#
# DEBUG:root:9330000 swaps..
#
# DEBUG:root:9340000 swaps..
#
# DEBUG:root:9350000 swaps..
#
# DEBUG:root:9360000 swaps..
#
# DEBUG:root:9370000 swaps..
#
# DEBUG:root:9380000 swaps..
#
#
# real	8m56.597s
# user	8m42.303s
# sys	0m4.829s
# ME
# DEBUG:root:comp ME for BRCA_wustl-som, BRCA_wustl-som
# INFO:root:0
# INFO:root:1000
# INFO:root:2000
# INFO:root:3000

# %%
# Use Edgereader to integrate cpairs and mpairs
